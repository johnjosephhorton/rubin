# %%
with open('libraries.py') as f:
    code = f.read()
exec(code)

with open('functions.py') as f:
    code = f.read()
exec(code)

# %%
# determine user
user = getpass.getuser()
if user == 'peymanshahidi':
    main_folder_path = '/Users/peymanshahidi/Dropbox (MIT)/Research/AI and Occupations/ai-exposure'
    data_path = f'{main_folder_path}/output'

# %% [markdown]
# ### GPT questions for assessing task stats

# %%
from edsl.questions import QuestionNumerical

def get_tasks_stas(occupation, tasks):
   scenarios = [Scenario({"occupation": occupation, "all_tasks": tasks, "task": task}) for task in tasks]

   q_human_cost = QuestionNumerical(
      question_name = "human_cost", # parameter M in model
      question_text = dedent("""
                           Consider {{ occupation }} as an occupation. 
                           And consider this task: {{ task }}.
                           How long (in minutes) does it take a person to complete this task? 
                           (5 = 5 minutes or less, 480 = a full day, or 8 hours)
                           """),
      min_value = 5, # 5 minutes or less
      max_value = 480, # a full day, or 8 hours
   )

   q_management_cost = QuestionNumerical(
      question_name = "management_cost", # parameter A in model
      question_text = dedent("""
                           Consider {{ occupation }} as an occupation. 
                           And consider this task: {{ task }}.
                           Suppose a human worker "A" is assigned to and completes this task.
                           Now imagine a general-purpose artificial intelligence machine is deployed
                              to automate management process of this task and to validate worker "A"'s output.
                           How long will it take the machine to confirm if worker "A" has completed the task successfully?
                           (5 = 5 minute or less, 480 = a full day, or 8 hours)
                           """),
      min_value = 5, # 5 minutes or less
      max_value = 480, # a full day, or 8 hours
   )

   q_management_difficulty = QuestionNumerical(
      question_name = "management_difficulty", # parameter D in model for version with A
      question_text = dedent("""
                           Consider {{ occupation }} as an occupation.
                           In order to successfully complete the job, a worker needs to do the following tasks: {{ all_tasks }}.
                           Now consider this task in particular: {{ task }}.
                           Suppose the task is managed using a general-purpose artificial intelligence (AI) machine.
                           Given that the machine is not specifically trained in managing tasks of this occupation,
                           how difficult is it that it successfully assesses completion of this task in an attempt?
                           Give an answer that represents the relative difficulty of assessing completion of this task compared to the rest of tasks in occupation.
                           The answer must be a value that has up to two significant digits after the decimal point.
                           (0 = not difficult at all AI can successfully do it in every try, 1 = so difficult AI cannot do it in any attempt)
                           """),
      min_value = 0, # not difficult at all AI can successfully do it in every try
      max_value = 1, # so difficult AI cannot do it in any attempt
   )


   q_completion_difficulty = QuestionNumerical(
      question_name = "completion_difficulty", # parameter D in model for version with C
      question_text = dedent("""
                           Consider {{ occupation }} as an occupation.
                           In order to successfully complete the job, a worker needs to do the following tasks: {{ all_tasks }}.
                           Now consider this task in particular: {{ task }}.
                           Suppose the task is completed using a general-purpose artificial intelligence (AI) machine.
                           Given that the machine is not specifically trained in managing tasks of this occupation,
                           how difficult is it that it successfully completes this task in an attempt?
                           Give an answer that represents the relative difficulty of completing this task compared to the rest of tasks in occupation.
                           The answer must be a value that has up to two significant digits after the decimal point.
                           (0 = not difficult at all AI can successfully do it in a single try, 1 = so difficult AI cannot do it in any attempt)
                           """),
      min_value = 0, # not difficult at all AI can successfully do it in a single try
      max_value = 1, # so difficult AI cannot do it in any attempt
   )

   # Run questions
   results_human_cost = q_human_cost.by(m4).by(scenarios).run()
   results_management_cost = q_management_cost.by(m4).by(scenarios).run()
   results_management_difficulty = q_management_difficulty.by(m4).by(scenarios).run()
   results_completion_difficulty = q_completion_difficulty.by(m4).by(scenarios).run()

   # Convert outputs to pandas dataframe
   human_cost_df = results_human_cost.to_pandas()
   print(human_cost_df)
   management_cost_df = results_management_cost.to_pandas()
   management_difficulty_df = results_management_difficulty.to_pandas()
   completion_difficulty_df = results_completion_difficulty.to_pandas()

   # Subset dataframe
   human_cost_df = human_cost_df[['scenario.task', 'answer.human_cost']]
   management_cost_df = management_cost_df[['scenario.task', 'answer.management_cost']]
   management_difficulty_df = management_difficulty_df[['scenario.task', 'answer.management_difficulty']]
   completion_difficulty_df = completion_difficulty_df[['scenario.task', 'answer.completion_difficulty']]

   # Merge outputs
   tasks_stats = pd.merge(human_cost_df, management_cost_df, on='scenario.task', how='inner')
   tasks_stats = pd.merge(tasks_stats, management_difficulty_df, on='scenario.task', how='inner')
   tasks_stats = pd.merge(tasks_stats, completion_difficulty_df, on='scenario.task', how='inner')

   # Rename columns
   tasks_stats.rename(columns={'scenario.task': 'task', 
                               'answer.human_cost': 'human_cost', 
                               'answer.management_cost': 'management_cost', 
                               'answer.management_difficulty': 'management_difficulty',
                               'answer.completion_difficulty': 'completion_difficulty'}, inplace=True)
   
   return tasks_stats

# %%
def get_tasks(onet_data_path,
              occupation_code):

    # Load the data
    onet = pd.read_csv(onet_data_path)
    onet = onet.sort_values(by=['year', 'occ_code', 'occ_title', 'task_id'])
    onet = onet[onet['year'] == 2023].reset_index(drop=True)

    # Get list of tasks
    my_df = onet[(onet.occ_code == f'{occupation_code}') & (onet.year == 2023)]
    tasks = my_df['task'].unique().tolist()
    tasks = [task.replace("'", "") for task in tasks] # remove apastrophes so partitions DAG code can handle task strings
    return tasks

# %%
def get_AI_completion_cost(occupation, tasks):
  scenarios = [Scenario({"occupation": occupation, "all_tasks": tasks})]

  # q_machine_cost = QuestionNumerical(
  # question_name = "machine_cost", # parameter C in model
  # question_text = dedent("""
  #                       Consider {{ occupation }} as an occupation. 
  #                       In order to successfully complete the job, the following tasks must be successfully done: {{ all_tasks }}.
  #                       Suppose a number of human workers are assigned to and complete these tasks.
  #                       Now imagine a general-purpose artificial intelligence is deployed to automate all tasks.
  #                       How many compute units should the machine spend on average on each tasks to complete the job successfully?
  #                         Your answer should not be "None" or "0".
  #                       A compute unit can be, for example, the compute power of a single CPU core running for one minute.
  #                       (1 = 1 compute unit or less, 480 = 480 CPUs working for a minute or 1 CPU working for 480 minutes, or a full working day)
  #                       """),
  # min_value = 1, # 1 compute units
  # max_value = 480, # 480 cpus working for a minute, or 480 API calls
  # )

  q_machine_cost = QuestionNumerical(
  question_name = "machine_cost", # parameter C in model
  question_text = dedent("""
                        Consider {{ occupation }} as an occupation. 
                        In order to successfully complete the job, the following tasks must be successfully done: {{ all_tasks }}.
                        Suppose a number of human workers are assigned to and complete these tasks.
                        Now imagine a general-purpose artificial intelligence is deployed to automate all tasks.
                        How many compute units should the machine spend on average on each tasks to complete the job successfully?
                          Your answer should not be "None" or "0".
                        A compute unit can be, for example, the number of API calls to a cloud service.
                        (1 = 1 compute unit or less, 10000 = 10000 API calls)
                        """),
  min_value = 1, # 1 compute units
  max_value = 10000, # 10000 API calls
  )

  # Run question
  results_machine_cost = q_machine_cost.by(m4).by(scenarios).run()

  # Convert outputs to pandas dataframe
  machine_cost_df = results_machine_cost.to_pandas()

  return machine_cost_df['answer.machine_cost'].iloc[0]

# %% [markdown]
# ### Fetch Occupation Task Stats

# %%
onet_data_path = f'{data_path}/data/onet_occupations_yearly.csv'

occupation_list = ['pileDriverOperators', 'dredgeOperators', 'gradersAndSortersForAgriculturalProducts',
                   'insuranceUnderwriters', 'insuranceAppraisersForAutoDamage', 'floorSandersAndFinishers', 
                   'reinforcingIronAndRebarWorkers', 'travelAgents', 'dataEntryKeyer', 
                   'athletesAndSportsCompetitors', 'audiovisualEquipmentInstallerAndRepairers', 'hearingAidSpecialists', 
                   'personalCareAides', 'proofreadersAndCopyMarkers', 'chiropractors', 
                   'shippingReceivingAndInventoryClerks', 'cooksShortOrder', 'orthodontists',
                   'subwayAndStreetcarOperators', 'packersAndPackagersHand', 'hoistAndWinchOperators', 
                   'forgingMachineSettersOperatorsAndTenders', 'avionicsTechnicians', 'dishwashers', 
                   'dispatchersExceptPoliceFireAndAmbulance', 'familyMedicinePhysicians', 'MachineFeedersAndOffbearers'
                   ]


#occupation_list = ['travelAgents']

# occupation_list = ['sociologists', 'dancers', 'carpetInstallers']

# %%
import time
start_time = time.time()

for occupation in occupation_list:
    occupation_start_time = time.time()
    print(f'--------------- Running: {occupation} ---------------')

    # Generate occupation-specific strings
    GPT_input_occupation, plot_title_occupation, occupation_code, occupation_folder = pick_occupation(occupation)

    # Get occupation tasks
    tasks = get_tasks(onet_data_path, occupation_code)
    print(f'Number of tasks: {len(tasks)}')

    # Ask GPT to assess tasks' stats
    tasks_stats = get_tasks_stas(GPT_input_occupation, tasks)

    # Ask GPT to assess AI completion cost for occupation
    machine_cost = get_AI_completion_cost(GPT_input_occupation, tasks)

    # add AI completion cost to tasks stats and change order of columns
    tasks_stats['machine_cost'] = machine_cost
    tasks_stats = tasks_stats[['task', 'human_cost', 'management_cost', 'management_difficulty', 'machine_cost', 'completion_difficulty']]


    # add "Target" task to tasks list
    aux_df = pd.DataFrame({'task': ['"Target"'],
                        'human_cost': [0],
                        'management_cost': [0],
                        'management_difficulty': [0], 
                        'machine_cost': [0],
                        'completion_difficulty': [0],})
    tasks_stats = pd.concat([tasks_stats, aux_df], ignore_index=True)

    # Save output
    tasks_stats.to_csv(f'{occupation_folder}/{occupation}_taskStats.csv', index=False)

    occupation_end_time = time.time()
    occupation_execution_time = occupation_end_time - occupation_start_time
    print(f"**** {occupation} runtime: {occupation_execution_time:.2f} seconds ****\n")

end_time = time.time()
execution_time = (end_time - start_time)/60
print(f"\n\nTotal Runtime: {execution_time:.2f} minutes")
# Out:
# --------------- Running: pileDriverOperators ---------------
# Number of tasks: 5
#    answer.human_cost    scenario.occupation  \
# 0                 60  pile dirver operators
# 1                 30  pile dirver operators
# 2                480  pile dirver operators
# 3                 60  pile dirver operators
# 4                 15  pile dirver operators
#
#                                   scenario.all_tasks  \
# 0  ['Move hand and foot levers of hoisting equipm...
# 1  ['Move hand and foot levers of hoisting equipm...
# 2  ['Move hand and foot levers of hoisting equipm...
# 3  ['Move hand and foot levers of hoisting equipm...
# 4  ['Move hand and foot levers of hoisting equipm...
#
#                                        scenario.task agent.agent_name  \
# 0            Clean, lubricate, and refill equipment.        Agent_105
# 1  Conduct pre-operational checks on equipment to...        Agent_105
# 2  Drive pilings to provide support for buildings...        Agent_105
# 3  Move levers and turn valves to activate power ...        Agent_105
# 4  Move hand and foot levers of hoisting equipmen...        Agent_105
#
#                              agent.agent_instruction  model.frequency_penalty  \
# 0  You are answering questions as if you were a h...                        0
# 1  You are answering questions as if you were a h...                        0
# 2  You are answering questions as if you were a h...                        0
# 3  You are answering questions as if you were a h...                        0
# 4  You are answering questions as if you were a h...                        0
#
#    model.temperature  model.max_tokens  model.logprobs  ...  \
# 0               0.50              1000           False  ...
# 1               0.50              1000           False  ...
# 2               0.50              1000           False  ...
# 3               0.50              1000           False  ...
# 4               0.50              1000           False  ...
#
#    prompt.human_cost_system_prompt raw_model_response.human_cost_one_usd_buys  \
# 0                              NaN                                     122.10
# 1                              NaN                                     114.94
# 2                              NaN                                     113.77
# 3                              NaN                                     107.88
# 4                              NaN                                     110.01
#
#     raw_model_response.human_cost_raw_model_response  \
# 0  {'id': 'chatcmpl-AHAS5ynK7dy1lAz99QLDdqCBpHKFl...
# 1  {'id': 'chatcmpl-AHAS5XiAd1yLyHpLw5sP8t5fDVfIW...
# 2  {'id': 'chatcmpl-AHAS59wb5laiykqrW9WoTkBJ6FIyg...
# 3  {'id': 'chatcmpl-AHAS6lktj6SzDrsOVikUfiuhklPPB...
# 4  {'id': 'chatcmpl-AHAS6DEywqAFrJytYkjcXnQIsIcKb...
#
#    raw_model_response.human_cost_cost iteration.iteration  \
# 0                                0.01                   0
# 1                                0.01                   0
# 2                                0.01                   0
# 3                                0.01                   0
# 4                                0.01                   0
#
#               question_text.human_cost_question_text  \
# 0  \nConsider {{ occupation }} as an occupation. ...
# 1  \nConsider {{ occupation }} as an occupation. ...
# 2  \nConsider {{ occupation }} as an occupation. ...
# 3  \nConsider {{ occupation }} as an occupation. ...
# 4  \nConsider {{ occupation }} as an occupation. ...
#
#    question_options.human_cost_question_options  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   question_type.human_cost_question_type  \
# 0                              numerical
# 1                              numerical
# 2                              numerical
# 3                              numerical
# 4                              numerical
#
#                           comment.human_cost_comment  \
# 0  Cleaning, lubricating, and refilling equipment...
# 1  This estimate is based on the assumption that ...
# 2  Driving pilings is a labor-intensive task that...
# 3  This is an estimate based on the assumption th...
# 4  This estimation is based on the complexity of ...
#
#         generated_tokens.human_cost_generated_tokens
# 0  60\n\nCleaning, lubricating, and refilling equ...
# 1  30\n\nThis estimate is based on the assumption...
# 2  480\n\nDriving pilings is a labor-intensive ta...
# 3  60\n\nThis is an estimate based on the assumpt...
# 4  15\n\nThis estimation is based on the complexi...
#
# [5 rows x 25 columns]
# **** pileDriverOperators runtime: 34.44 seconds ****
#
# --------------- Running: dredgeOperators ---------------
# Number of tasks: 6
#    answer.human_cost scenario.occupation  \
# 0                  5    dredge operators
# 1                 10    dredge operators
# 2                 30    dredge operators
# 3                 10    dredge operators
# 4                120    dredge operators
# 5                 60    dredge operators
#
#                                   scenario.all_tasks  \
# 0  ['Move levers to position dredges for excavati...
# 1  ['Move levers to position dredges for excavati...
# 2  ['Move levers to position dredges for excavati...
# 3  ['Move levers to position dredges for excavati...
# 4  ['Move levers to position dredges for excavati...
# 5  ['Move levers to position dredges for excavati...
#
#                                        scenario.task agent.agent_name  \
# 0       Start and stop engines to operate equipment.        Agent_110
# 1  Start power winches that draw in or let out ca...        Agent_110
# 2  Lower anchor poles to verify depths of excavat...        Agent_110
# 3  Move levers to position dredges for excavation...        Agent_110
# 4  Direct or assist workers placing shore anchors...        Agent_110
# 5           Pump water to clear machinery pipelines.        Agent_110
#
#                              agent.agent_instruction  model.frequency_penalty  \
# 0  You are answering questions as if you were a h...                        0
# 1  You are answering questions as if you were a h...                        0
# 2  You are answering questions as if you were a h...                        0
# 3  You are answering questions as if you were a h...                        0
# 4  You are answering questions as if you were a h...                        0
# 5  You are answering questions as if you were a h...                        0
#
#    model.temperature  model.max_tokens  model.logprobs  ...  \
# 0               0.50              1000           False  ...
# 1               0.50              1000           False  ...
# 2               0.50              1000           False  ...
# 3               0.50              1000           False  ...
# 4               0.50              1000           False  ...
# 5               0.50              1000           False  ...
#
#    prompt.human_cost_system_prompt raw_model_response.human_cost_one_usd_buys  \
# 0                              NaN                                     153.61
# 1                              NaN                                     127.23
# 2                              NaN                                     124.85
# 3                              NaN                                     114.94
# 4                              NaN                                     123.92
# 5                              NaN                                     114.16
#
#     raw_model_response.human_cost_raw_model_response  \
# 0  {'id': 'chatcmpl-AHASXto3rSvXcM6wEZjyo0A7pf9tV...
# 1  {'id': 'chatcmpl-AHASXWsku0UB9OMI80PHiYXEnIrOx...
# 2  {'id': 'chatcmpl-AHASXP9ZAt3P0sMf6JAxYwgx5D1g8...
# 3  {'id': 'chatcmpl-AHASXCeHzRo1KOWy1JAJgZvJVikOl...
# 4  {'id': 'chatcmpl-AHASXnvTl2w2oTgTrjp84bDVrwFho...
# 5  {'id': 'chatcmpl-AHASXduY8K6LE6X63sNZkH4pkByyP...
#
#    raw_model_response.human_cost_cost iteration.iteration  \
# 0                                0.01                   0
# 1                                0.01                   0
# 2                                0.01                   0
# 3                                0.01                   0
# 4                                0.01                   0
# 5                                0.01                   0
#
#               question_text.human_cost_question_text  \
# 0  \nConsider {{ occupation }} as an occupation. ...
# 1  \nConsider {{ occupation }} as an occupation. ...
# 2  \nConsider {{ occupation }} as an occupation. ...
# 3  \nConsider {{ occupation }} as an occupation. ...
# 4  \nConsider {{ occupation }} as an occupation. ...
# 5  \nConsider {{ occupation }} as an occupation. ...
#
#    question_options.human_cost_question_options  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
#
#   question_type.human_cost_question_type  \
# 0                              numerical
# 1                              numerical
# 2                              numerical
# 3                              numerical
# 4                              numerical
# 5                              numerical
#
#                           comment.human_cost_comment  \
# 0  Starting and stopping engines to operate equip...
# 1  This estimation is based on the assumption tha...
# 2  Lowering anchor poles and verifying depths of ...
# 3  The time it takes to complete this task can va...
# 4  This task involves multiple steps and coordina...
# 5  The duration can vary depending on the size of...
#
#         generated_tokens.human_cost_generated_tokens
# 0  5\n\nStarting and stopping engines to operate ...
# 1  10\n\nThis estimation is based on the assumpti...
# 2  30\n\nLowering anchor poles and verifying dept...
# 3  10\n\nThe time it takes to complete this task ...
# 4  120\n\nThis task involves multiple steps and c...
# 5  60\n\nThe duration can vary depending on the s...
#
# [6 rows x 25 columns]
# **** dredgeOperators runtime: 23.38 seconds ****
#
# --------------- Running: gradersAndSortersForAgriculturalProducts ---------------
# Number of tasks: 6
#    answer.human_cost                            scenario.occupation  \
# 0                480  Graders and sorters for agricultural products
# 1                 10  Graders and sorters for agricultural products
# 2                  5  Graders and sorters for agricultural products
# 3                 30  Graders and sorters for agricultural products
# 4                  5  Graders and sorters for agricultural products
# 5                480  Graders and sorters for agricultural products
#
#                                   scenario.all_tasks  \
# 0  ['Grade and sort products according to factors...
# 1  ['Grade and sort products according to factors...
# 2  ['Grade and sort products according to factors...
# 3  ['Grade and sort products according to factors...
# 4  ['Grade and sort products according to factors...
# 5  ['Grade and sort products according to factors...
#
#                                        scenario.task agent.agent_name  \
# 0  Discard inferior or defective products or fore...        Agent_114
# 1  Record grade or identification numbers on tags...        Agent_114
# 2  Separate fiber tufts between fingers to assess...        Agent_114
# 3  Place products in containers according to grad...        Agent_114
# 4  Weigh products or estimate their weight, visua...        Agent_114
# 5  Grade and sort products according to factors s...        Agent_114
#
#                              agent.agent_instruction  model.frequency_penalty  \
# 0  You are answering questions as if you were a h...                        0
# 1  You are answering questions as if you were a h...                        0
# 2  You are answering questions as if you were a h...                        0
# 3  You are answering questions as if you were a h...                        0
# 4  You are answering questions as if you were a h...                        0
# 5  You are answering questions as if you were a h...                        0
#
#    model.temperature  model.max_tokens  model.logprobs  ...  \
# 0               0.50              1000           False  ...
# 1               0.50              1000           False  ...
# 2               0.50              1000           False  ...
# 3               0.50              1000           False  ...
# 4               0.50              1000           False  ...
# 5               0.50              1000           False  ...
#
#    prompt.human_cost_system_prompt raw_model_response.human_cost_one_usd_buys  \
# 0                              NaN                                     119.91
# 1                              NaN                                     123.00
# 2                              NaN                                     123.00
# 3                              NaN                                     113.77
# 4                              NaN                                     118.63
# 5                              NaN                                     113.38
#
#     raw_model_response.human_cost_raw_model_response  \
# 0  {'id': 'chatcmpl-AHASuL0dmkpMeVmZ9779RbMiYgXck...
# 1  {'id': 'chatcmpl-AHASvAjYTmgjLBvhA8WBUhcwdLjSS...
# 2  {'id': 'chatcmpl-AHASvHTUqbrsTpqIGKZOxgqDjXypF...
# 3  {'id': 'chatcmpl-AHASvtMmMJneHFlDN6oZa9d75OX4A...
# 4  {'id': 'chatcmpl-AHASvt42l0RG6I154LFRKmLrMbPvA...
# 5  {'id': 'chatcmpl-AHASzmyoOU67G01AB4oZxGptwFBE5...
#
#    raw_model_response.human_cost_cost iteration.iteration  \
# 0                                0.01                   0
# 1                                0.01                   0
# 2                                0.01                   0
# 3                                0.01                   0
# 4                                0.01                   0
# 5                                0.01                   0
#
#               question_text.human_cost_question_text  \
# 0  \nConsider {{ occupation }} as an occupation. ...
# 1  \nConsider {{ occupation }} as an occupation. ...
# 2  \nConsider {{ occupation }} as an occupation. ...
# 3  \nConsider {{ occupation }} as an occupation. ...
# 4  \nConsider {{ occupation }} as an occupation. ...
# 5  \nConsider {{ occupation }} as an occupation. ...
#
#    question_options.human_cost_question_options  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
#
#   question_type.human_cost_question_type  \
# 0                              numerical
# 1                              numerical
# 2                              numerical
# 3                              numerical
# 4                              numerical
# 5                              numerical
#
#                           comment.human_cost_comment  \
# 0  This task is a continuous one that goes on thr...
# 1  This task involves recording information, whic...
# 2  The task of separating fiber tufts and assessi...
# 3  The time it takes for a person to complete thi...
# 4  Weighing a product or estimating its weight vi...
# 5  Grading and sorting agricultural products is a...
#
#         generated_tokens.human_cost_generated_tokens
# 0  480\n\nThis task is a continuous one that goes...
# 1  10\n\nThis task involves recording information...
# 2  5\nThe task of separating fiber tufts and asse...
# 3  30\n\nThe time it takes for a person to comple...
# 4  5\nWeighing a product or estimating its weight...
# 5  480\nGrading and sorting agricultural products...
#
# [6 rows x 25 columns]
# **** gradersAndSortersForAgriculturalProducts runtime: 34.31 seconds ****
#
# --------------- Running: insuranceUnderwriters ---------------
# Number of tasks: 7
#    answer.human_cost     scenario.occupation  \
# 0                 60  insurance underwriters
# 1                 60  insurance underwriters
# 2                 60  insurance underwriters
# 3                120  insurance underwriters
# 4                 60  insurance underwriters
# 5                480  insurance underwriters
# 6                120  insurance underwriters
#
#                                   scenario.all_tasks  \
# 0  ['Decline excessive risks.', 'Write to field r...
# 1  ['Decline excessive risks.', 'Write to field r...
# 2  ['Decline excessive risks.', 'Write to field r...
# 3  ['Decline excessive risks.', 'Write to field r...
# 4  ['Decline excessive risks.', 'Write to field r...
# 5  ['Decline excessive risks.', 'Write to field r...
# 6  ['Decline excessive risks.', 'Write to field r...
#
#                                        scenario.task agent.agent_name  \
# 0                           Decline excessive risks.        Agent_119
# 1  Examine documents to determine degree of risk ...        Agent_119
# 2  Authorize reinsurance of policy when risk is h...        Agent_119
# 3  Decrease value of policy when risk is substand...        Agent_119
# 4  Write to field representatives, medical person...        Agent_119
# 5  Evaluate possibility of losses due to catastro...        Agent_119
# 6  Review company records to determine amount of ...        Agent_119
#
#                              agent.agent_instruction  model.frequency_penalty  \
# 0  You are answering questions as if you were a h...                        0
# 1  You are answering questions as if you were a h...                        0
# 2  You are answering questions as if you were a h...                        0
# 3  You are answering questions as if you were a h...                        0
# 4  You are answering questions as if you were a h...                        0
# 5  You are answering questions as if you were a h...                        0
# 6  You are answering questions as if you were a h...                        0
#
#    model.temperature  model.max_tokens  model.logprobs  ...  \
# 0               0.50              1000           False  ...
# 1               0.50              1000           False  ...
# 2               0.50              1000           False  ...
# 3               0.50              1000           False  ...
# 4               0.50              1000           False  ...
# 5               0.50              1000           False  ...
# 6               0.50              1000           False  ...
#
#    prompt.human_cost_system_prompt raw_model_response.human_cost_one_usd_buys  \
# 0                              NaN                                     124.38
# 1                              NaN                                     126.27
# 2                              NaN                                     126.27
# 3                              NaN                                     112.24
# 4                              NaN                                     111.86
# 5                              NaN                                     120.78
# 6                              NaN                                     101.94
#
#     raw_model_response.human_cost_raw_model_response  \
# 0  {'id': 'chatcmpl-AHATT0dQSCwba3Qlpx37oL5XjLAr5...
# 1  {'id': 'chatcmpl-AHATWSrEwpahuGbbKPRQ3JGuUW1il...
# 2  {'id': 'chatcmpl-AHATWOBgksRpOTjO57vB5foJ9uBnn...
# 3  {'id': 'chatcmpl-AHATWz0ea9Cv4BgHThBLAzuoF3Vj1...
# 4  {'id': 'chatcmpl-AHATWl2VL78JCso8fCfT8xrsLOn2H...
# 5  {'id': 'chatcmpl-AHATWcftIUuUXnxBjWVIYjItK8phk...
# 6  {'id': 'chatcmpl-AHATWAOd9EPBdpFGD8Hb5AinGUAw1...
#
#    raw_model_response.human_cost_cost iteration.iteration  \
# 0                                0.01                   0
# 1                                0.01                   0
# 2                                0.01                   0
# 3                                0.01                   0
# 4                                0.01                   0
# 5                                0.01                   0
# 6                                0.01                   0
#
#               question_text.human_cost_question_text  \
# 0  \nConsider {{ occupation }} as an occupation. ...
# 1  \nConsider {{ occupation }} as an occupation. ...
# 2  \nConsider {{ occupation }} as an occupation. ...
# 3  \nConsider {{ occupation }} as an occupation. ...
# 4  \nConsider {{ occupation }} as an occupation. ...
# 5  \nConsider {{ occupation }} as an occupation. ...
# 6  \nConsider {{ occupation }} as an occupation. ...
#
#    question_options.human_cost_question_options  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
#
#   question_type.human_cost_question_type  \
# 0                              numerical
# 1                              numerical
# 2                              numerical
# 3                              numerical
# 4                              numerical
# 5                              numerical
# 6                              numerical
#
#                           comment.human_cost_comment  \
# 0  The time it takes to decline excessive risks c...
# 1  This task could take roughly an hour, consider...
# 2  Authorizing reinsurance of a policy when risk ...
# 3  This task involves assessing risk, adjusting p...
# 4  This task involves gathering information, form...
# 5  Evaluating the possibility of losses due to ca...
# 6  This task involves reviewing company records w...
#
#         generated_tokens.human_cost_generated_tokens
# 0  60\n\nThe time it takes to decline excessive r...
# 1  60\n\nThis task could take roughly an hour, co...
# 2  60\n\nAuthorizing reinsurance of a policy when...
# 3  120\n\nThis task involves assessing risk, adju...
# 4  60\n\nThis task involves gathering information...
# 5  480\n\nEvaluating the possibility of losses du...
# 6  120\n\nThis task involves reviewing company re...
#
# [7 rows x 25 columns]
# **** insuranceUnderwriters runtime: 37.70 seconds ****
#
# --------------- Running: insuranceAppraisersForAutoDamage ---------------
# Number of tasks: 7
#    answer.human_cost                   scenario.occupation  \
# 0                 60  Insurance appraisers for auto damage
# 1                 60  Insurance appraisers for auto damage
# 2                120  Insurance appraisers for auto damage
# 3                 60  Insurance appraisers for auto damage
# 4                 30  Insurance appraisers for auto damage
# 5                 60  Insurance appraisers for auto damage
# 6                120  Insurance appraisers for auto damage
#
#                                   scenario.all_tasks  \
# 0  ['Estimate parts and labor to repair damage, u...
# 1  ['Estimate parts and labor to repair damage, u...
# 2  ['Estimate parts and labor to repair damage, u...
# 3  ['Estimate parts and labor to repair damage, u...
# 4  ['Estimate parts and labor to repair damage, u...
# 5  ['Estimate parts and labor to repair damage, u...
# 6  ['Estimate parts and labor to repair damage, u...
#
#                                        scenario.task agent.agent_name  \
# 0  Estimate parts and labor to repair damage, usi...        Agent_124
# 1  Examine damaged vehicle to determine extent of...        Agent_124
# 2  Arrange to have damage appraised by another ap...        Agent_124
# 3     Determine salvage value on total-loss vehicle.        Agent_124
# 4  Prepare insurance forms to indicate repair cos...        Agent_124
# 5  Review repair cost estimates with automobile r...        Agent_124
# 6  Evaluate practicality of repair as opposed to ...        Agent_124
#
#                              agent.agent_instruction  model.frequency_penalty  \
# 0  You are answering questions as if you were a h...                        0
# 1  You are answering questions as if you were a h...                        0
# 2  You are answering questions as if you were a h...                        0
# 3  You are answering questions as if you were a h...                        0
# 4  You are answering questions as if you were a h...                        0
# 5  You are answering questions as if you were a h...                        0
# 6  You are answering questions as if you were a h...                        0
#
#    model.temperature  model.max_tokens  model.logprobs  ...  \
# 0               0.50              1000           False  ...
# 1               0.50              1000           False  ...
# 2               0.50              1000           False  ...
# 3               0.50              1000           False  ...
# 4               0.50              1000           False  ...
# 5               0.50              1000           False  ...
# 6               0.50              1000           False  ...
#
#    prompt.human_cost_system_prompt raw_model_response.human_cost_one_usd_buys  \
# 0                              NaN                                     114.55
# 1                              NaN                                     125.79
# 2                              NaN                                     122.10
# 3                              NaN                                     116.96
# 4                              NaN                                     118.21
# 5                              NaN                                     116.15
# 6                              NaN                                     106.16
#
#     raw_model_response.human_cost_raw_model_response  \
# 0  {'id': 'chatcmpl-AHAU4GtKF5Ab8maBfctdbrwkDZkBu...
# 1  {'id': 'chatcmpl-AHAU7v4oVEQF483Z864xV2PZmDsOq...
# 2  {'id': 'chatcmpl-AHAU7da7Q43gNWgXdtwgcSMT1fX07...
# 3  {'id': 'chatcmpl-AHAU7Kywh1iSCWzsrwqFD73X9owvV...
# 4  {'id': 'chatcmpl-AHAU7b1j1AhSfHM89LPpidtL7F31m...
# 5  {'id': 'chatcmpl-AHAU829s9bAvpBTUvfUTXrn8CH2WO...
# 6  {'id': 'chatcmpl-AHAU7C3GckZsWshk3zWmdEYxeW8mE...
#
#    raw_model_response.human_cost_cost iteration.iteration  \
# 0                                0.01                   0
# 1                                0.01                   0
# 2                                0.01                   0
# 3                                0.01                   0
# 4                                0.01                   0
# 5                                0.01                   0
# 6                                0.01                   0
#
#               question_text.human_cost_question_text  \
# 0  \nConsider {{ occupation }} as an occupation. ...
# 1  \nConsider {{ occupation }} as an occupation. ...
# 2  \nConsider {{ occupation }} as an occupation. ...
# 3  \nConsider {{ occupation }} as an occupation. ...
# 4  \nConsider {{ occupation }} as an occupation. ...
# 5  \nConsider {{ occupation }} as an occupation. ...
# 6  \nConsider {{ occupation }} as an occupation. ...
#
#    question_options.human_cost_question_options  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
#
#   question_type.human_cost_question_type  \
# 0                              numerical
# 1                              numerical
# 2                              numerical
# 3                              numerical
# 4                              numerical
# 5                              numerical
# 6                              numerical
#
#                           comment.human_cost_comment  \
# 0  This task can take about an hour, considering ...
# 1  This task involves a detailed examination of a...
# 2  Arranging to have damage appraised by another ...
# 3  Determining the salvage value of a total-loss ...
# 4  This is an estimate as the time can vary depen...
# 5  This task involves reviewing cost estimates wh...
# 6  This task involves inspecting the vehicle dama...
#
#         generated_tokens.human_cost_generated_tokens
# 0  60\n\nThis task can take about an hour, consid...
# 1  60\n\nThis task involves a detailed examinatio...
# 2  120\n\nArranging to have damage appraised by a...
# 3  60\n\nDetermining the salvage value of a total...
# 4  30\n\nThis is an estimate as the time can vary...
# 5  60\n\nThis task involves reviewing cost estima...
# 6  120\n\nThis task involves inspecting the vehic...
#
# [7 rows x 25 columns]
# **** insuranceAppraisersForAutoDamage runtime: 35.10 seconds ****
#
# --------------- Running: floorSandersAndFinishers ---------------
# Number of tasks: 7
#    answer.human_cost          scenario.occupation  \
# 0                 30  Floor sanders and finishers
# 1                 10  Floor sanders and finishers
# 2                 60  Floor sanders and finishers
# 3                 60  Floor sanders and finishers
# 4                240  Floor sanders and finishers
# 5                240  Floor sanders and finishers
# 6                120  Floor sanders and finishers
#
#                                   scenario.all_tasks  \
# 0  ['Inspect floors for smoothness.', 'Scrape and...
# 1  ['Inspect floors for smoothness.', 'Scrape and...
# 2  ['Inspect floors for smoothness.', 'Scrape and...
# 3  ['Inspect floors for smoothness.', 'Scrape and...
# 4  ['Inspect floors for smoothness.', 'Scrape and...
# 5  ['Inspect floors for smoothness.', 'Scrape and...
# 6  ['Inspect floors for smoothness.', 'Scrape and...
#
#                                        scenario.task agent.agent_name  \
# 0                     Inspect floors for smoothness.        Agent_129
# 1   Attach sandpaper to rollers of sanding machines.        Agent_129
# 2  Remove excess glue from joints, using knives, ...        Agent_129
# 3  Buff and vacuum floors to ensure their cleanli...        Agent_129
# 4  Guide sanding machines over surfaces of floors...        Agent_129
# 5  Apply filler compound and coats of finish to f...        Agent_129
# 6  Scrape and sand floor edges and areas inaccess...        Agent_129
#
#                              agent.agent_instruction  model.frequency_penalty  \
# 0  You are answering questions as if you were a h...                        0
# 1  You are answering questions as if you were a h...                        0
# 2  You are answering questions as if you were a h...                        0
# 3  You are answering questions as if you were a h...                        0
# 4  You are answering questions as if you were a h...                        0
# 5  You are answering questions as if you were a h...                        0
# 6  You are answering questions as if you were a h...                        0
#
#    model.temperature  model.max_tokens  model.logprobs  ...  \
# 0               0.50              1000           False  ...
# 1               0.50              1000           False  ...
# 2               0.50              1000           False  ...
# 3               0.50              1000           False  ...
# 4               0.50              1000           False  ...
# 5               0.50              1000           False  ...
# 6               0.50              1000           False  ...
#
#    prompt.human_cost_system_prompt raw_model_response.human_cost_one_usd_buys  \
# 0                              NaN                                     127.72
# 1                              NaN                                     140.06
# 2                              NaN                                     119.91
# 3                              NaN                                     108.58
# 4                              NaN                                     107.88
# 5                              NaN                                      89.85
# 6                              NaN                                      93.90
#
#     raw_model_response.human_cost_raw_model_response  \
# 0  {'id': 'chatcmpl-AHAUdkP3eybTlCHPOve8LdvYzpesp...
# 1  {'id': 'chatcmpl-AHAUgdGLveA1yMeMEl8tqyqEXVSfF...
# 2  {'id': 'chatcmpl-AHAUgmo9MAt8EmZ01WUxa0LaXxXOM...
# 3  {'id': 'chatcmpl-AHAUg5MLQ8hYLytoG9I9JOraoIQ1C...
# 4  {'id': 'chatcmpl-AHAUgimABpdclK077hdrYvL6qCs8N...
# 5  {'id': 'chatcmpl-AHAUgthABsYQUdbk4Mos82msZeG2i...
# 6  {'id': 'chatcmpl-AHAUgr6sbfed8pA0GXlIlaLJTFd4A...
#
#    raw_model_response.human_cost_cost iteration.iteration  \
# 0                                0.01                   0
# 1                                0.01                   0
# 2                                0.01                   0
# 3                                0.01                   0
# 4                                0.01                   0
# 5                                0.01                   0
# 6                                0.01                   0
#
#               question_text.human_cost_question_text  \
# 0  \nConsider {{ occupation }} as an occupation. ...
# 1  \nConsider {{ occupation }} as an occupation. ...
# 2  \nConsider {{ occupation }} as an occupation. ...
# 3  \nConsider {{ occupation }} as an occupation. ...
# 4  \nConsider {{ occupation }} as an occupation. ...
# 5  \nConsider {{ occupation }} as an occupation. ...
# 6  \nConsider {{ occupation }} as an occupation. ...
#
#    question_options.human_cost_question_options  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
#
#   question_type.human_cost_question_type  \
# 0                              numerical
# 1                              numerical
# 2                              numerical
# 3                              numerical
# 4                              numerical
# 5                              numerical
# 6                              numerical
#
#                           comment.human_cost_comment  \
# 0  The time it takes to inspect a floor for smoot...
# 1  This task is relatively simple and straightfor...
# 2  The duration of this task can vary greatly dep...
# 3  The time it takes to buff and vacuum floors ca...
# 4  The time it takes to sand a floor can vary gre...
# 5  This task involves applying filler compound an...
# 6  The time taken to complete this task can vary ...
#
#         generated_tokens.human_cost_generated_tokens
# 0  30\n\nThe time it takes to inspect a floor for...
# 1  10\n\nThis task is relatively simple and strai...
# 2  60\n\nThe duration of this task can vary great...
# 3  60\n\nThe time it takes to buff and vacuum flo...
# 4  240\n\nThe time it takes to sand a floor can v...
# 5  240\n\nThis task involves applying filler comp...
# 6  120\n\nThe time taken to complete this task ca...
#
# [7 rows x 25 columns]
# **** floorSandersAndFinishers runtime: 32.74 seconds ****
#
# --------------- Running: reinforcingIronAndRebarWorkers ---------------
# Number of tasks: 7
#    answer.human_cost                 scenario.occupation  \
# 0                 20  Reinforcing iron and rebar working
# 1                 30  Reinforcing iron and rebar working
# 2                 60  Reinforcing iron and rebar working
# 3                 60  Reinforcing iron and rebar working
# 4                 60  Reinforcing iron and rebar working
# 5                120  Reinforcing iron and rebar working
# 6                120  Reinforcing iron and rebar working
#
#                                   scenario.all_tasks  \
# 0  ['Position and secure steel bars, rods, cables...
# 1  ['Position and secure steel bars, rods, cables...
# 2  ['Position and secure steel bars, rods, cables...
# 3  ['Position and secure steel bars, rods, cables...
# 4  ['Position and secure steel bars, rods, cables...
# 5  ['Position and secure steel bars, rods, cables...
# 6  ['Position and secure steel bars, rods, cables...
#
#                                        scenario.task agent.agent_name  \
# 0  Cut rods to required lengths, using metal shea...        Agent_134
# 1  Place blocks under rebar to hold the bars off ...        Agent_134
# 2  Bend steel rods with hand tools or rod-bending...        Agent_134
# 3  Space and fasten together rods in forms accord...        Agent_134
# 4  Determine quantities, sizes, shapes, and locat...        Agent_134
# 5  Cut and fit wire mesh or fabric, using hooked ...        Agent_134
# 6  Position and secure steel bars, rods, cables, ...        Agent_134
#
#                              agent.agent_instruction  model.frequency_penalty  \
# 0  You are answering questions as if you were a h...                        0
# 1  You are answering questions as if you were a h...                        0
# 2  You are answering questions as if you were a h...                        0
# 3  You are answering questions as if you were a h...                        0
# 4  You are answering questions as if you were a h...                        0
# 5  You are answering questions as if you were a h...                        0
# 6  You are answering questions as if you were a h...                        0
#
#    model.temperature  model.max_tokens  model.logprobs  ...  \
# 0               0.50              1000           False  ...
# 1               0.50              1000           False  ...
# 2               0.50              1000           False  ...
# 3               0.50              1000           False  ...
# 4               0.50              1000           False  ...
# 5               0.50              1000           False  ...
# 6               0.50              1000           False  ...
#
#    prompt.human_cost_system_prompt raw_model_response.human_cost_one_usd_buys  \
# 0                              NaN                                     117.37
# 1                              NaN                                     113.00
# 2                              NaN                                     113.38
# 3                              NaN                                     111.11
# 4                              NaN                                     105.82
# 5                              NaN                                      99.80
# 6                              NaN                                      87.72
#
#     raw_model_response.human_cost_raw_model_response  \
# 0  {'id': 'chatcmpl-AHAVBt8VJEibIvNPG1XYUU5Kf9rrE...
# 1  {'id': 'chatcmpl-AHAVA35YxkRHL4ZXLVvte1BtjOQ1u...
# 2  {'id': 'chatcmpl-AHAVAMHki9xyTiAm2vbc7ekmwwoJf...
# 3  {'id': 'chatcmpl-AHAVAxNjPng9ZoQ6894O6ozGsGlza...
# 4  {'id': 'chatcmpl-AHAVB6fywJgO3d2xOKUzfOOHzyaJE...
# 5  {'id': 'chatcmpl-AHAVBvTaFklUkXPbjSRvuRQfTE0IZ...
# 6  {'id': 'chatcmpl-AHAVB5cS2dSoR7iy1c7OpxBnjBnWI...
#
#    raw_model_response.human_cost_cost iteration.iteration  \
# 0                                0.01                   0
# 1                                0.01                   0
# 2                                0.01                   0
# 3                                0.01                   0
# 4                                0.01                   0
# 5                                0.01                   0
# 6                                0.01                   0
#
#               question_text.human_cost_question_text  \
# 0  \nConsider {{ occupation }} as an occupation. ...
# 1  \nConsider {{ occupation }} as an occupation. ...
# 2  \nConsider {{ occupation }} as an occupation. ...
# 3  \nConsider {{ occupation }} as an occupation. ...
# 4  \nConsider {{ occupation }} as an occupation. ...
# 5  \nConsider {{ occupation }} as an occupation. ...
# 6  \nConsider {{ occupation }} as an occupation. ...
#
#    question_options.human_cost_question_options  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
#
#   question_type.human_cost_question_type  \
# 0                              numerical
# 1                              numerical
# 2                              numerical
# 3                              numerical
# 4                              numerical
# 5                              numerical
# 6                              numerical
#
#                           comment.human_cost_comment  \
# 0  This estimate is based on the assumption that ...
# 1  The time it takes to place blocks under rebar ...
# 2  The time it takes to bend steel rods and weld ...
# 3  The time it takes to complete this task can va...
# 4  This task requires a person to carefully read ...
# 5  The time it takes to cut and fit wire mesh or ...
# 6  This task involves positioning and securing st...
#
#         generated_tokens.human_cost_generated_tokens
# 0  20\n\nThis estimate is based on the assumption...
# 1  30\n\nThe time it takes to place blocks under ...
# 2  60\n\nThe time it takes to bend steel rods and...
# 3  60\n\nThe time it takes to complete this task ...
# 4  60\n\nThis task requires a person to carefully...
# 5  120\n\nThe time it takes to cut and fit wire m...
# 6  120\n\nThis task involves positioning and secu...
#
# [7 rows x 25 columns]
# **** reinforcingIronAndRebarWorkers runtime: 28.88 seconds ****
#
# --------------- Running: travelAgents ---------------
# Number of tasks: 8
#    answer.human_cost scenario.occupation  \
# 0                 10       travel agents
# 1                 30       travel agents
# 2                 30       travel agents
# 3                 30       travel agents
# 4                240       travel agents
# 5                 15       travel agents
# 6                 10       travel agents
# 7                 60       travel agents
#
#                                   scenario.all_tasks  \
# 0  ['Collect payment for transportation and accom...
# 1  ['Collect payment for transportation and accom...
# 2  ['Collect payment for transportation and accom...
# 3  ['Collect payment for transportation and accom...
# 4  ['Collect payment for transportation and accom...
# 5  ['Collect payment for transportation and accom...
# 6  ['Collect payment for transportation and accom...
# 7  ['Collect payment for transportation and accom...
#
#                                        scenario.task agent.agent_name  \
# 0  Collect payment for transportation and accommo...        Agent_139
# 1  Converse with customer to determine destinatio...        Agent_139
# 2  Compute cost of travel and accommodations, usi...        Agent_139
# 3  Book transportation and hotel reservations, us...        Agent_139
# 4  Plan, describe, arrange, and sell itinerary to...        Agent_139
# 5  Provide customer with brochures and publicatio...        Agent_139
# 6  Print or request transportation carrier ticket...        Agent_139
# 7  Record and maintain information on clients, ve...        Agent_139
#
#                              agent.agent_instruction  model.frequency_penalty  \
# 0  You are answering questions as if you were a h...                        0
# 1  You are answering questions as if you were a h...                        0
# 2  You are answering questions as if you were a h...                        0
# 3  You are answering questions as if you were a h...                        0
# 4  You are answering questions as if you were a h...                        0
# 5  You are answering questions as if you were a h...                        0
# 6  You are answering questions as if you were a h...                        0
# 7  You are answering questions as if you were a h...                        0
#
#    model.temperature  model.max_tokens  model.logprobs  ...  \
# 0               0.50              1000           False  ...
# 1               0.50              1000           False  ...
# 2               0.50              1000           False  ...
# 3               0.50              1000           False  ...
# 4               0.50              1000           False  ...
# 5               0.50              1000           False  ...
# 6               0.50              1000           False  ...
# 7               0.50              1000           False  ...
#
#    prompt.human_cost_system_prompt raw_model_response.human_cost_one_usd_buys  \
# 0                              NaN                                     125.79
# 1                              NaN                                     114.16
# 2                              NaN                                     112.24
# 3                              NaN                                     131.75
# 4                              NaN                                     114.55
# 5                              NaN                                     120.78
# 6                              NaN                                     127.23
# 7                              NaN                                     118.63
#
#     raw_model_response.human_cost_raw_model_response  \
# 0  {'id': 'chatcmpl-AHAMpyvQsdimQuYJ0xPfFtiOFw950...
# 1  {'id': 'chatcmpl-AHAMpK0g9UF2z9NQID3qMMhB5hBcO...
# 2  {'id': 'chatcmpl-AHAMpsP438LYaqi1SXC0YUrRpWoDW...
# 3  {'id': 'chatcmpl-AHAMpxFXNSX8od0ZYmRy0rQ6vUnVb...
# 4  {'id': 'chatcmpl-AHAMp3j8gnyFZcnIDsVUB0fkrlXMJ...
# 5  {'id': 'chatcmpl-AHAMpyppLIoYr76KwMHwho6iaht5M...
# 6  {'id': 'chatcmpl-AHAMpqsbekC1m2eP0TvgbwQhTY8hS...
# 7  {'id': 'chatcmpl-AHAMpWFzUB0BrAw6In8ZEB2GlvYYL...
#
#    raw_model_response.human_cost_cost iteration.iteration  \
# 0                                0.01                   0
# 1                                0.01                   0
# 2                                0.01                   0
# 3                                0.01                   0
# 4                                0.01                   0
# 5                                0.01                   0
# 6                                0.01                   0
# 7                                0.01                   0
#
#               question_text.human_cost_question_text  \
# 0  \nConsider {{ occupation }} as an occupation. ...
# 1  \nConsider {{ occupation }} as an occupation. ...
# 2  \nConsider {{ occupation }} as an occupation. ...
# 3  \nConsider {{ occupation }} as an occupation. ...
# 4  \nConsider {{ occupation }} as an occupation. ...
# 5  \nConsider {{ occupation }} as an occupation. ...
# 6  \nConsider {{ occupation }} as an occupation. ...
# 7  \nConsider {{ occupation }} as an occupation. ...
#
#    question_options.human_cost_question_options  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
#
#   question_type.human_cost_question_type  \
# ...
# 11  {'id': 'chatcmpl-AHAbV0dwsyqdmjic54djEKAiaK3rQ...
#
#     raw_model_response.human_cost_cost iteration.iteration  \
# 0                                 0.01                   0
# 1                                 0.01                   0
# 2                                 0.01                   0
# 3                                 0.01                   0
# 4                                 0.01                   0
# 5                                 0.01                   0
# 6                                 0.01                   0
# 7                                 0.01                   0
# 8                                 0.01                   0
# 9                                 0.01                   0
# 10                                0.01                   0
# 11                                0.01                   0
#
#                question_text.human_cost_question_text  \
# 0   \nConsider {{ occupation }} as an occupation. ...
# 1   \nConsider {{ occupation }} as an occupation. ...
# 2   \nConsider {{ occupation }} as an occupation. ...
# 3   \nConsider {{ occupation }} as an occupation. ...
# 4   \nConsider {{ occupation }} as an occupation. ...
# 5   \nConsider {{ occupation }} as an occupation. ...
# 6   \nConsider {{ occupation }} as an occupation. ...
# 7   \nConsider {{ occupation }} as an occupation. ...
# 8   \nConsider {{ occupation }} as an occupation. ...
# 9   \nConsider {{ occupation }} as an occupation. ...
# 10  \nConsider {{ occupation }} as an occupation. ...
# 11  \nConsider {{ occupation }} as an occupation. ...
#
#     question_options.human_cost_question_options  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
#
#    question_type.human_cost_question_type  \
# 0                               numerical
# 1                               numerical
# 2                               numerical
# 3                               numerical
# 4                               numerical
# 5                               numerical
# 6                               numerical
# 7                               numerical
# 8                               numerical
# 9                               numerical
# 10                              numerical
# 11                              numerical
#
#                            comment.human_cost_comment  \
# 0   This is an estimation. The actual time may var...
# 1   This is an estimation. The actual time it take...
# 2   Recording product, packaging, and order inform...
# 3   This estimation is based on the assumption tha...
# 4   The time it takes to complete this task can va...
# 5   The duration of this task can vary greatly dep...
# 6   This is an estimate as the time can vary depen...
# 7   The time it takes to complete this task can va...
# 8   The time it takes to assemble, line, and pad a...
# 9   The time it takes to load materials and produc...
# 10  This is an estimate, as the exact time would d...
# 11  The time it takes to mark and label containers...
#
#          generated_tokens.human_cost_generated_tokens
# 0   10\n\nThis is an estimation. The actual time m...
# 1   10\n\nThis is an estimation. The actual time i...
# 2   10\n\nRecording product, packaging, and order ...
# 3   10\n\nThis estimation is based on the assumpti...
# 4   5\nThe time it takes to complete this task can...
# 5   60\n\nThe duration of this task can vary great...
# 6   10\n\nThis is an estimate as the time can vary...
# 7   60\n\nThe time it takes to complete this task ...
# 8   15\n\nThe time it takes to assemble, line, and...
# 9   10\n\nThe time it takes to load materials and ...
# 10  30\n\nThis is an estimate, as the exact time w...
# 11  15\n\nThe time it takes to mark and label cont...
#
# [12 rows x 25 columns]
# **** packersAndPackagersHand runtime: 41.54 seconds ****
#
# --------------- Running: hoistAndWinchOperators ---------------
# Number of tasks: 13
#     answer.human_cost        scenario.occupation  \
# 0                5.00  Hoist and winch operators
# 1               60.00  Hoist and winch operators
# 2               10.00  Hoist and winch operators
# 3                5.00  Hoist and winch operators
# 4                 NaN  Hoist and winch operators
# 5               10.00  Hoist and winch operators
# 6               20.00  Hoist and winch operators
# 7               10.00  Hoist and winch operators
# 8                5.00  Hoist and winch operators
# 9               30.00  Hoist and winch operators
# 10              60.00  Hoist and winch operators
# 11             120.00  Hoist and winch operators
# 12               5.00  Hoist and winch operators
#
#                                    scenario.all_tasks  \
# 0   ['Move levers, pedals, and throttles to stop, ...
# 1   ['Move levers, pedals, and throttles to stop, ...
# 2   ['Move levers, pedals, and throttles to stop, ...
# 3   ['Move levers, pedals, and throttles to stop, ...
# 4   ['Move levers, pedals, and throttles to stop, ...
# 5   ['Move levers, pedals, and throttles to stop, ...
# 6   ['Move levers, pedals, and throttles to stop, ...
# 7   ['Move levers, pedals, and throttles to stop, ...
# 8   ['Move levers, pedals, and throttles to stop, ...
# 9   ['Move levers, pedals, and throttles to stop, ...
# 10  ['Move levers, pedals, and throttles to stop, ...
# 11  ['Move levers, pedals, and throttles to stop, ...
# 12  ['Move levers, pedals, and throttles to stop, ...
#
#                                         scenario.task agent.agent_name  \
# 0   Apply hand or foot brakes and move levers to l...        Agent_203
# 1   Oil winch drums so that cables will wind smoot...        Agent_203
# 2   Attach, fasten, and disconnect cables or lines...        Agent_203
# 3   Start engines of hoists or winches and use lev...        Agent_203
# 4   Operate compressed air, diesel, electric, gaso...        Agent_203
# 5   Select loads or materials according to weight ...        Agent_203
# 6   Tend auxiliary equipment, such as jacks, sling...        Agent_203
# 7   Climb ladders to position and set up vehicle-m...        Agent_203
# 8   Observe equipment gauges and indicators and ha...        Agent_203
# 9   Signal and assist other workers loading or unl...        Agent_203
# 10  Move or reposition hoists, winches, loads and ...        Agent_203
# 11  Repair, maintain, and adjust equipment, using ...        Agent_203
# 12  Move levers, pedals, and throttles to stop, st...        Agent_203
#
#                               agent.agent_instruction  \
# 0   You are answering questions as if you were a h...
# 1   You are answering questions as if you were a h...
# 2   You are answering questions as if you were a h...
# 3   You are answering questions as if you were a h...
# 4   You are answering questions as if you were a h...
# 5   You are answering questions as if you were a h...
# 6   You are answering questions as if you were a h...
# 7   You are answering questions as if you were a h...
# 8   You are answering questions as if you were a h...
# 9   You are answering questions as if you were a h...
# 10  You are answering questions as if you were a h...
# 11  You are answering questions as if you were a h...
# 12  You are answering questions as if you were a h...
#
#     model.frequency_penalty  model.temperature  model.max_tokens  \
# 0                         0               0.50              1000
# 1                         0               0.50              1000
# 2                         0               0.50              1000
# 3                         0               0.50              1000
# 4                         0               0.50              1000
# 5                         0               0.50              1000
# 6                         0               0.50              1000
# 7                         0               0.50              1000
# 8                         0               0.50              1000
# 9                         0               0.50              1000
# 10                        0               0.50              1000
# 11                        0               0.50              1000
# 12                        0               0.50              1000
#
#     model.logprobs  ...  prompt.human_cost_system_prompt  \
# 0            False  ...                              NaN
# 1            False  ...                              NaN
# 2            False  ...                              NaN
# 3            False  ...                              NaN
# 4            False  ...                              NaN
# 5            False  ...                              NaN
# 6            False  ...                              NaN
# 7            False  ...                              NaN
# 8            False  ...                              NaN
# 9            False  ...                              NaN
# 10           False  ...                              NaN
# 11           False  ...                              NaN
# 12           False  ...                              NaN
#
#    raw_model_response.human_cost_one_usd_buys  \
# 0                                      129.70
# 1                                      129.70
# 2                                      121.66
# 3                                      122.55
# 4                                      109.29
# 5                                      123.00
# 6                                      110.74
# 7                                      116.96
# 8                                      103.52
# 9                                      133.87
# 10                                     110.38
# 11                                      91.58
# 12                                     110.01
#
#      raw_model_response.human_cost_raw_model_response  \
# 0   {'id': 'chatcmpl-AHAcBuyTr5eofz0yunVxFl8Bh7Aje...
# 1   {'id': 'chatcmpl-AHAcBrPklx4FX72vAiV4Gz3D6Dlqr...
# 2   {'id': 'chatcmpl-AHAcBv25rIM7zwE1DTJBzD8ohdGIA...
# 3   {'id': 'chatcmpl-AHAcBG0voUpoHcnnbolryqv6AWGFC...
# 4   {'id': 'chatcmpl-AHAcBO2LxhaMWtvPPEkXzEk21qKW9...
# 5   {'id': 'chatcmpl-AHAcBQtb7BtsqqkIvX2B3e52pOqqI...
# 6   {'id': 'chatcmpl-AHAcBGbeZtjKAdHNwSy87hjCcpNRa...
# 7   {'id': 'chatcmpl-AHAcBUSPvCIHNzaH71UVqAiK3yZqT...
# 8   {'id': 'chatcmpl-AHAcBmRcq59boyO4fxbmdtoJnBqGU...
# 9   {'id': 'chatcmpl-AHAcBUtKKBfKEWDtxPV7CoeSHeXcJ...
# 10  {'id': 'chatcmpl-AHAcBwkeZnLCIllNDrzX7IxMSkPIO...
# 11  {'id': 'chatcmpl-AHAcBKiDiR6K4ou6oEVdNCOrDkW2U...
# 12  {'id': 'chatcmpl-AHAcBnoWjIgCe2i7i5ImGkDqWDCLe...
#
#     raw_model_response.human_cost_cost iteration.iteration  \
# 0                                 0.01                   0
# 1                                 0.01                   0
# 2                                 0.01                   0
# 3                                 0.01                   0
# 4                                 0.01                   0
# 5                                 0.01                   0
# 6                                 0.01                   0
# 7                                 0.01                   0
# 8                                 0.01                   0
# 9                                 0.01                   0
# 10                                0.01                   0
# 11                                0.01                   0
# 12                                0.01                   0
#
#                question_text.human_cost_question_text  \
# 0   \nConsider {{ occupation }} as an occupation. ...
# 1   \nConsider {{ occupation }} as an occupation. ...
# 2   \nConsider {{ occupation }} as an occupation. ...
# 3   \nConsider {{ occupation }} as an occupation. ...
# 4   \nConsider {{ occupation }} as an occupation. ...
# 5   \nConsider {{ occupation }} as an occupation. ...
# 6   \nConsider {{ occupation }} as an occupation. ...
# 7   \nConsider {{ occupation }} as an occupation. ...
# 8   \nConsider {{ occupation }} as an occupation. ...
# 9   \nConsider {{ occupation }} as an occupation. ...
# 10  \nConsider {{ occupation }} as an occupation. ...
# 11  \nConsider {{ occupation }} as an occupation. ...
# 12  \nConsider {{ occupation }} as an occupation. ...
#
#     question_options.human_cost_question_options  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
#
#    question_type.human_cost_question_type  \
# 0                               numerical
# 1                               numerical
# 2                               numerical
# 3                               numerical
# 4                               numerical
# 5                               numerical
# 6                               numerical
# 7                               numerical
# 8                               numerical
# 9                               numerical
# 10                              numerical
# 11                              numerical
# 12                              numerical
#
#                            comment.human_cost_comment  \
# 0   The task of applying hand or foot brakes and m...
# 1   This is an estimate based on the size of the w...
# 2   This task could take around 10 minutes. This t...
# 3   Starting the engines of hoists or winches and ...
# 4                         The response was not valid.
# 5   This task requires the operator to assess the ...
# 6   This task involves tending to several pieces o...
# 7   This task would typically take about 10 minute...
# 8   This task is a constant part of the hoist and ...
# 9   The duration can vary greatly depending on the...
# 10  This task would typically take around an hour....
# 11  The time it takes to repair, maintain, and adj...
# 12  This task involves immediate response to signa...
#
#          generated_tokens.human_cost_generated_tokens
# 0   5\nThe task of applying hand or foot brakes an...
# 1   60\n\nThis is an estimate based on the size of...
# 2   10\n\nThis task could take around 10 minutes. ...
# 3   5\nStarting the engines of hoists or winches a...
# 4   None\nThe time it takes to complete this task ...
# 5   10\n\nThis task requires the operator to asses...
# 6   20\n\nThis task involves tending to several pi...
# 7   10\n\nThis task would typically take about 10 ...
# 8   5\nThis task is a constant part of the hoist a...
# 9   30\n\nThe duration can vary greatly depending ...
# 10  60\n\nThis task would typically take around an...
# 11  120\n\nThe time it takes to repair, maintain, ...
# 12  5\nThis task involves immediate response to si...
#
# [13 rows x 25 columns]
# **** hoistAndWinchOperators runtime: 34.61 seconds ****
#
# --------------- Running: forgingMachineSettersOperatorsAndTenders ---------------
# Number of tasks: 13
