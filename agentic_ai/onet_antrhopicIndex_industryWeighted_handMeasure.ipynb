# %% [markdown]
# #### By: Peyman Shahidi
# #### Created: Oct 29, 2025
# #### Last Edit: Nov 3, 2025
#
# <br>

# %%
#Python
import getpass
import numpy as np
import pandas as pd
from collections import defaultdict
import itertools
import random 

## formatting number to appear comma separated and with two digits after decimal: e.g, 1000 shown as 1,000.00
pd.set_option('float_format', "{:,.2f}".format)

import matplotlib.pyplot as plt
#%matplotlib inline
#from matplotlib.legend import Legend

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 200)

# %%
#Python
import getpass
import numpy as np
import pandas as pd
from collections import defaultdict
import itertools
import random 

## formatting number to appear comma separated and with two digits after decimal: e.g, 1000 shown as 1,000.00
pd.set_option('float_format', "{:,.2f}".format)

import matplotlib.pyplot as plt
#%matplotlib inline
#from matplotlib.legend import Legend

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 200)

main_folder_path = ".."
input_data_path = f"{main_folder_path}/data"
# Modify the output path accordingly
output_data_path = f'{input_data_path}/computed_objects/BLS_ONET_matchedEmpShares'
output_plot_path = f"{main_folder_path}/writeup/plots/anthropic_AI_index/BLS_ONET_matchedEmpShares"

# Toggle: if True, randomly reassign occ_totalEmpShare weights in the merged master_df
# during the merge_industry_employment_shares step. Set to False for default behavior.
randomize_occ_weights = True

# %%
import os
for path in [output_data_path, output_plot_path]:
    if not os.path.exists(path):
        os.makedirs(path)

# %% [markdown]
# ## Functions

# %%
def create_occupation_analysis(df, onet_occupation_code_var, onet_occupation_title_var):
    # Create occupation-level analysis for scatter plots
    # Group by occupation and calculate label fractions and task counts
    occupation_stats = []

    for (soc_code, occ_title), group in df.groupby([onet_occupation_code_var, onet_occupation_title_var]):
        num_tasks = group['Task ID'].nunique()
        # num_occupations = group[onet_occupation_code_var].nunique()
        total_tasks = len(group)
        
        manual_fraction = (group['label'] == 'Manual').sum() / total_tasks
        augmentation_fraction = (group['label'] == 'Augmentation').sum() / total_tasks  
        automation_fraction = (group['label'] == 'Automation').sum() / total_tasks
        ai_fraction = augmentation_fraction + automation_fraction
        gpt4_E0_fraction = (group['gpt4_exposure'] == 'E0').sum() / total_tasks
        gpt4_E1_fraction = (group['gpt4_exposure'] == 'E1').sum() / total_tasks
        gpt4_E2_fraction = (group['gpt4_exposure'] == 'E2').sum() / total_tasks
        gpt4_aiExposure_fraction = gpt4_E1_fraction + gpt4_E2_fraction
        human_E0_fraction = (group['human_labels'] == 'E0').sum() / total_tasks
        human_E1_fraction = (group['human_labels'] == 'E1').sum() / total_tasks
        human_E2_fraction = (group['human_labels'] == 'E2').sum() / total_tasks
        human_aiExposure_fraction = human_E1_fraction + human_E2_fraction

        
        occupation_stats.append({
            f'{onet_occupation_code_var}': soc_code,
            f'{onet_occupation_title_var}': occ_title,
            'num_tasks': num_tasks,
            # 'num_occupations': num_occupations,
            'manual_fraction': manual_fraction,
            'ai_fraction': ai_fraction,
            'augmentation_fraction': augmentation_fraction,
            'automation_fraction': automation_fraction,
            'gpt4_E0_fraction': gpt4_E0_fraction,
            'gpt4_E1_fraction': gpt4_E1_fraction,
            'gpt4_E2_fraction': gpt4_E2_fraction,
            'gpt4_aiExposure_fraction': gpt4_aiExposure_fraction,
            'human_E0_fraction': human_E0_fraction,
            'human_E1_fraction': human_E1_fraction,
            'human_E2_fraction': human_E2_fraction,
            'human_aiExposure_fraction': human_aiExposure_fraction
        })

    occupation_analysis = pd.DataFrame(occupation_stats)

    return occupation_analysis

# %% [markdown]
# #### Main Code

# %%
# Read the merged data
merged_data = pd.read_csv(f"{input_data_path}/computed_objects/ONET_Eloundou_Anthropic_GPT/ONET_Eloundou_Anthropic_GPT.csv")

# %%
# # Drop the supplemental tasks
# merged_data = merged_data[merged_data['Task Type'] != 'Supplemental'].reset_index(drop=True)

# # Drop rows whose Occupation Title includes 'Teachers, Postsecondary'
# merged_data = merged_data[~merged_data['Occupation Title'].str.contains('Teachers, Postsecondary')].reset_index(drop=True)

# %%
# Define levels and variables
bls_sector_levels = ['sector']#, '3-digit', '4-digit', '5-digit', '6-digit']

onet_levels = ['major', 'minor', 'broad', 'detailed']
onet_occupation_code_vars = ['Major_Group_Code', 'Minor_Group_Code', 'Broad_Occupation_Code', 'Detailed_Occupation_Code']
onet_occupation_title_vars = ['Major_Group_Title', 'Minor_Group_Title', 'Broad_Occupation_Title', 'Detailed_Occupation_Title']

weight_cols = ['occ_totalEmpShare',         # Weight each occupation by occupation's share of total employment (ignoring sector shares)
               'sectorEmpShare',            # Weight each occupation by its sector's share of total employment
               'occ_sectorEmpShare']        # Weight each occupation by its share of employment within its sector and weight sectors equally  

dependent_var_list = ['ai_fraction', 'human_E1_fraction']#, 'human_aiExposure_fraction']#, 'gpt4_E1_fraction']

# %%
my_sector = '3-digit'  # Choose from bls_sector_levels
my_onet_level = 'detailed'  # Choose from onet_levels
onet_occupation_code_var = 'Detailed_Occupation_Code'
onet_occupation_title_var = 'Detailed_Occupation_Title'
dependent_var = 'ai_fraction'

# Create occupation-level
occupation_analysis = create_occupation_analysis(merged_data, onet_occupation_code_var, onet_occupation_title_var)

# Add BLS employment shares for all NAICS sectors and create a master dataset
bls_sector_shares = pd.read_csv(f'{input_data_path}/computed_objects/BLS_ONET_empShares/BLS{my_sector}_ONET{my_onet_level}_empShares.csv')

master_df = occupation_analysis.copy()

# 1) sectorEmpShare
sector_weights_df = bls_sector_shares[['NAICS', 'NAICS_TITLE', 'TOT_EMP']].groupby(['NAICS', 'NAICS_TITLE']).sum('TOT_EMP')

# Convert to % and change variable name
sector_weights_df['TOT_EMP'] = sector_weights_df['TOT_EMP'] / sector_weights_df['TOT_EMP'].sum()
sector_weights_df = sector_weights_df.rename(columns={'TOT_EMP': 'sectorEmpShare'})

# Merge back sector weights to bls dataset to get sector-by-sector occupation data with sector weights
bls_sector_weights_df = bls_sector_shares[['NAICS', 'NAICS_TITLE', 'OCC_CODE', 'OCC_TITLE']].merge(sector_weights_df, on='NAICS', how='left')

# Add weight column to master_df
master_df = master_df.merge(bls_sector_weights_df[['NAICS', 'NAICS_TITLE', 'OCC_CODE', 'sectorEmpShare']], left_on=onet_occupation_code_var, right_on=['OCC_CODE'], how='left')
master_df = master_df.drop(columns=['OCC_CODE'])

# 2) occ_sectorEmpShare
within_sector_weights_df = bls_sector_shares[['NAICS', 'NAICS_TITLE', 'OCC_CODE', 'OCC_TITLE', 'TOT_EMP']].copy()
within_sector_weights_df['occ_sectorEmpShare'] = within_sector_weights_df['TOT_EMP'] / within_sector_weights_df.groupby(['NAICS', 'NAICS_TITLE'])['TOT_EMP'].transform('sum')

# Add weight column to master_df
master_df = master_df.merge(within_sector_weights_df[['NAICS', 'OCC_CODE', 'occ_sectorEmpShare']], left_on=['NAICS', onet_occupation_code_var], right_on=['NAICS', 'OCC_CODE'], how='left')
master_df = master_df.drop(columns=['OCC_CODE'])

# Drop rows with null NAICS -- i.e., unmatched occupations in both procedures
master_df = master_df[~master_df.NAICS.isnull()]

# Save master dataframe to CSV
master_df = master_df.sort_values(by=['NAICS', 'occ_sectorEmpShare'], ascending=[True, False]).reset_index(drop=True)
out_dir = f"{output_data_path}"#/BLS{my_sector}_ONET{my_onet_level}/{dependent_var}/"
os.makedirs(out_dir, exist_ok=True)
master_out = f"{out_dir}/BLS{my_sector}_ONET{my_onet_level}.csv"
master_df.to_csv(master_out, index=False)

# %%
my_sector = '3-digit'  # Choose from bls_sector_levels
my_onet_level = 'detailed'  # Choose from onet_levels
onet_occupation_code_var = 'Detailed_Occupation_Code'
onet_occupation_title_var = 'Detailed_Occupation_Title'
dependent_var = 'ai_fraction'

# Create occupation-level
occupation_analysis = create_occupation_analysis(merged_data, onet_occupation_code_var, onet_occupation_title_var)

# Add BLS employment shares for all NAICS sectors and create a master dataset
bls_sector_shares = pd.read_csv(f'{input_data_path}/computed_objects/BLS_ONET_empShares/BLS{my_sector}_ONET{my_onet_level}_empShares.csv')

master_df = occupation_analysis.copy()

# 1) sectorEmpShare
sector_weights_df = bls_sector_shares[['NAICS', 'NAICS_TITLE', 'TOT_EMP']].groupby(['NAICS', 'NAICS_TITLE']).sum('TOT_EMP')

# Convert to % and change variable name
sector_weights_df['TOT_EMP'] = sector_weights_df['TOT_EMP'] / sector_weights_df['TOT_EMP'].sum()
sector_weights_df = sector_weights_df.rename(columns={'TOT_EMP': 'sectorEmpShare'})

# Merge back sector weights to bls dataset to get sector-by-sector occupation data with sector weights
bls_sector_weights_df = bls_sector_shares[['NAICS', 'NAICS_TITLE', 'OCC_CODE', 'OCC_TITLE']].merge(sector_weights_df, on='NAICS', how='left')

# Add weight column to master_df
master_df = master_df.merge(bls_sector_weights_df[['NAICS', 'NAICS_TITLE', 'OCC_CODE', 'sectorEmpShare']], left_on=onet_occupation_code_var, right_on=['OCC_CODE'], how='left')
master_df = master_df.drop(columns=['OCC_CODE'])

# 2) occ_sectorEmpShare
within_sector_weights_df = bls_sector_shares[['NAICS', 'NAICS_TITLE', 'OCC_CODE', 'OCC_TITLE', 'TOT_EMP']].copy()

within_sector_weights_df[['NAICS', 'NAICS_TITLE', 'TOT_EMP']].groupby(['NAICS', 'NAICS_TITLE']).sum()
# Out:
#                                                             TOT_EMP
# NAICS  NAICS_TITLE
# 113000 Forestry and Logging                                   43350
# 115000 Support Activities for Agriculture and Forestry       365930
# 211000 Oil and Gas Extraction                                106690
# 212000 Mining (except Oil and Gas)                           181550
# 213000 Support Activities for Mining                         274260
# 221000 Utilities                                             562210
# 236000 Construction of Buildings                            1775870
# 237000 Heavy and Civil Engineering Construction             1102640
# 238000 Specialty Trade Contractors                          5026470
# 311000 Food Manufacturing                                   1714470
# 312000 Beverage and Tobacco Product Manufacturing            326680
# 313000 Textile Mills                                          86070
# 314000 Textile Product Mills                                  94600
# 315000 Apparel Manufacturing                                  86900
# 316000 Leather and Allied Product Manufacturing               23800
# 321000 Wood Product Manufacturing                            421730
# 322000 Paper Manufacturing                                   359960
# 323000 Printing and Related Support Activities               377120
# 324000 Petroleum and Coal Products Manufacturing             105640
# 325000 Chemical Manufacturing                                883010
# 326000 Plastics and Rubber Products Manufacturing            738240
# 327000 Nonmetallic Mineral Product Manufacturing             830140
# 331000 Primary Metal Manufacturing                           362860
# 332000 Fabricated Metal Product Manufacturing               1437550
# 333000 Machinery Manufacturing                              1119820
# 334000 Computer and Electronic Product Manufacturing        1089150
# 335000 Electrical Equipment, Appliance, and Component ...    407350
# 336000 Transportation Equipment Manufacturing               1732740
# 337000 Furniture and Related Product Manufacturing           363530
# 339000 Miscellaneous Manufacturing                           628090
# 423000 Merchant Wholesalers, Durable Goods                  3330460
# 424000 Merchant Wholesalers, Nondurable Goods               2166380
# 425000 Wholesale Trade Agents and Brokers                    479350
# 441000 Motor Vehicle and Parts Dealers                      1933300
# 444000 Building Material and Garden Equipment and Supp...   1429900
# 445000 Food and Beverage Retailers                          3204320
# 449000 Furniture, Home Furnishings, Electronics, and A...    849080
# 455000 General Merchandise Retailers                        5089380
# 456000 Health and Personal Care Retailers                   1102000
# 457000 Gasoline Stations and Fuel Dealers                   1033770
# 458000 Clothing, Clothing Accessories, Shoe, and Jewel...   1155630
# 459000 Sporting Goods, Hobby, Musical Instrument, Book...   1537540
# 481000 Air Transportation                                    534490
# 482000 Rail Transportation                                   178270
# 483000 Water Transportation                                   63940
# 484000 Truck Transportation                                 3144540
# 485000 Transit and Ground Passenger Transportation           431080
# 486000 Pipeline Transportation                                51080
# 487000 Scenic and Sightseeing Transportation                  29020
# 488000 Support Activities for Transportation                 800740
# 491000 Postal Service (Federal Government)                   632270
# 492000 Couriers and Messengers                              1102010
# 493000 Warehousing and Storage                              1908610
# 512000 Motion Picture and Sound Recording Industries         420230
# 513000 Publishing Industries                                 942520
# 516000 Broadcasting and Content Providers                    350970
# 517000 Telecommunications                                   1290860
# 518000 Computing Infrastructure Providers, Data Proces...    475440
# 519000 Web Search Portals, Libraries, Archives, and Ot...    180420
# 521000 Monetary Authorities-Central Bank                      20320
# 522000 Credit Intermediation and Related Activities         2586220
# 523000 Securities, Commodity Contracts, and Other Fina...   2117860
# 524000 Insurance Carriers and Related Activities            2541780
# 525000 Funds, Trusts, and Other Financial Vehicles            28080
# 531000 Real Estate                                          3522240
# 532000 Rental and Leasing Services                           544980
# 533000 Lessors of Nonfinancial Intangible Assets (exce...     20260
# 541000 Professional, Scientific, and Technical Services    10724550
# 551000 Management of Companies and Enterprises              2755380
# 561000 Administrative and Support Services                  8720870
# 562000 Waste Management and Remediation Services             485880
# 611000 Educational Services                                53219560
# 621000 Ambulatory Health Care Services                      8319520
# 622000 Hospitals                                           24374840
# 623000 Nursing and Residential Care Facilities              3058060
# 624000 Social Assistance                                    4410810
# 711000 Performing Arts, Spectator Sports, and Related ...    534060
# 712000 Museums, Historical Sites, and Similar Institut...    167260
# 713000 Amusement, Gambling, and Recreation Industries       1803690
# 721000 Accommodation                                        1922190
# 722000 Food Services and Drinking Places                   11992830
# 811000 Repair and Maintenance                               1418870
# 812000 Personal and Laundry Services                        1517890
# 813000 Religious, Grantmaking, Civic, Professional, an...   1357490
# 999000 Federal, State, and Local Government, excluding...   9755390

# %%
bls_sector_shares[['NAICS', 'NAICS_TITLE']].drop_duplicates()
x = bls_sector_shares[bls_sector_shares[['NAICS', 'NAICS_TITLE']].NAICS_TITLE == 'Hospitals'][['OCC_TITLE', 'occ_sectorEmpShare']]

x.occ_sectorEmpShare.sum()
# Out:
# np.float64(3.9095261543001416)

# %%
# 1) Ensure numeric types and fill NaN with 0 (safe for summing)
master_df['num_tasks'] = pd.to_numeric(master_df.get('num_tasks', 0), errors='coerce').fillna(0)
master_df['occ_sectorEmpShare'] = pd.to_numeric(master_df.get('occ_sectorEmpShare', 0), errors='coerce').fillna(0)

# 2) Per-row weighted value (keep this if useful downstream)
master_df['num_task_weighted'] = master_df['num_tasks'] * master_df['occ_sectorEmpShare']
master_df['ai_fraction_weighted'] = master_df['ai_fraction'] * master_df['occ_sectorEmpShare']
master_df['human_E1_fraction_weighted'] = master_df['human_E1_fraction'] * master_df['occ_sectorEmpShare']

# 3) Compute group sums within NAICS / NAICS_TITLE for both columns
sector_sums = (master_df.groupby(['NAICS', 'NAICS_TITLE'], dropna=True)
               .agg(occ_sectorEmpShare_sum=('occ_sectorEmpShare', 'sum'),
                    num_task_weighted_sum=('num_task_weighted', 'sum'),
                    ai_fraction_weighted_sum=('ai_fraction_weighted', 'sum'),
                    human_E1_fraction_weighted_sum=('human_E1_fraction_weighted', 'sum'))
               .reset_index())

# Calculate Hand-off measure: num_task_weighted_sum / occ_sectorEmpShare_sum (Cause occ_sectorEmpShare_sum might be < 1)
sector_sums['num_task_weighted'] = sector_sums['num_task_weighted_sum'] / sector_sums['occ_sectorEmpShare_sum']
sector_sums['ai_fraction_weighted'] = sector_sums['ai_fraction_weighted_sum'] / sector_sums['occ_sectorEmpShare_sum']
sector_sums['human_E1_fraction_weighted'] = sector_sums['human_E1_fraction_weighted_sum'] / sector_sums['occ_sectorEmpShare_sum']


# Optional: sort sectors by total weighted tasks (helpful for inspection)
sector_sums = sector_sums.sort_values(by=['num_task_weighted'], ascending=False).reset_index(drop=True)

# 4) Merge the group sums back into master_df so each row has the sector totals
master_df = master_df.merge(sector_sums, on=['NAICS', 'NAICS_TITLE'], how='left')

# 5) Quick checks: display the sector-level sums and the head of master_df
sector_sums
# master_df.head()
# Out:
#         NAICS                                        NAICS_TITLE  \
# 0  622,000.00                                          Hospitals
# 1  334,000.00      Computer and Electronic Product Manufacturing
# 2  516,000.00                 Broadcasting and Content Providers
# 3  999,000.00  Federal, State, and Local Government, excludin...
# 4  519,000.00  Web Search Portals, Libraries, Archives, and O...
# 5  336,000.00             Transportation Equipment Manufacturing
# 6  512,000.00      Motion Picture and Sound Recording Industries
# 7  551,000.00            Management of Companies and Enterprises
# 8  621,000.00                    Ambulatory Health Care Services
# 9  623,000.00            Nursing and Residential Care Facilities
# 10 333,000.00                            Machinery Manufacturing
# 11 518,000.00  Computing Infrastructure Providers, Data Proce...
# 12 335,000.00  Electrical Equipment, Appliance, and Component...
# 13 541,000.00   Professional, Scientific, and Technical Services
# 14 327,000.00          Nonmetallic Mineral Product Manufacturing
# 15 611,000.00                               Educational Services
# 16 488,000.00              Support Activities for Transportation
# 17 339,000.00                        Miscellaneous Manufacturing
# 18 517,000.00                                 Telecommunications
# 19 325,000.00                             Chemical Manufacturing
# 20 624,000.00                                  Social Assistance
# 21 324,000.00          Petroleum and Coal Products Manufacturing
# 22 513,000.00                              Publishing Industries
# 23 221,000.00                                          Utilities
# 24 525,000.00        Funds, Trusts, and Other Financial Vehicles
# 25 211,000.00                             Oil and Gas Extraction
# 26 533,000.00  Lessors of Nonfinancial Intangible Assets (exc...
# 27 521,000.00                  Monetary Authorities-Central Bank
# 28 486,000.00                            Pipeline Transportation
# 29 484,000.00                               Truck Transportation
# 30 722,000.00                  Food Services and Drinking Places
# 31 332,000.00             Fabricated Metal Product Manufacturing
# 32 236,000.00                          Construction of Buildings
# 33 326,000.00         Plastics and Rubber Products Manufacturing
# 34 813,000.00  Religious, Grantmaking, Civic, Professional, a...
# 35 523,000.00  Securities, Commodity Contracts, and Other Fin...
# 36 237,000.00           Heavy and Civil Engineering Construction
# 37 711,000.00  Performing Arts, Spectator Sports, and Related...
# 38 524,000.00          Insurance Carriers and Related Activities
# 39 483,000.00                               Water Transportation
# 40 493,000.00                            Warehousing and Storage
# 41 457,000.00                 Gasoline Stations and Fuel Dealers
# 42 531,000.00                                        Real Estate
# 43 522,000.00       Credit Intermediation and Related Activities
# 44 331,000.00                        Primary Metal Manufacturing
# 45 238,000.00                        Specialty Trade Contractors
# 46 481,000.00                                 Air Transportation
# 47 423,000.00                Merchant Wholesalers, Durable Goods
# 48 561,000.00                Administrative and Support Services
# 49 445,000.00                        Food and Beverage Retailers
# 50 425,000.00                 Wholesale Trade Agents and Brokers
# 51 424,000.00             Merchant Wholesalers, Nondurable Goods
# 52 492,000.00                            Couriers and Messengers
# 53 321,000.00                         Wood Product Manufacturing
# 54 712,000.00  Museums, Historical Sites, and Similar Institu...
# 55 115,000.00    Support Activities for Agriculture and Forestry
# 56 455,000.00                      General Merchandise Retailers
# 57 562,000.00          Waste Management and Remediation Services
# 58 313,000.00                                      Textile Mills
# 59 337,000.00        Furniture and Related Product Manufacturing
# 60 444,000.00  Building Material and Garden Equipment and Sup...
# 61 314,000.00                              Textile Product Mills
# 62 315,000.00                              Apparel Manufacturing
# 63 212,000.00                        Mining (except Oil and Gas)
# 64 213,000.00                      Support Activities for Mining
# 65 322,000.00                                Paper Manufacturing
# 66 312,000.00         Beverage and Tobacco Product Manufacturing
# 67 316,000.00           Leather and Allied Product Manufacturing
# 68 323,000.00            Printing and Related Support Activities
# 69 459,000.00  Sporting Goods, Hobby, Musical Instrument, Boo...
# 70 458,000.00  Clothing, Clothing Accessories, Shoe, and Jewe...
# 71 811,000.00                             Repair and Maintenance
# 72 721,000.00                                      Accommodation
# 73 311,000.00                                 Food Manufacturing
# 74 449,000.00  Furniture, Home Furnishings, Electronics, and ...
# 75 482,000.00                                Rail Transportation
# 76 532,000.00                        Rental and Leasing Services
# 77 456,000.00                 Health and Personal Care Retailers
# 78 487,000.00              Scenic and Sightseeing Transportation
# 79 713,000.00     Amusement, Gambling, and Recreation Industries
# 80 441,000.00                    Motor Vehicle and Parts Dealers
# 81 812,000.00                      Personal and Laundry Services
# 82 491,000.00                Postal Service (Federal Government)
# 83 485,000.00        Transit and Ground Passenger Transportation
# 84 113,000.00                               Forestry and Logging
#
#     occ_sectorEmpShare_sum  num_task_weighted_sum  ai_fraction_weighted_sum  \
# 0                     3.72                 229.26                      0.41
# 1                     0.73                  28.43                      0.11
# 2                     0.87                  32.81                      0.16
# 3                     0.92                  33.09                      0.11
# 4                     0.66                  23.20                      0.15
# 5                     0.71                  24.65                      0.05
# 6                     0.91                  31.42                      0.14
# 7                     0.87                  30.06                      0.17
# 8                     0.81                  27.84                      0.11
# 9                     0.75                  25.90                      0.06
# 10                    0.80                  26.72                      0.07
# 11                    0.74                  24.56                      0.19
# 12                    0.66                  21.34                      0.07
# 13                    0.86                  27.06                      0.18
# 14                    1.84                  58.11                      0.10
# 15                    3.19                 100.31                      0.87
# 16                    0.89                  27.78                      0.07
# 17                    0.78                  24.34                      0.08
# 18                    1.65                  51.57                      0.26
# 19                    0.94                  28.99                      0.09
# 20                    0.47                  14.36                      0.07
# 21                    0.94                  28.86                      0.08
# 22                    0.74                  22.59                      0.18
# 23                    0.95                  28.65                      0.10
# 24                    0.85                  25.79                      0.18
# 25                    0.95                  28.73                      0.09
# 26                    0.86                  25.94                      0.18
# 27                    0.80                  23.81                      0.19
# 28                    0.95                  28.08                      0.08
# 29                    1.92                  56.25                      0.11
# 30                    0.99                  28.99                      0.07
# 31                    0.88                  25.58                      0.05
# 32                    0.92                  26.54                      0.08
# 33                    0.86                  24.72                      0.04
# 34                    0.91                  26.07                      0.16
# 35                    1.74                  49.78                      0.50
# 36                    0.96                  27.49                      0.05
# 37                    0.92                  25.47                      0.14
# 38                    0.95                  26.11                      0.18
# 39                    0.94                  25.94                      0.07
# 40                    0.96                  26.17                      0.04
# 41                    0.99                  27.20                      0.11
# 42                    1.92                  52.23                      0.33
# 43                    0.92                  25.07                      0.20
# 44                    0.95                  25.73                      0.04
# 45                    0.96                  25.77                      0.06
# 46                    0.97                  26.05                      0.05
# 47                    0.91                  24.17                      0.12
# 48                    0.90                  23.92                      0.10
# 49                    0.97                  25.76                      0.08
# 50                    0.92                  24.26                      0.17
# 51                    0.94                  24.73                      0.11
# 52                    0.95                  24.78                      0.02
# 53                    0.80                  20.58                      0.04
# 54                    0.84                  21.59                      0.15
# 55                    0.98                  25.31                      0.06
# 56                    1.97                  50.48                      0.18
# 57                    0.94                  23.96                      0.06
# 58                    0.97                  24.88                      0.05
# 59                    0.83                  21.08                      0.05
# 60                    0.98                  24.57                      0.12
# 61                    0.94                  23.64                      0.06
# 62                    0.94                  23.59                      0.07
# 63                    0.95                  23.71                      0.04
# 64                    0.95                  23.58                      0.05
# 65                    0.94                  22.95                      0.05
# 66                    0.97                  23.62                      0.08
# 67                    0.88                  21.45                      0.04
# 68                    0.95                  23.05                      0.09
# 69                    0.96                  23.21                      0.13
# 70                    0.99                  23.67                      0.14
# 71                    0.96                  22.86                      0.08
# 72                    0.96                  23.03                      0.07
# 73                    0.95                  22.58                      0.05
# 74                    0.89                  21.19                      0.12
# 75                    0.96                  22.73                      0.05
# 76                    0.93                  21.91                      0.11
# 77                    0.99                  23.35                      0.13
# 78                    0.81                  19.24                      0.06
# 79                    0.94                  21.88                      0.10
# 80                    0.96                  21.98                      0.10
# 81                    0.95                  21.00                      0.08
# 82                    0.99                  21.70                      0.02
# 83                    0.34                   6.93                      0.03
# 84                    0.94                  17.94                      0.04
#
#     human_E1_fraction_weighted_sum  num_task_weighted  ai_fraction_weighted  \
# 0                             0.49              61.66                  0.11
# 1                             0.12              39.21                  0.15
# 2                             0.23              37.91                  0.19
# 3                             0.14              36.01                  0.12
# 4                             0.16              35.23                  0.23
# 5                             0.07              34.82                  0.08
# 6                             0.16              34.64                  0.16
# 7                             0.18              34.51                  0.20
# 8                             0.12              34.42                  0.14
# 9                             0.07              34.35                  0.07
# 10                            0.09              33.40                  0.08
# 11                            0.18              33.38                  0.26
# 12                            0.08              32.32                  0.10
# 13                            0.18              31.55                  0.21
# 14                            0.13              31.53                  0.05
# 15                            0.60              31.42                  0.27
# 16                            0.11              31.23                  0.08
# 17                            0.09              31.18                  0.10
# 18                            0.31              31.16                  0.16
# 19                            0.12              30.86                  0.10
# 20                            0.09              30.73                  0.15
# 21                            0.09              30.68                  0.08
# 22                            0.19              30.54                  0.25
# 23                            0.11              30.28                  0.10
# 24                            0.20              30.25                  0.22
# 25                            0.11              30.17                  0.09
# 26                            0.19              30.13                  0.21
# 27                            0.17              29.61                  0.24
# 28                            0.09              29.46                  0.09
# 29                            0.13              29.30                  0.06
# 30                            0.09              29.20                  0.07
# 31                            0.06              29.11                  0.06
# 32                            0.08              28.94                  0.08
# 33                            0.06              28.85                  0.05
# 34                            0.18              28.61                  0.18
# 35                            0.45              28.60                  0.28
# 36                            0.05              28.52                  0.05
# 37                            0.15              27.68                  0.16
# 38                            0.24              27.62                  0.19
# 39                            0.11              27.55                  0.08
# 40                            0.06              27.35                  0.04
# 41                            0.13              27.35                  0.11
# 42                            0.34              27.21                  0.17
# 43                            0.21              27.12                  0.21
# 44                            0.06              26.99                  0.05
# 45                            0.06              26.97                  0.06
# 46                            0.10              26.83                  0.05
# 47                            0.17              26.49                  0.13
# 48                            0.11              26.47                  0.11
# 49                            0.11              26.43                  0.09
# 50                            0.22              26.29                  0.18
# 51                            0.14              26.26                  0.11
# 52                            0.03              26.10                  0.02
# 53                            0.04              25.82                  0.04
# 54                            0.15              25.72                  0.17
# 55                            0.03              25.71                  0.06
# 56                            0.32              25.62                  0.09
# 57                            0.08              25.56                  0.06
# 58                            0.06              25.56                  0.05
# 59                            0.06              25.39                  0.05
# 60                            0.18              25.18                  0.12
# 61                            0.07              25.17                  0.06
# 62                            0.08              25.12                  0.07
# 63                            0.05              24.92                  0.04
# 64                            0.06              24.82                  0.05
# 65                            0.06              24.38                  0.05
# 66                            0.10              24.33                  0.08
# 67                            0.04              24.32                  0.04
# 68                            0.08              24.25                  0.10
# 69                            0.20              24.08                  0.13
# 70                            0.23              24.01                  0.14
# 71                            0.08              23.91                  0.08
# 72                            0.12              23.90                  0.07
# 73                            0.06              23.88                  0.05
# 74                            0.18              23.74                  0.14
# 75                            0.05              23.72                  0.05
# 76                            0.18              23.67                  0.12
# 77                            0.19              23.62                  0.13
# 78                            0.08              23.62                  0.08
# 79                            0.15              23.36                  0.11
# 80                            0.14              22.98                  0.11
# 81                            0.10              22.09                  0.08
# 82                            0.12              22.00                  0.02
# 83                            0.04              20.58                  0.08
# 84                            0.04              18.99                  0.04
#
#     human_E1_fraction_weighted
# 0                         0.13
# 1                         0.17
# 2                         0.26
# 3                         0.16
# 4                         0.24
# 5                         0.10
# 6                         0.17
# 7                         0.21
# 8                         0.15
# 9                         0.09
# 10                        0.11
# 11                        0.25
# 12                        0.13
# 13                        0.21
# 14                        0.07
# 15                        0.19
# 16                        0.12
# 17                        0.12
# 18                        0.19
# 19                        0.13
# 20                        0.19
# 21                        0.10
# 22                        0.26
# 23                        0.12
# 24                        0.23
# 25                        0.11
# 26                        0.22
# 27                        0.22
# 28                        0.09
# 29                        0.07
# 30                        0.09
# 31                        0.07
# 32                        0.09
# 33                        0.07
# 34                        0.20
# 35                        0.26
# 36                        0.05
# 37                        0.16
# 38                        0.26
# 39                        0.11
# 40                        0.06
# 41                        0.13
# 42                        0.17
# 43                        0.22
# 44                        0.06
# 45                        0.06
# 46                        0.10
# 47                        0.18
# 48                        0.13
# 49                        0.12
# 50                        0.24
# 51                        0.15
# 52                        0.03
# 53                        0.05
# 54                        0.18
# 55                        0.03
# 56                        0.16
# 57                        0.09
# 58                        0.06
# 59                        0.07
# 60                        0.19
# 61                        0.07
# 62                        0.08
# 63                        0.06
# 64                        0.07
# 65                        0.06
# 66                        0.10
# 67                        0.05
# 68                        0.08
# 69                        0.21
# 70                        0.24
# 71                        0.09
# 72                        0.12
# 73                        0.07
# 74                        0.20
# 75                        0.06
# 76                        0.19
# 77                        0.19
# 78                        0.10
# 79                        0.16
# 80                        0.15
# 81                        0.11
# 82                        0.12
# 83                        0.12
# 84                        0.05

# %%
# Regression: regress 'ai_fraction_weighted' on 'num_task_weighted'
# controlling for 'human_E1_fraction_weighted' using sector_sums (one row per sector)
import statsmodels.api as sm

# Select relevant columns and drop missing values
reg_df = sector_sums[[
    'ai_fraction_weighted',
    'num_task_weighted',
    'human_E1_fraction_weighted'
]].dropna()

print(f'Observations available for regression: {len(reg_df)}')

if len(reg_df) < 3:
    print('Not enough observations to run a reliable regression (need at least 3 rows after dropping NA).')
else:
    # Prepare design matrix
    X = reg_df[['num_task_weighted', 'human_E1_fraction_weighted']]
    X = sm.add_constant(X)
    y = reg_df['ai_fraction_weighted']

    # Fit OLS model
    model = sm.OLS(y, X).fit()
    print('\nOLS results:')
    print(model.summary())

    robust = model.get_robustcov_results(cov_type='HC3')    # Also show robust standard errors (HC3)
    print('OLS results with HC3 robust SEs:')
    print(robust.summary())
# Out:
# Observations available for regression: 85
#
# OLS results:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     ai_fraction_weighted   R-squared:                       0.827
# Model:                              OLS   Adj. R-squared:                  0.823
# Method:                   Least Squares   F-statistic:                     195.9
# Date:                  Wed, 05 Nov 2025   Prob (F-statistic):           5.85e-32
# Time:                          09:45:38   Log-Likelihood:                 189.20
# No. Observations:                    85   AIC:                            -372.4
# Df Residuals:                        82   BIC:                            -365.1
# Df Model:                             2
# Covariance Type:              nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -0.0371      0.016     -2.376      0.020      -0.068      -0.006
# num_task_weighted              0.0011      0.001      2.026      0.046    2.03e-05       0.002
# human_E1_fraction_weighted     0.8710      0.047     18.623      0.000       0.778       0.964
# ==============================================================================
# Omnibus:                       17.439   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.774
# Skew:                           0.623   Prob(JB):                     5.15e-10
# Kurtosis:                       6.244   Cond. No.                         468.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# OLS results with HC3 robust SEs:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     ai_fraction_weighted   R-squared:                       0.827
# Model:                              OLS   Adj. R-squared:                  0.823
# Method:                   Least Squares   F-statistic:                     128.0
# Date:                  Wed, 05 Nov 2025   Prob (F-statistic):           6.05e-26
# Time:                          09:45:38   Log-Likelihood:                 189.20
# No. Observations:                    85   AIC:                            -372.4
# Df Residuals:                        82   BIC:                            -365.1
# Df Model:                             2
# Covariance Type:                    HC3
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -0.0371      0.029     -1.294      0.199      -0.094       0.020
# num_task_weighted              0.0011      0.001      0.999      0.321      -0.001       0.003
# human_E1_fraction_weighted     0.8710      0.061     14.349      0.000       0.750       0.992
# ==============================================================================
# Omnibus:                       17.439   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.774
# Skew:                           0.623   Prob(JB):                     5.15e-10
# Kurtosis:                       6.244   Cond. No.                         468.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
