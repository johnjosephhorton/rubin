# %% [markdown]
# #### By: Peyman Shahidi
# #### Created: Oct 9, 2025
# #### Last Edit: Oct 27, 2025
#
# <br>

# %%
#Python
import getpass
import numpy as np
import pandas as pd
from collections import defaultdict
import itertools
import random 

## formatting number to appear comma separated and with two digits after decimal: e.g, 1000 shown as 1,000.00
pd.set_option('float_format', "{:,.2f}".format)

import matplotlib.pyplot as plt
#%matplotlib inline
#from matplotlib.legend import Legend

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 200)

# %%
main_folder_path = ".."
input_data_path = f"{main_folder_path}/data"
output_data_path = f'{input_data_path}/computed_objects/GPT_aiExposure'
output_plot_path = f"{main_folder_path}/writeup/plots/GPT_aiExposure"

# %%
# Create directories if they don't exist
import os

for path in [output_data_path, output_plot_path]:
    if not os.path.exists(path):
        os.makedirs(path)

# %%
# Read O*NET data
ONET = pd.read_csv(f'{input_data_path}/computed_objects/ONET_cleaned_tasks.csv')

# Remove apostrophes for consistency
ONET = ONET.applymap(lambda x: x.replace("'", "") if isinstance(x, str) else x)

# Drop  columns to avoid double counting
# Note: In ~4k instances, the same task is mapped to multiple DWAs
ONET = ONET.drop(columns=['DWA ID', 'DWA Title'])

# Remove duplicate rows
rows_before = len(ONET)
print(f"Number of rows before removing duplicates: {rows_before:,}")
ONET = ONET.drop_duplicates().reset_index(drop=True)
rows_after = len(ONET)
print(f"Number of rows after removing duplicates: {rows_after:,}")
print(f"Duplicates removed: {rows_before - rows_after}")

# Print length of dataset
print(f"Number of rows in ONET dataset: {len(ONET):,}")

ONET.head(5)
# Out:
# Number of rows before removing duplicates: 22,310
# Number of rows after removing duplicates: 17,953
# Duplicates removed: 4357
# Number of rows in ONET dataset: 17,953
#   O*NET-SOC Code  Occupation Title  Task ID  \
# 0     11-1011.00  Chief Executives     8823
# 1     11-1011.00  Chief Executives     8824
# 2     11-1011.00  Chief Executives     8825
# 3     11-1011.00  Chief Executives     8826
# 4     11-1011.00  Chief Executives     8827
#
#                                           Task Title Task Type  Job Zone  \
# 0  Direct or coordinate an organizations financia...      Core         5
# 1  Confer with board members, organization offici...      Core         5
# 2  Analyze operations to evaluate performance of ...      Core         5
# 3  Direct, plan, or implement policies, objective...      Core         5
# 4  Prepare budgets for approval, including those ...      Core         5
#
#    Task_Time_Percentage  Hourly_Mean_Wage  Hourly_P10_Wage  Hourly_P25_Wage  \
# 0                  9.62            124.47            38.46            62.90
# 1                  9.49            124.47            38.46            62.90
# 2                  9.22            124.47            38.46            62.90
# 3                 10.26            124.47            38.46            62.90
# 4                  1.46            124.47            38.46            62.90
#
#    ...  Relevance  Base_SOC_Code  Major_Group_Code       Major_Group_Title  \
# 0  ...      94.19        11-1011           11-0000  Management Occupations
# 1  ...      98.79        11-1011           11-0000  Management Occupations
# 2  ...     100.00        11-1011           11-0000  Management Occupations
# 3  ...      95.84        11-1011           11-0000  Management Occupations
# 4  ...      90.47        11-1011           11-0000  Management Occupations
#
#    Minor_Group_Code  Minor_Group_Title  Broad_Occupation_Code  \
# 0           11-1000     Top Executives                11-1010
# 1           11-1000     Top Executives                11-1010
# 2           11-1000     Top Executives                11-1010
# 3           11-1000     Top Executives                11-1010
# 4           11-1000     Top Executives                11-1010
#
#    Broad_Occupation_Title  Detailed_Occupation_Code  Detailed_Occupation_Title
# 0        Chief Executives                   11-1011           Chief Executives
# 1        Chief Executives                   11-1011           Chief Executives
# 2        Chief Executives                   11-1011           Chief Executives
# 3        Chief Executives                   11-1011           Chief Executives
# 4        Chief Executives                   11-1011           Chief Executives
#
# [5 rows x 37 columns]

# %%
# Load GPTs are GPTs full label dataset
gpts_full_labels = pd.read_csv(f'{input_data_path}/GPTs-are-GPTs-main/data/full_labelset.tsv', sep="\t")
# Drop the first column
gpts_full_labels = gpts_full_labels.drop(gpts_full_labels.columns[:1], axis=1)

# Convert Task ID to integer
gpts_full_labels['Task ID'] = gpts_full_labels['Task ID'].astype(int)

# Remove apostrophes for consistency
gpts_full_labels = gpts_full_labels.applymap(lambda x: x.replace("'", "") if isinstance(x, str) else x)

# Rename columns
gpts_full_labels = gpts_full_labels.rename(columns={
    'Task': 'Task Title',
    'Title': 'Occupation Title'
})

# Print length of dataset
print(f"Number of rows in GPTs full labels dataset: {len(gpts_full_labels):,}")


gpts_full_labels.head(5)
# Out:
# Number of rows in GPTs full labels dataset: 19,265
#   O*NET-SOC Code  Task ID                                         Task Title  \
# 0     11-1011.00     8823  Direct or coordinate an organizations financia...
# 1     11-1011.00     8831  Appoint department heads or managers and assig...
# 2     11-1011.00     8825  Analyze operations to evaluate performance of ...
# 3     11-1011.00     8826  Direct, plan, or implement policies, objective...
# 4     11-1011.00     8827  Prepare budgets for approval, including those ...
#
#   Task Type  Occupation Title human_exposure_agg gpt4_exposure  \
# 0      Core  Chief Executives                 E0            E2
# 1      Core  Chief Executives                 E0            E0
# 2      Core  Chief Executives                 E2            E2
# 3      Core  Chief Executives                 E0            E2
# 4      Core  Chief Executives                 E2            E2
#
#   gpt4_exposure_alt_rubric  gpt_3_relevant gpt4_automation  alpha  beta  \
# 0                       E2           False              T2   0.00  0.50
# 1                       E0           False              T1   0.00  0.00
# 2                       E2           False              T2   0.00  0.50
# 3                       E0           False              T1   0.00  0.50
# 4                       E2           False              T2   0.00  0.50
#
#    gamma  automation human_labels
# 0   1.00        0.50           E0
# 1   0.00        0.25           E0
# 2   1.00        0.50           E2
# 3   1.00        0.25           E0
# 4   1.00        0.50           E2

# %%
# Merge with ONET dataset to get hierarchical codes and titles
ONET = ONET.merge(gpts_full_labels, on=['O*NET-SOC Code', 'Occupation Title', 'Task ID', 'Task Title', 'Task Type'], how='left')

# Check how many tasks were not matched
unmatched_tasks = ONET[ONET['gpt4_exposure'].isna()]
print(f"Number of unmatched tasks: {len(unmatched_tasks):,}")
# Out:
# Number of unmatched tasks: 0

# %%
# Drop the supplemental tasks
ONET = ONET[ONET['Task Type'] != 'Supplemental'].reset_index(drop=True)

# Drop rows whose Occupation Title includes 'Teachers, Postsecondary'
ONET = ONET[~ONET['Occupation Title'].str.contains('Teachers, Postsecondary')].reset_index(drop=True)

# %% [markdown]
# ## Replication of Eloundou et al. (2024) Measures

# %%
# Reconstruct the occ_level exposure dataset from the original paper
def compute_exposure_shares(df, exposure_col, prefix):
    # Weight core vs. supplemental tasks (if column exists)
    df["task_weight"] = df["Task Type"].map({"Core": 1.0, "Supplemental": 0.5}).fillna(1.0)

    # One-hot exposure indicators
    df[f"{prefix}_E1"] = (df[exposure_col] == "E1").astype(int)
    df[f"{prefix}_E2"] = (df[exposure_col] == "E2").astype(int)

    # Weighted shares per occupation
    occ_level = (
        df.groupby(["O*NET-SOC Code", "Occupation Title"])
        .apply(lambda x: pd.Series({
            f"{prefix}_E1_share": (x[f"{prefix}_E1"] * x["task_weight"]).sum() / x["task_weight"].sum(),
            f"{prefix}_E2_share": (x[f"{prefix}_E2"] * x["task_weight"]).sum() / x["task_weight"].sum(),
        }))
        .reset_index()
    )

    # Composite measures
    occ_level[f"{prefix}_E1_plus_halfE2"] = occ_level[f"{prefix}_E1_share"] + 0.5 * occ_level[f"{prefix}_E2_share"]
    occ_level[f"{prefix}_E1_plus_E2"]     = occ_level[f"{prefix}_E1_share"] + occ_level[f"{prefix}_E2_share"]

    occ_level = occ_level.drop(columns=[f'{prefix}_E2_share'])

    occ_level = occ_level.rename(columns={'gpt4_E1_share': 'gpt4_alpha',
                                          'gpt4_E1_plus_halfE2': 'gpt4_beta',
                                          'gpt4_E1_plus_E2': 'gpt4_gamma',
                                          'human_E1_share': 'human_alpha',
                                          'human_E1_plus_halfE2': 'human_beta',
                                          'human_E1_plus_E2': 'human_gamma'})

    return occ_level


# Compute exposure shares for GPT-4 and human ratings
gpt4_exposure_scores = compute_exposure_shares(ONET, "gpt4_exposure", "gpt4")
human_exposure_scores = compute_exposure_shares(ONET, "human_labels", "human")

# Merge GPT-4 and human exposure scores on occupation code and title
exposure_scores_occupation = pd.merge(gpt4_exposure_scores, human_exposure_scores, 
                                     on=["O*NET-SOC Code", "Occupation Title"])

# Save the combined exposure scores to CSV
# exposure_scores_occupation.to_csv(f'{output_data_path}/exposure_scores_occupation.csv', index=False)
# print(f"Saved combined exposure scores to: {output_data_path}/exposure_scores_occupation.csv")
print(f"Number of occupations: {len(exposure_scores_occupation)}")

# Display the results
exposure_scores_occupation.head()
# Out:
# Number of occupations: 837
#   O*NET-SOC Code                     Occupation Title  gpt4_alpha  gpt4_beta  \
# 0     11-1011.00                     Chief Executives        0.11       0.47
# 1     11-1011.03        Chief Sustainability Officers        0.17       0.56
# 2     11-1021.00      General and Operations Managers        0.00       0.50
# 3     11-2011.00  Advertising and Promotions Managers        0.00       0.50
# 4     11-2021.00                   Marketing Managers        0.08       0.50
#
#    gpt4_gamma  human_alpha  human_beta  human_gamma
# 0        0.84         0.21        0.37         0.53
# 1        0.94         0.06        0.39         0.72
# 2        1.00         0.11        0.39         0.67
# 3        1.00         0.38        0.62         0.85
# 4        0.92         0.17        0.54         0.92

# %% [markdown]
# ### Add additional columns to replicated measures and save

# %%
# Enrich exposure_scores_occupation with hierarchical ONET codes/titles (Major, Minor, Broad, Detailed), add task counts, and save
print('\nAdding ONET hierarchy columns to exposure_scores_occupation and merging unique task counts; saving as ONET_tasklevel_exposure.csv')

# Select unique occupation-level mapping from ONET
occupation_map = ONET.drop_duplicates(subset=['O*NET-SOC Code', 'Occupation Title'])[[
    'O*NET-SOC Code', 'Occupation Title',
    'Major_Group_Code', 'Major_Group_Title',
    'Minor_Group_Code', 'Minor_Group_Title',
    'Broad_Occupation_Code', 'Broad_Occupation_Title',
    'Detailed_Occupation_Code', 'Detailed_Occupation_Title'
    ]]

# Merge with exposure_scores_occupation
exposure_scores_occupation = exposure_scores_occupation.merge(
    occupation_map,
    on=['O*NET-SOC Code', 'Occupation Title'],
    how='left'
    )

# Compute number of unique tasks per occupation and merge into the enriched dataset
task_counts = ONET.groupby(['O*NET-SOC Code', 'Occupation Title'])['Task ID'].nunique().reset_index()
task_counts = task_counts.rename(columns={'Task ID': 'num_unique_tasks'})

exposure_scores_occupation = exposure_scores_occupation.merge(
    task_counts,
    on=['O*NET-SOC Code', 'Occupation Title'],
    how='left'
    )

# Save to CSV
exposure_scores_occupation.to_csv(f'{output_data_path}/ONET_tasklevel_exposure.csv', index=False)
print(f"✓ Saved enriched exposure dataset with task counts to: {output_data_path}/ONET_tasklevel_exposure.csv")

# Display sample
exposure_scores_occupation.head()
# Out:
# Adding ONET hierarchy columns to exposure_scores_occupation and merging unique task counts; saving as ONET_tasklevel_exposure.csv
# ✓ Saved enriched exposure dataset with task counts to: ../data/computed_objects/GPT_aiExposure/ONET_tasklevel_exposure.csv
#   O*NET-SOC Code                     Occupation Title  gpt4_alpha  gpt4_beta  \
# 0     11-1011.00                     Chief Executives        0.11       0.47
# 1     11-1011.03        Chief Sustainability Officers        0.17       0.56
# 2     11-1021.00      General and Operations Managers        0.00       0.50
# 3     11-2011.00  Advertising and Promotions Managers        0.00       0.50
# 4     11-2021.00                   Marketing Managers        0.08       0.50
#
#    gpt4_gamma  human_alpha  human_beta  human_gamma Major_Group_Code  \
# 0        0.84         0.21        0.37         0.53          11-0000
# 1        0.94         0.06        0.39         0.72          11-0000
# 2        1.00         0.11        0.39         0.67          11-0000
# 3        1.00         0.38        0.62         0.85          11-0000
# 4        0.92         0.17        0.54         0.92          11-0000
#
#         Major_Group_Title Minor_Group_Code  \
# 0  Management Occupations          11-1000
# 1  Management Occupations          11-1000
# 2  Management Occupations          11-1000
# 3  Management Occupations          11-2000
# 4  Management Occupations          11-2000
#
#                                    Minor_Group_Title Broad_Occupation_Code  \
# 0                                     Top Executives               11-1010
# 1                                     Top Executives               11-1010
# 2                                     Top Executives               11-1020
# 3  Advertising, Marketing, Promotions, Public Rel...               11-2010
# 4  Advertising, Marketing, Promotions, Public Rel...               11-2020
#
#                 Broad_Occupation_Title Detailed_Occupation_Code  \
# 0                     Chief Executives                  11-1011
# 1                     Chief Executives                  11-1011
# 2      General and Operations Managers                  11-1021
# 3  Advertising and Promotions Managers                  11-2011
# 4         Marketing and Sales Managers                  11-2021
#
#              Detailed_Occupation_Title  num_unique_tasks
# 0                     Chief Executives                19
# 1                     Chief Executives                18
# 2      General and Operations Managers                 9
# 3  Advertising and Promotions Managers                13
# 4                   Marketing Managers                12

# %%
# Define exposure measures and labels
measures = ['alpha', 'beta', 'gamma']
import numpy as _np

# Create combined 2x3 figure (2 rows: GPT-4, Human; 3 columns: alpha,beta,gamma)
fig, axes = plt.subplots(2, 3, figsize=(20, 10), sharex='col', sharey='row')
# Top row: GPT-4
for i, measure in enumerate(measures):
    ax = axes[0, i]
    # Plot Number of Occupation Tasks on x and Exposure on y (axes flipped)
    x = exposure_scores_occupation['num_unique_tasks'].astype(float)
    y = exposure_scores_occupation[f'gpt4_{measure}'].astype(float)
    ax.scatter(x, y, alpha=0.05, color='steelblue', edgecolors='white')

    # Add binned scatter overlay: bin by num_unique_tasks
    n_bins = 12
    try:
        bins = pd.cut(x, bins=n_bins)
    except Exception:
        bins = pd.qcut(x, q=min(n_bins, x.nunique()), duplicates='drop')
    bin_stats = (
        exposure_scores_occupation
        .assign(bin=bins)
        .groupby('bin')
        .agg(task_count_mean=('num_unique_tasks', 'mean'),
             exposure_mean=(f'gpt4_{measure}', 'mean'),
             count=('num_unique_tasks', 'size'))
        .reset_index()
    )
    base_marker_scale = 60
    bin_marker_sizes = np.clip(np.sqrt(bin_stats['count']) * base_marker_scale, 20, 300)
    ax.scatter(bin_stats['task_count_mean'], bin_stats['exposure_mean'], s=bin_marker_sizes, color='steelblue', alpha=0.9, edgecolors='k', label='Binned means')

    # Fit linear regression line (baseline) if we have enough valid points
    valid_mask = (~_np.isnan(x)) & (~_np.isnan(y))
    if valid_mask.sum() > 1:
        # Baseline: simple OLS via polyfit
        coeffs = _np.polyfit(x[valid_mask], y[valid_mask], 1)
        x_fit = _np.linspace(x[valid_mask].min(), x[valid_mask].max(), 100)
        y_fit = coeffs[0] * x_fit + coeffs[1]
        ax.plot(x_fit, y_fit, color='black', linestyle='--', linewidth=2, label=f'baseline slope={coeffs[0]:.2e}')

        # Fixed-effects (within-Major) slope: demean by Major_Group_Code and fit slope on deviations
        if 'Major_Group_Code' in exposure_scores_occupation.columns:
            dfv = exposure_scores_occupation.loc[valid_mask, ['num_unique_tasks', f'gpt4_{measure}', 'Major_Group_Code']].dropna()
            if dfv['Major_Group_Code'].nunique() > 1:
                x_dev = dfv['num_unique_tasks'] - dfv.groupby('Major_Group_Code')['num_unique_tasks'].transform('mean')
                y_dev = dfv[f'gpt4_{measure}'] - dfv.groupby('Major_Group_Code')[f'gpt4_{measure}'].transform('mean')
                denom = (x_dev ** 2).sum()
                if denom > 0:
                    slope_within = (x_dev * y_dev).sum() / denom
                    overall_mean_x = dfv['num_unique_tasks'].mean()
                    overall_mean_y = dfv[f'gpt4_{measure}'].mean()
                    x_fit_fe = _np.linspace(dfv['num_unique_tasks'].min(), dfv['num_unique_tasks'].max(), 100)
                    y_fit_fe = overall_mean_y + slope_within * (x_fit_fe - overall_mean_x)
                    ax.plot(x_fit_fe, y_fit_fe, color='#FFD966', linestyle='-', linewidth=2, label=f'FE slope={slope_within:.2e}')

        ax.legend()

    # xlabel is number of tasks, ylabel is exposure (show per-measure on each subplot)
    ax.set_xlabel('Number of Occupation Tasks')
    ax.set_ylabel(f'GPT-4 AI Exposure ({measure.upper()})')
    ax.set_title(f'Occupation GPT-4 AI Exposure ({measure.capitalize()}) vs. Number of Tasks')
    ax.grid(True, alpha=0.3)
    ax.set_ylim(-0.02, 1.02)

# Bottom row: Human
for i, measure in enumerate(measures):
    ax = axes[1, i]
    # Plot Number of Occupation Tasks on x and Exposure on y (axes flipped)
    x = exposure_scores_occupation['num_unique_tasks'].astype(float)
    y = exposure_scores_occupation[f'human_{measure}'].astype(float)
    ax.scatter(x, y, alpha=0.05, color='indianred', edgecolors='white')

    # Binned overlay
    n_bins = 12
    try:
        bins = pd.cut(x, bins=n_bins)
    except Exception:
        bins = pd.qcut(x, q=min(n_bins, x.nunique()), duplicates='drop')
    bin_stats = (
        exposure_scores_occupation
        .assign(bin=bins)
        .groupby('bin')
        .agg(task_count_mean=('num_unique_tasks', 'mean'),
             exposure_mean=(f'human_{measure}', 'mean'),
             count=('num_unique_tasks', 'size'))
        .reset_index()
    )
    base_marker_scale = 60
    bin_marker_sizes = np.clip(np.sqrt(bin_stats['count']) * base_marker_scale, 20, 300)
    ax.scatter(bin_stats['task_count_mean'], bin_stats['exposure_mean'], s=bin_marker_sizes, color='indianred', alpha=0.9, edgecolors='k', label='Binned means')

    # Fit linear regression line (baseline)
    valid_mask = (~_np.isnan(x)) & (~_np.isnan(y))
    if valid_mask.sum() > 1:
        coeffs = _np.polyfit(x[valid_mask], y[valid_mask], 1)
        x_fit = _np.linspace(x[valid_mask].min(), x[valid_mask].max(), 100)
        y_fit = coeffs[0] * x_fit + coeffs[1]
        ax.plot(x_fit, y_fit, color='black', linestyle='--', linewidth=2, label=f'baseline slope={coeffs[0]:.2e}')

        # FE within-Major slope
        if 'Major_Group_Code' in exposure_scores_occupation.columns:
            dfv = exposure_scores_occupation.loc[valid_mask, ['num_unique_tasks', f'human_{measure}', 'Major_Group_Code']].dropna()
            if dfv['Major_Group_Code'].nunique() > 1:
                x_dev = dfv['num_unique_tasks'] - dfv.groupby('Major_Group_Code')['num_unique_tasks'].transform('mean')
                y_dev = dfv[f'human_{measure}'] - dfv.groupby('Major_Group_Code')[f'human_{measure}'].transform('mean')
                denom = (x_dev ** 2).sum()
                if denom > 0:
                    slope_within = (x_dev * y_dev).sum() / denom
                    overall_mean_x = dfv['num_unique_tasks'].mean()
                    overall_mean_y = dfv[f'human_{measure}'].mean()
                    x_fit_fe = _np.linspace(dfv['num_unique_tasks'].min(), dfv['num_unique_tasks'].max(), 100)
                    y_fit_fe = overall_mean_y + slope_within * (x_fit_fe - overall_mean_x)
                    ax.plot(x_fit_fe, y_fit_fe, color='orange', linestyle='-', linewidth=2, label=f'FE slope={slope_within:.2e}')

        ax.legend()

    ax.set_xlabel('Number of Occupation Tasks')
    ax.set_ylabel(f'Human AI Exposure ({measure.upper()})')
    ax.set_title(f'Occupation Human AI Exposure ({measure.capitalize()}) vs. Number of Tasks')
    ax.grid(True, alpha=0.3)
    ax.set_ylim(-0.02, 1.02)

plt.tight_layout()
combined_plot_file = f'{output_plot_path}/numtasks_vs_exposure_occupation.png'
plt.savefig(combined_plot_file, dpi=300, bbox_inches='tight')
plt.show()
print(f"✓ Saved combined 2x3 scatter figure to: {combined_plot_file}")
# Out:
# ✓ Saved combined 2x3 scatter figure to: ../writeup/plots/GPT_aiExposure/numtasks_vs_exposure_occupation.png

# %%
# Regress exposure measures (alpha/beta/gamma) on number of tasks within occupation
# Two specifications per measure:
#  - baseline: exposure ~ num_unique_tasks (constant + slope)
#  - FE:       exposure ~ num_unique_tasks + C(Major_Group_Code)  (Major group fixed effects)

import statsmodels.api as sm
import statsmodels.formula.api as smf

results = []
print('\nRunning OLS regressions of exposure measures on num_unique_tasks (HC3 robust SE).')
for source in ['gpt4', 'human']:
    for measure in ['alpha', 'beta', 'gamma']:
        dep = f"{source}_{measure}"
        if dep not in exposure_scores_occupation.columns:
            print(f"Skipping {dep}: column not found")
            continue

        # Pull relevant columns and drop NA
        cols_needed = ['num_unique_tasks']
        if 'Major_Group_Code' in exposure_scores_occupation.columns:
            cols_needed.append('Major_Group_Code')
        df_reg = exposure_scores_occupation[[dep] + cols_needed].dropna()
        n = len(df_reg)
        if n == 0:
            print(f"Skipping {dep}: no non-missing rows")
            continue
        if n < 10:
            print(f"Warning: small sample for {dep} (n={n}) — results may be noisy")

        # Baseline: intercept + num_unique_tasks
        X = sm.add_constant(df_reg['num_unique_tasks'].astype(float))
        y = df_reg[dep].astype(float)
        model_base = sm.OLS(y, X).fit(cov_type='HC3')

        coef = model_base.params.get('num_unique_tasks', float('nan'))
        se = model_base.bse.get('num_unique_tasks', float('nan'))
        pval = model_base.pvalues.get('num_unique_tasks', float('nan'))
        r2 = model_base.rsquared

        print(f"\n{dep} ~ num_unique_tasks   (baseline)   n={n}")
        print(model_base.summary())

        results.append({
            'measure': dep,
            'spec': 'baseline',
            'n': n,
            'coef_num_tasks': coef,
            'se_num_tasks': se,
            'pval_num_tasks': pval,
            'r2': r2
        })

        # Fixed effects by Major_Group_Code
        formula = f"{dep} ~ num_unique_tasks + C(Major_Group_Code)"
        model_fe = smf.ols(formula, data=df_reg).fit(cov_type='HC3')

        coef_fe = model_fe.params.get('num_unique_tasks', float('nan'))
        se_fe = model_fe.bse.get('num_unique_tasks', float('nan'))
        pval_fe = model_fe.pvalues.get('num_unique_tasks', float('nan'))
        r2_fe = model_fe.rsquared

        print(f"\n{dep} ~ num_unique_tasks + C(Major_Group_Code)   (FE)   n={n}")
        print(model_fe.summary())

        results.append({
            'measure': dep,
            'spec': 'fe_major',
            'n': n,
            'coef_num_tasks': coef_fe,
            'se_num_tasks': se_fe,
            'pval_num_tasks': pval_fe,
            'r2': r2_fe
        })

# Save a compact summary to CSV
res_df = pd.DataFrame(results)
out_fp = f"{output_data_path}/regressions_exposure_on_num_tasks_withFE.csv"
res_df.to_csv(out_fp, index=False)
print(f"\n✓ Saved regression summary to: {out_fp}")
# Out:
# Running OLS regressions of exposure measures on num_unique_tasks (HC3 robust SE).
#
# gpt4_alpha ~ num_unique_tasks   (baseline)   n=837
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             gpt4_alpha   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.2783
# Date:                Mon, 27 Oct 2025   Prob (F-statistic):              0.598
# Time:                        13:12:19   Log-Likelihood:                 266.84
# No. Observations:                 837   AIC:                            -529.7
# Df Residuals:                     835   BIC:                            -520.2
# Df Model:                           1
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.1472      0.018      8.207      0.000       0.112       0.182
# num_unique_tasks    -0.0005      0.001     -0.528      0.598      -0.003       0.001
# ==============================================================================
# Omnibus:                      430.124   Durbin-Watson:                   1.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2389.342
# Skew:                           2.368   Prob(JB):                         0.00
# Kurtosis:                       9.788   Cond. No.                         42.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# gpt4_alpha ~ num_unique_tasks + C(Major_Group_Code)   (FE)   n=837
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             gpt4_alpha   R-squared:                       0.382
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     16.37
# Date:                Mon, 27 Oct 2025   Prob (F-statistic):           5.59e-51
# Time:                        13:12:19   Log-Likelihood:                 467.78
# No. Observations:                 837   AIC:                            -889.6
# Df Residuals:                     814   BIC:                            -780.8
# Df Model:                          22
# Covariance Type:                  HC3
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.0899      0.018      4.921      0.000       0.054       0.126
# C(Major_Group_Code)[T.13-0000]     0.0835      0.024      3.438      0.001       0.036       0.131
# C(Major_Group_Code)[T.15-0000]     0.4319      0.055      7.834      0.000       0.324       0.540
# C(Major_Group_Code)[T.17-0000]     0.0960      0.022      4.446      0.000       0.054       0.138
# C(Major_Group_Code)[T.19-0000]     0.0586      0.021      2.806      0.005       0.018       0.100
# C(Major_Group_Code)[T.21-0000]     0.0436      0.025      1.725      0.084      -0.006       0.093
# C(Major_Group_Code)[T.23-0000]     0.0493      0.045      1.089      0.276      -0.039       0.138
# C(Major_Group_Code)[T.25-0000]     0.0792      0.024      3.244      0.001       0.031       0.127
# C(Major_Group_Code)[T.27-0000]     0.1226      0.045      2.719      0.007       0.034       0.211
# C(Major_Group_Code)[T.29-0000]     0.0052      0.014      0.376      0.707      -0.022       0.032
# C(Major_Group_Code)[T.31-0000]     0.0956      0.044      2.158      0.031       0.009       0.183
# C(Major_Group_Code)[T.33-0000]     0.0642      0.021      3.012      0.003       0.022       0.106
# C(Major_Group_Code)[T.35-0000]    -0.0097      0.023     -0.420      0.675      -0.055       0.035
# C(Major_Group_Code)[T.37-0000]     0.0028      0.038      0.074      0.941      -0.072       0.077
# C(Major_Group_Code)[T.39-0000]     0.0378      0.019      2.012      0.044       0.001       0.075
# C(Major_Group_Code)[T.41-0000]     0.0767      0.036      2.102      0.036       0.005       0.148
# C(Major_Group_Code)[T.43-0000]     0.3321      0.037      8.868      0.000       0.259       0.406
# C(Major_Group_Code)[T.45-0000]    -0.0377      0.024     -1.606      0.108      -0.084       0.008
# C(Major_Group_Code)[T.47-0000]    -0.0519      0.013     -4.091      0.000      -0.077      -0.027
# C(Major_Group_Code)[T.49-0000]     0.0151      0.017      0.874      0.382      -0.019       0.049
# C(Major_Group_Code)[T.51-0000]     0.0057      0.016      0.366      0.714      -0.025       0.036
# C(Major_Group_Code)[T.53-0000]     0.0415      0.020      2.118      0.034       0.003       0.080
# num_unique_tasks                  -0.0011      0.001     -1.305      0.192      -0.003       0.001
# ==============================================================================
# Omnibus:                      285.517   Durbin-Watson:                   1.581
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1396.950
# Skew:                           1.489   Prob(JB):                    4.53e-304
# Kurtosis:                       8.584   Cond. No.                         330.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# gpt4_beta ~ num_unique_tasks   (baseline)   n=837
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              gpt4_beta   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     10.01
# Date:                Mon, 27 Oct 2025   Prob (F-statistic):            0.00162
# Time:                        13:12:19   Log-Likelihood:                 47.930
# No. Observations:                 837   AIC:                            -91.86
# Df Residuals:                     835   BIC:                            -82.40
# Df Model:                           1
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.2784      0.022     12.915      0.000       0.236       0.321
# num_unique_tasks     0.0039      0.001      3.163      0.002       0.001       0.006
# ==============================================================================
# Omnibus:                       26.944   Durbin-Watson:                   0.620
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.608
# Skew:                           0.400   Prob(JB):                     1.67e-06
# Kurtosis:                       2.651   Cond. No.                         42.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# gpt4_beta ~ num_unique_tasks + C(Major_Group_Code)   (FE)   n=837
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              gpt4_beta   R-squared:                       0.637
# Model:                            OLS   Adj. R-squared:                  0.627
# Method:                 Least Squares   F-statistic:                     85.21
# Date:                Mon, 27 Oct 2025   Prob (F-statistic):          6.93e-194
# Time:                        13:12:19   Log-Likelihood:                 467.17
# No. Observations:                 837   AIC:                            -888.3
# Df Residuals:                     814   BIC:                            -779.6
# Df Model:                          22
# Covariance Type:                  HC3
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.4634      0.018     25.233      0.000       0.427       0.499
# C(Major_Group_Code)[T.13-0000]     0.0741      0.019      3.830      0.000       0.036       0.112
# C(Major_Group_Code)[T.15-0000]     0.2693      0.030      9.054      0.000       0.211       0.328
# C(Major_Group_Code)[T.17-0000]     0.0353      0.017      2.077      0.038       0.002       0.069
# C(Major_Group_Code)[T.19-0000]     0.0009      0.019      0.047      0.963      -0.037       0.039
# C(Major_Group_Code)[T.21-0000]    -0.1387      0.035     -3.974      0.000      -0.207      -0.070
# C(Major_Group_Code)[T.23-0000]     0.0417      0.029      1.422      0.155      -0.016       0.099
# C(Major_Group_Code)[T.25-0000]    -0.0898      0.029     -3.071      0.002      -0.147      -0.032
# C(Major_Group_Code)[T.27-0000]     0.0067      0.038      0.176      0.860      -0.068       0.081
# C(Major_Group_Code)[T.29-0000]    -0.1268      0.018     -6.873      0.000      -0.163      -0.091
# C(Major_Group_Code)[T.31-0000]    -0.2250      0.051     -4.391      0.000      -0.325      -0.125
# C(Major_Group_Code)[T.33-0000]    -0.1753      0.029     -6.138      0.000      -0.231      -0.119
# C(Major_Group_Code)[T.35-0000]    -0.3418      0.038     -8.971      0.000      -0.417      -0.267
# C(Major_Group_Code)[T.37-0000]    -0.3321      0.059     -5.607      0.000      -0.448      -0.216
# C(Major_Group_Code)[T.39-0000]    -0.2578      0.028     -9.085      0.000      -0.313      -0.202
# C(Major_Group_Code)[T.41-0000]    -0.0265      0.046     -0.580      0.562      -0.116       0.063
# C(Major_Group_Code)[T.43-0000]     0.1479      0.033      4.534      0.000       0.084       0.212
# C(Major_Group_Code)[T.45-0000]    -0.3426      0.038     -8.946      0.000      -0.418      -0.268
# C(Major_Group_Code)[T.47-0000]    -0.3959      0.017    -23.849      0.000      -0.428      -0.363
# C(Major_Group_Code)[T.49-0000]    -0.3217      0.020    -16.119      0.000      -0.361      -0.283
# C(Major_Group_Code)[T.51-0000]    -0.3251      0.017    -18.798      0.000      -0.359      -0.291
# C(Major_Group_Code)[T.53-0000]    -0.2600      0.023    -11.474      0.000      -0.304      -0.216
# num_unique_tasks                   0.0002      0.001      0.240      0.810      -0.001       0.002
# ==============================================================================
# Omnibus:                       64.542   Durbin-Watson:                   1.565
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              219.667
# Skew:                           0.302   Prob(JB):                     1.99e-48
# Kurtosis:                       5.436   Cond. No.                         330.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# gpt4_gamma ~ num_unique_tasks   (baseline)   n=837
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             gpt4_gamma   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     20.90
# Date:                Mon, 27 Oct 2025   Prob (F-statistic):           5.56e-06
# Time:                        13:12:19   Log-Likelihood:                -315.15
# No. Observations:                 837   AIC:                             634.3
# Df Residuals:                     835   BIC:                             643.8
# Df Model:                           1
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.4096      0.032     12.999      0.000       0.348       0.471
# num_unique_tasks     0.0084      0.002      4.572      0.000       0.005       0.012
# ==============================================================================
# Omnibus:                     7222.145   Durbin-Watson:                   0.536
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.166
# Skew:                          -0.042   Prob(JB):                     4.76e-17
# Kurtosis:                       1.534   Cond. No.                         42.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# gpt4_gamma ~ num_unique_tasks + C(Major_Group_Code)   (FE)   n=837
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             gpt4_gamma   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     147.8
# Date:                Mon, 27 Oct 2025   Prob (F-statistic):          2.20e-266
# Time:                        13:12:19   Log-Likelihood:                 150.94
# No. Observations:                 837   AIC:                            -255.9
# Df Residuals:                     814   BIC:                            -147.1
# Df Model:                          22
# Covariance Type:                  HC3
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.8369      0.028     29.998      0.000       0.782       0.892
# C(Major_Group_Code)[T.13-0000]     0.0646      0.027      2.419      0.016       0.012       0.117
# C(Major_Group_Code)[T.15-0000]     0.1066      0.020      5.301      0.000       0.067       0.146
# C(Major_Group_Code)[T.17-0000]    -0.0254      0.027     -0.943      0.346      -0.078       0.027
# C(Major_Group_Code)[T.19-0000]    -0.0568      0.031     -1.851      0.064      -0.117       0.003
# C(Major_Group_Code)[T.21-0000]    -0.3211      0.057     -5.612      0.000      -0.433      -0.209
# C(Major_Group_Code)[T.23-0000]     0.0341      0.031      1.104      0.270      -0.026       0.095
# C(Major_Group_Code)[T.25-0000]    -0.2589      0.047     -5.507      0.000      -0.351      -0.167
# C(Major_Group_Code)[T.27-0000]    -0.1093      0.049     -2.218      0.027      -0.206      -0.013
# C(Major_Group_Code)[T.29-0000]    -0.2588      0.032     -7.974      0.000      -0.322      -0.195
# C(Major_Group_Code)[T.31-0000]    -0.5457      0.065     -8.440      0.000      -0.672      -0.419
# C(Major_Group_Code)[T.33-0000]    -0.4148      0.051     -8.167      0.000      -0.514      -0.315
# C(Major_Group_Code)[T.35-0000]    -0.6740      0.057    -11.859      0.000      -0.785      -0.563
# C(Major_Group_Code)[T.37-0000]    -0.6669      0.085     -7.884      0.000      -0.833      -0.501
# C(Major_Group_Code)[T.39-0000]    -0.5534      0.048    -11.612      0.000      -0.647      -0.460
# C(Major_Group_Code)[T.41-0000]    -0.1296      0.075     -1.738      0.082      -0.276       0.017
# C(Major_Group_Code)[T.43-0000]    -0.0363      0.040     -0.900      0.368      -0.115       0.043
# C(Major_Group_Code)[T.45-0000]    -0.6474      0.069     -9.392      0.000      -0.782      -0.512
# C(Major_Group_Code)[T.47-0000]    -0.7398      0.029    -25.080      0.000      -0.798      -0.682
# C(Major_Group_Code)[T.49-0000]    -0.6584      0.030    -21.762      0.000      -0.718      -0.599
# C(Major_Group_Code)[T.51-0000]    -0.6558      0.026    -24.964      0.000      -0.707      -0.604
# C(Major_Group_Code)[T.53-0000]    -0.5616      0.036    -15.511      0.000      -0.633      -0.491
# num_unique_tasks                   0.0015      0.001      1.221      0.222      -0.001       0.004
# ==============================================================================
# Omnibus:                       38.006   Durbin-Watson:                   1.507
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              114.617
# Skew:                          -0.045   Prob(JB):                     1.29e-25
# Kurtosis:                       4.811   Cond. No.                         330.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# human_alpha ~ num_unique_tasks   (baseline)   n=837
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            human_alpha   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     11.42
# Date:                Mon, 27 Oct 2025   Prob (F-statistic):           0.000759
# Time:                        13:12:19   Log-Likelihood:                 358.15
# No. Observations:                 837   AIC:                            -712.3
# Df Residuals:                     835   BIC:                            -702.8
# Df Model:                           1
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0968      0.015      6.307      0.000       0.067       0.127
# num_unique_tasks     0.0029      0.001      3.380      0.001       0.001       0.005
# ==============================================================================
# Omnibus:                      255.223   Durbin-Watson:                   0.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              692.255
# Skew:                           1.554   Prob(JB):                    4.77e-151
# Kurtosis:                       6.191   Cond. No.                         42.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# human_alpha ~ num_unique_tasks + C(Major_Group_Code)   (FE)   n=837
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            human_alpha   R-squared:                       0.418
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     57.94
# Date:                Mon, 27 Oct 2025   Prob (F-statistic):          7.72e-150
# Time:                        13:12:19   Log-Likelihood:                 579.04
# No. Observations:                 837   AIC:                            -1112.
# Df Residuals:                     814   BIC:                            -1003.
# Df Model:                          22
# Covariance Type:                  HC3
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.1718      0.019      8.943      0.000       0.134       0.209
# C(Major_Group_Code)[T.13-0000]     0.0945      0.029      3.306      0.001       0.038       0.151
# C(Major_Group_Code)[T.15-0000]     0.1123      0.029      3.914      0.000       0.056       0.168
# C(Major_Group_Code)[T.17-0000]     0.0163      0.022      0.745      0.456      -0.027       0.059
# C(Major_Group_Code)[T.19-0000]     0.1080      0.026      4.125      0.000       0.057       0.159
# C(Major_Group_Code)[T.21-0000]     0.0373      0.021      1.784      0.074      -0.004       0.078
# C(Major_Group_Code)[T.23-0000]    -0.0826      0.041     -1.998      0.046      -0.164      -0.002
# C(Major_Group_Code)[T.25-0000]    -0.0007      0.023     -0.030      0.976      -0.045       0.044
# C(Major_Group_Code)[T.27-0000]     0.0003      0.040      0.007      0.994      -0.077       0.078
# C(Major_Group_Code)[T.29-0000]    -0.0585      0.018     -3.254      0.001      -0.094      -0.023
# C(Major_Group_Code)[T.31-0000]    -0.1203      0.023     -5.245      0.000      -0.165      -0.075
# C(Major_Group_Code)[T.33-0000]    -0.0532      0.023     -2.289      0.022      -0.099      -0.008
# C(Major_Group_Code)[T.35-0000]    -0.1232      0.024     -5.150      0.000      -0.170      -0.076
# C(Major_Group_Code)[T.37-0000]    -0.1475      0.022     -6.699      0.000      -0.191      -0.104
# C(Major_Group_Code)[T.39-0000]    -0.0178      0.034     -0.519      0.604      -0.085       0.049
# C(Major_Group_Code)[T.41-0000]     0.1097      0.039      2.811      0.005       0.033       0.186
# C(Major_Group_Code)[T.43-0000]     0.0825      0.032      2.603      0.009       0.020       0.145
# C(Major_Group_Code)[T.45-0000]    -0.1660      0.020     -8.444      0.000      -0.204      -0.127
# C(Major_Group_Code)[T.47-0000]    -0.1713      0.014    -12.289      0.000      -0.199      -0.144
# C(Major_Group_Code)[T.49-0000]    -0.1160      0.020     -5.907      0.000      -0.155      -0.078
# C(Major_Group_Code)[T.51-0000]    -0.1706      0.014    -12.048      0.000      -0.198      -0.143
# C(Major_Group_Code)[T.53-0000]    -0.1549      0.016     -9.771      0.000      -0.186      -0.124
# num_unique_tasks                   0.0007      0.001      0.841      0.400      -0.001       0.002
# ==============================================================================
# Omnibus:                      271.577   Durbin-Watson:                   1.564
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1314.128
# Skew:                           1.412   Prob(JB):                    4.37e-286
# Kurtosis:                       8.451   Cond. No.                         330.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# human_beta ~ num_unique_tasks   (baseline)   n=837
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             human_beta   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     17.95
# Date:                Mon, 27 Oct 2025   Prob (F-statistic):           2.53e-05
# Time:                        13:12:19   Log-Likelihood:                 100.98
# No. Observations:                 837   AIC:                            -198.0
# Df Residuals:                     835   BIC:                            -188.5
# Df Model:                           1
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.2226      0.020     11.139      0.000       0.183       0.262
# num_unique_tasks     0.0049      0.001      4.236      0.000       0.003       0.007
# ==============================================================================
# Omnibus:                       49.886   Durbin-Watson:                   0.553
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.300
# Skew:                           0.430   Prob(JB):                     4.82e-09
# Kurtosis:                       2.400   Cond. No.                         42.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# human_beta ~ num_unique_tasks + C(Major_Group_Code)   (FE)   n=837
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             human_beta   R-squared:                       0.660
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     124.2
# Date:                Mon, 27 Oct 2025   Prob (F-statistic):          2.31e-242
# Time:                        13:12:19   Log-Likelihood:                 543.23
# No. Observations:                 837   AIC:                            -1040.
# Df Residuals:                     814   BIC:                            -931.7
# Df Model:                          22
# Covariance Type:                  HC3
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.4192      0.020     21.171      0.000       0.380       0.458
# C(Major_Group_Code)[T.13-0000]     0.0999      0.027      3.708      0.000       0.047       0.153
# C(Major_Group_Code)[T.15-0000]     0.1684      0.020      8.479      0.000       0.130       0.207
# C(Major_Group_Code)[T.17-0000]     0.0054      0.020      0.268      0.788      -0.034       0.045
# C(Major_Group_Code)[T.19-0000]     0.0693      0.025      2.731      0.006       0.020       0.119
# C(Major_Group_Code)[T.21-0000]    -0.0675      0.029     -2.319      0.020      -0.125      -0.010
# C(Major_Group_Code)[T.23-0000]    -0.0061      0.047     -0.128      0.898      -0.099       0.087
# C(Major_Group_Code)[T.25-0000]    -0.0725      0.028     -2.554      0.011      -0.128      -0.017
# C(Major_Group_Code)[T.27-0000]    -0.0587      0.040     -1.479      0.139      -0.137       0.019
# C(Major_Group_Code)[T.29-0000]    -0.1481      0.021     -7.105      0.000      -0.189      -0.107
# C(Major_Group_Code)[T.31-0000]    -0.2930      0.028    -10.633      0.000      -0.347      -0.239
# C(Major_Group_Code)[T.33-0000]    -0.1398      0.025     -5.673      0.000      -0.188      -0.091
# C(Major_Group_Code)[T.35-0000]    -0.3122      0.030    -10.289      0.000      -0.372      -0.253
# C(Major_Group_Code)[T.37-0000]    -0.3212      0.048     -6.625      0.000      -0.416      -0.226
# C(Major_Group_Code)[T.39-0000]    -0.1877      0.035     -5.436      0.000      -0.255      -0.120
# C(Major_Group_Code)[T.41-0000]     0.0694      0.032      2.202      0.028       0.008       0.131
# C(Major_Group_Code)[T.43-0000]     0.0548      0.030      1.828      0.068      -0.004       0.114
# C(Major_Group_Code)[T.45-0000]    -0.3201      0.031    -10.223      0.000      -0.381      -0.259
# C(Major_Group_Code)[T.47-0000]    -0.3792      0.017    -22.365      0.000      -0.412      -0.346
# C(Major_Group_Code)[T.49-0000]    -0.3217      0.020    -15.968      0.000      -0.361      -0.282
# C(Major_Group_Code)[T.51-0000]    -0.3523      0.016    -22.442      0.000      -0.383      -0.322
# C(Major_Group_Code)[T.53-0000]    -0.2735      0.022    -12.280      0.000      -0.317      -0.230
# num_unique_tasks                   0.0009      0.001      1.016      0.310      -0.001       0.002
# ==============================================================================
# Omnibus:                       56.551   Durbin-Watson:                   1.475
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              137.459
# Skew:                           0.368   Prob(JB):                     1.42e-30
# Kurtosis:                       4.844   Cond. No.                         330.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# human_gamma ~ num_unique_tasks   (baseline)   n=837
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            human_gamma   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     17.43
# Date:                Mon, 27 Oct 2025   Prob (F-statistic):           3.29e-05
# Time:                        13:12:19   Log-Likelihood:                -194.99
# No. Observations:                 837   AIC:                             394.0
# Df Residuals:                     835   BIC:                             403.4
# Df Model:                           1
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.3484      0.028     12.282      0.000       0.293       0.404
# num_unique_tasks     0.0069      0.002      4.175      0.000       0.004       0.010
# ==============================================================================
# Omnibus:                      365.265   Durbin-Watson:                   0.563
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.795
# Skew:                           0.178   Prob(JB):                     2.54e-11
# Kurtosis:                       1.872   Cond. No.                         42.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# human_gamma ~ num_unique_tasks + C(Major_Group_Code)   (FE)   n=837
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            human_gamma   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.667
# Method:                 Least Squares   F-statistic:                     138.7
# Date:                Mon, 27 Oct 2025   Prob (F-statistic):          1.52e-257
# Time:                        13:12:19   Log-Likelihood:                 268.55
# No. Observations:                 837   AIC:                            -491.1
# Df Residuals:                     814   BIC:                            -382.3
# Df Model:                          22
# Covariance Type:                  HC3
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.6666      0.028     23.594      0.000       0.611       0.722
# C(Major_Group_Code)[T.13-0000]     0.1054      0.036      2.928      0.003       0.035       0.176
# C(Major_Group_Code)[T.15-0000]     0.2246      0.025      9.060      0.000       0.176       0.273
# C(Major_Group_Code)[T.17-0000]    -0.0054      0.029     -0.188      0.851      -0.062       0.051
# C(Major_Group_Code)[T.19-0000]     0.0306      0.032      0.950      0.342      -0.033       0.094
# C(Major_Group_Code)[T.21-0000]    -0.1724      0.045     -3.839      0.000      -0.260      -0.084
# C(Major_Group_Code)[T.23-0000]     0.0705      0.082      0.855      0.392      -0.091       0.232
# C(Major_Group_Code)[T.25-0000]    -0.1443      0.041     -3.562      0.000      -0.224      -0.065
# C(Major_Group_Code)[T.27-0000]    -0.1178      0.052     -2.247      0.025      -0.221      -0.015
# C(Major_Group_Code)[T.29-0000]    -0.2376      0.031     -7.768      0.000      -0.298      -0.178
# C(Major_Group_Code)[T.31-0000]    -0.4658      0.038    -12.377      0.000      -0.540      -0.392
# C(Major_Group_Code)[T.33-0000]    -0.2263      0.038     -5.883      0.000      -0.302      -0.151
# C(Major_Group_Code)[T.35-0000]    -0.5011      0.045    -11.086      0.000      -0.590      -0.413
# C(Major_Group_Code)[T.37-0000]    -0.4949      0.079     -6.269      0.000      -0.650      -0.340
# C(Major_Group_Code)[T.39-0000]    -0.3575      0.041     -8.768      0.000      -0.437      -0.278
# C(Major_Group_Code)[T.41-0000]     0.0291      0.046      0.637      0.524      -0.061       0.119
# C(Major_Group_Code)[T.43-0000]     0.0271      0.039      0.693      0.488      -0.050       0.104
# C(Major_Group_Code)[T.45-0000]    -0.4742      0.058     -8.118      0.000      -0.589      -0.360
# C(Major_Group_Code)[T.47-0000]    -0.5871      0.027    -22.019      0.000      -0.639      -0.535
# C(Major_Group_Code)[T.49-0000]    -0.5274      0.027    -19.673      0.000      -0.580      -0.475
# C(Major_Group_Code)[T.51-0000]    -0.5340      0.024    -21.825      0.000      -0.582      -0.486
# C(Major_Group_Code)[T.53-0000]    -0.3922      0.038    -10.446      0.000      -0.466      -0.319
# num_unique_tasks                   0.0010      0.001      0.901      0.367      -0.001       0.003
# ==============================================================================
# Omnibus:                       16.497   Durbin-Watson:                   1.585
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.584
# Skew:                          -0.043   Prob(JB):                     2.28e-07
# Kurtosis:                       3.933   Cond. No.                         330.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# ✓ Saved regression summary to: ../data/computed_objects/GPT_aiExposure/regressions_exposure_on_num_tasks_withFE.csv

# %% [markdown]
# ## Use Occupation-level AI Exposure Measures to Calculate Industry Group Exposure

# %%
# Create and save industry group-level exposure datasets (Major, Minor, Broad, Detailed)
import os
print('Creating industry group-level exposure datasets and saving to data/industryGroup_exposure')
group_levels = [
    ('Major_Group_Code', 'Major_Group_Title'),
    ('Minor_Group_Code', 'Minor_Group_Title'),
    ('Broad_Occupation_Code', 'Broad_Occupation_Title'),
    ('Detailed_Occupation_Code', 'Detailed_Occupation_Title')
]
exposure_cols = [
    'gpt4_alpha', 'gpt4_beta', 'gpt4_gamma',
    'human_alpha', 'human_beta', 'human_gamma'
]
output_dir = f'{output_data_path}/industryGroup_exposure'
os.makedirs(output_dir, exist_ok=True)
for code_col, title_col in group_levels:
    # Build occupation-level mapping and ensure num_unique_tasks present
    # exposure_scores_occupation already contains num_unique_tasks and ONET hierarchy columns
    agg_funcs = {col: 'mean' for col in exposure_cols}
    agg_funcs.update({'O*NET-SOC Code': 'nunique', 'num_unique_tasks': 'sum'})
    group_df = exposure_scores_occupation.groupby([code_col, title_col]).agg(agg_funcs).reset_index()
    group_df = group_df.rename(columns={'O*NET-SOC Code': 'num_unique_occupations'})
    # Save dataset to data folder
    out_file = f'{output_dir}/{code_col}_exposure.csv'
    group_df.to_csv(out_file, index=False)
    print(f'✓ Saved {code_col} exposure dataset to: {out_file}')
    display(group_df.head())
# Out:
# Creating industry group-level exposure datasets and saving to data/industryGroup_exposure
# ✓ Saved Major_Group_Code exposure dataset to: ../data/computed_objects/GPT_aiExposure/industryGroup_exposure/Major_Group_Code_exposure.csv
#   Major_Group_Code                               Major_Group_Title  \
# 0          11-0000                          Management Occupations
# 1          13-0000   Business and Financial Operations Occupations
# 2          15-0000           Computer and Mathematical Occupations
# 3          17-0000        Architecture and Engineering Occupations
# 4          19-0000  Life, Physical, and Social Science Occupations
#
#    gpt4_alpha  gpt4_beta  gpt4_gamma  human_alpha  human_beta  human_gamma  \
# 0        0.07       0.47        0.86         0.18        0.43         0.68
# 1        0.16       0.54        0.93         0.28        0.53         0.79
# 2        0.50       0.74        0.97         0.30        0.60         0.91
# 3        0.17       0.50        0.84         0.20        0.44         0.68
# 4        0.13       0.47        0.80         0.29        0.50         0.71
#
#    num_unique_occupations  num_unique_tasks
# 0                      50               843
# 1                      43               675
# 2                      29               547
# 3                      55               903
# 4                      57               869
# ✓ Saved Minor_Group_Code exposure dataset to: ../data/computed_objects/GPT_aiExposure/industryGroup_exposure/Minor_Group_Code_exposure.csv
#   Minor_Group_Code                                  Minor_Group_Title  \
# 0          11-1000                                     Top Executives
# 1          11-2000  Advertising, Marketing, Promotions, Public Rel...
# 2          11-3000                    Operations Specialties Managers
# 3          11-9000                       Other Management Occupations
# 4          13-1000                    Business Operations Specialists
#
#    gpt4_alpha  gpt4_beta  gpt4_gamma  human_alpha  human_beta  human_gamma  \
# 0        0.09       0.51        0.93         0.13        0.38         0.64
# 1        0.03       0.49        0.95         0.21        0.54         0.87
# 2        0.06       0.45        0.85         0.15        0.41         0.66
# 3        0.06       0.43        0.80         0.19        0.40         0.61
# 4        0.15       0.52        0.89         0.26        0.47         0.69
#
#    num_unique_occupations  num_unique_tasks
# 0                       3                46
# 1                       3                38
# 2                      14               220
# 3                      10               170
# 4                      20               302
# ✓ Saved Broad_Occupation_Code exposure dataset to: ../data/computed_objects/GPT_aiExposure/industryGroup_exposure/Broad_Occupation_Code_exposure.csv
#   Broad_Occupation_Code                           Broad_Occupation_Title  \
# 0               11-1010                                 Chief Executives
# 1               11-1020                  General and Operations Managers
# 2               11-2010              Advertising and Promotions Managers
# 3               11-2020                     Marketing and Sales Managers
# 4               11-3010  Administrative Services and Facilities Managers
#
#    gpt4_alpha  gpt4_beta  gpt4_gamma  human_alpha  human_beta  human_gamma  \
# 0        0.14       0.51        0.89         0.13        0.38         0.62
# 1        0.00       0.50        1.00         0.11        0.39         0.67
# 2        0.00       0.50        1.00         0.38        0.62         0.85
# 3        0.04       0.48        0.92         0.12        0.50         0.88
# 4        0.00       0.30        0.60         0.20        0.50         0.80
#
#    num_unique_occupations  num_unique_tasks
# 0                       2                37
# 1                       1                 9
# 2                       1                13
# 3                       2                25
# 4                       1                 5
# ✓ Saved Detailed_Occupation_Code exposure dataset to: ../data/computed_objects/GPT_aiExposure/industryGroup_exposure/Detailed_Occupation_Code_exposure.csv
#   Detailed_Occupation_Code            Detailed_Occupation_Title  gpt4_alpha  \
# 0                  11-1011                     Chief Executives        0.14
# 1                  11-1021      General and Operations Managers        0.00
# 2                  11-2011  Advertising and Promotions Managers        0.00
# 3                  11-2021                   Marketing Managers        0.08
# 4                  11-2022                       Sales Managers        0.00
#
#    gpt4_beta  gpt4_gamma  human_alpha  human_beta  human_gamma  \
# 0       0.51        0.89         0.13        0.38         0.62
# 1       0.50        1.00         0.11        0.39         0.67
# 2       0.50        1.00         0.38        0.62         0.85
# 3       0.50        0.92         0.17        0.54         0.92
# 4       0.46        0.92         0.08        0.46         0.85
#
#    num_unique_occupations  num_unique_tasks
# 0                       2                37
# 1                       1                 9
# 2                       1                13
# 3                       1                12
# 4                       1                13

# %%
# Plot 2x3 figures for each industry group: exposure vs unique tasks, and exposure vs unique occupations
import matplotlib.pyplot as plt
import numpy as np

group_levels = [
    ('Major_Group_Code', 'Major_Group_Title'),
    ('Minor_Group_Code', 'Minor_Group_Title'),
    ('Broad_Occupation_Code', 'Broad_Occupation_Title'),
    ('Detailed_Occupation_Code', 'Detailed_Occupation_Title')
]
exposure_cols = [
    'gpt4_alpha', 'gpt4_beta', 'gpt4_gamma',
    'human_alpha', 'human_beta', 'human_gamma'
]

# Create mapping for cleaner labels
exposure_labels = {
    'gpt4_alpha': 'GPT-4 AI Exposure (ALPHA)',
    'gpt4_beta': 'GPT-4 AI Exposure (BETA)',
    'gpt4_gamma': 'GPT-4 AI Exposure (GAMMA)',
    'human_alpha': 'Human AI Exposure (ALPHA)',
    'human_beta': 'Human AI Exposure (BETA)',
    'human_gamma': 'Human AI Exposure (GAMMA)'
}

input_dir = f'{output_data_path}/industryGroup_exposure'
output_dir = f'{output_plot_path}/industryGroup_exposure'
os.makedirs(output_dir, exist_ok=True)

# Try to load the saved industry-group regression results (contains baseline and FE slopes)
reg_fp = f'{output_data_path}/regressions_industryGroup_exposure_byGroupLevel.csv'
try:
    reg_df = pd.read_csv(reg_fp)
    reg_df.columns = reg_df.columns.astype(str)
except Exception:
    reg_df = None

for code_col, title_col in group_levels:
    df = pd.read_csv(f'{input_dir}/{code_col}_exposure.csv')
    # 2x3: exposure vs num_unique_tasks -> now plot tasks on x, exposure on y
    fig, axes = plt.subplots(2, 3, figsize=(20, 10), sharex=False, sharey=False)
    for i, col in enumerate(exposure_cols):
        ax = axes[i//3, i%3]
        x = df['num_unique_tasks'].astype(float)
        y = df[col].astype(float)
        ax.scatter(x, y, alpha=0.05, color='steelblue', edgecolors='white')
        # Binned overlay
        n_bins = 12
        try:
            bins = pd.cut(x, bins=n_bins)
        except Exception:
            bins = pd.qcut(x, q=min(n_bins, x.nunique()), duplicates='drop')
        bin_stats = (
            df
            .assign(bin=bins)
            .groupby('bin')
            .agg(task_count_mean=('num_unique_tasks', 'mean'),
                 exposure_mean=(col, 'mean'),
                 count=('num_unique_tasks', 'size'))
            .reset_index()
        )
        base_marker_scale = 40
        bin_marker_sizes = np.clip(np.sqrt(bin_stats['count']) * base_marker_scale, 20, 200)
        ax.scatter(bin_stats['task_count_mean'], bin_stats['exposure_mean'], s=bin_marker_sizes, color='steelblue', alpha=0.9, edgecolors='k', label='Binned means')

        valid_mask = (~np.isnan(x)) & (~np.isnan(y))
        if valid_mask.sum() > 1:
            coeffs = np.polyfit(x[valid_mask], y[valid_mask], 1)
            x_fit = np.linspace(x[valid_mask].min(), x[valid_mask].max(), 100)
            y_fit = coeffs[0] * x_fit + coeffs[1]
            ax.plot(x_fit, y_fit, color='black', linestyle='--', linewidth=2, label=f'slope={coeffs[0]:.2e}')
            # If we have the saved regression results, plot the FE (major) slope from that table
            if reg_df is not None:
                try:
                    row = reg_df.loc[(reg_df['group_level'] == code_col) & (reg_df['exposure'] == col) & (reg_df['regressed_on'] == 'num_unique_tasks') & (reg_df['spec'] == 'fe_major')]
                    if len(row) > 0:
                        slope_fe = float(row['coef'].iloc[0])
                        if not np.isnan(slope_fe):
                            overall_mean_x = x.mean()
                            overall_mean_y = y.mean()
                            intercept_fe = overall_mean_y - slope_fe * overall_mean_x
                            x_fit_fe = np.linspace(x[valid_mask].min(), x[valid_mask].max(), 100)
                            y_fit_fe = intercept_fe + slope_fe * x_fit_fe
                            ax.plot(x_fit_fe, y_fit_fe, color='#FFD966', linestyle='-', linewidth=2, label=f'FE(slope={slope_fe:.2e})')
                except Exception:
                    pass
            ax.legend()
        ax.set_xlabel('Number of Unique Tasks')
        # Show the exposure measure on each subplot's y-axis
        ax.set_ylabel(exposure_labels.get(col, col))
        ax.set_title(f'{code_col}: Exposure vs Unique Tasks')
        ax.grid(True, alpha=0.3)
        # Ensure y-axis range covers 0..1 with a small margin for visualization (exposure axis)
        ax.set_ylim(-0.02, 1.02)
    plt.tight_layout()
    plot_file = f'{output_dir}/tasks_vs_exposure_{code_col}.png'
    plt.savefig(plot_file, dpi=300, bbox_inches='tight')
    plt.show()
    print(f'✓ Saved {code_col} exposure vs tasks plot to: {plot_file}')

    # 2x3: exposure vs num_unique_occupations -> now plot occupations on x, exposure on y
    fig, axes = plt.subplots(2, 3, figsize=(20, 10), sharex=False, sharey=False)
    for i, col in enumerate(exposure_cols):
        ax = axes[i//3, i%3]
        x = df['num_unique_occupations'].astype(float)
        y = df[col].astype(float)
        ax.scatter(x, y, alpha=0.05, color='indianred', edgecolors='white')

        # Binned overlay
        n_bins = 12
        try:
            bins = pd.cut(x, bins=n_bins)
        except Exception:
            bins = pd.qcut(x, q=min(n_bins, x.nunique()), duplicates='drop')
        bin_stats = (
            df
            .assign(bin=bins)
            .groupby('bin')
            .agg(task_count_mean=('num_unique_occupations', 'mean'),
                 exposure_mean=(col, 'mean'),
                 count=('num_unique_occupations', 'size'))
            .reset_index()
        )
        bin_marker_sizes = np.clip(np.sqrt(bin_stats['count']) * base_marker_scale, 20, 200)
        ax.scatter(bin_stats['task_count_mean'], bin_stats['exposure_mean'], s=bin_marker_sizes, color='indianred', alpha=0.9, edgecolors='k', label='Binned means')

        valid_mask = (~np.isnan(x)) & (~np.isnan(y))
        if valid_mask.sum() > 1:
            coeffs = np.polyfit(x[valid_mask], y[valid_mask], 1)
            x_fit = np.linspace(x[valid_mask].min(), x[valid_mask].max(), 100)
            y_fit = coeffs[0] * x_fit + coeffs[1]
            ax.plot(x_fit, y_fit, color='black', linestyle='--', linewidth=2, label=f'slope={coeffs[0]:.2e}')
            # Add FE line from saved regression results (num_unique_occupations)
            if reg_df is not None:
                try:
                    row = reg_df.loc[(reg_df['group_level'] == code_col) & (reg_df['exposure'] == col) & (reg_df['regressed_on'] == 'num_unique_occupations') & (reg_df['spec'] == 'fe_major')]
                    if len(row) > 0:
                        slope_fe = float(row['coef'].iloc[0])
                        if not np.isnan(slope_fe):
                            overall_mean_x = x.mean()
                            overall_mean_y = y.mean()
                            intercept_fe = overall_mean_y - slope_fe * overall_mean_x
                            x_fit_fe = np.linspace(x[valid_mask].min(), x[valid_mask].max(), 100)
                            y_fit_fe = intercept_fe + slope_fe * x_fit_fe
                            ax.plot(x_fit_fe, y_fit_fe, color='#FFD966', linestyle='-', linewidth=2, label=f'FE(slope={slope_fe:.2e})')
                except Exception:
                    pass
            ax.legend()
        # x is number of unique occupations, y is the exposure measure
        ax.set_xlabel('Number of Unique Occupations')
        ax.set_ylabel(exposure_labels.get(col, col))
        ax.set_title(f'{code_col}: Exposure vs Unique Occupations')
        ax.grid(True, alpha=0.3)
        ax.set_ylim(-0.02, 1.02)
    plt.tight_layout()
    plot_file = f'{output_dir}/occupations_vs_exposure_{code_col}.png'
    plt.savefig(plot_file, dpi=300, bbox_inches='tight')
    plt.show()
    print(f'✓ Saved {code_col} exposure vs occupations plot to: {plot_file}')
# Out:
# ✓ Saved Major_Group_Code exposure vs tasks plot to: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/tasks_vs_exposure_Major_Group_Code.png
# ✓ Saved Major_Group_Code exposure vs occupations plot to: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/occupations_vs_exposure_Major_Group_Code.png
# ✓ Saved Minor_Group_Code exposure vs tasks plot to: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/tasks_vs_exposure_Minor_Group_Code.png
# ✓ Saved Minor_Group_Code exposure vs occupations plot to: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/occupations_vs_exposure_Minor_Group_Code.png
# ✓ Saved Broad_Occupation_Code exposure vs tasks plot to: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/tasks_vs_exposure_Broad_Occupation_Code.png
# ✓ Saved Broad_Occupation_Code exposure vs occupations plot to: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/occupations_vs_exposure_Broad_Occupation_Code.png
# ✓ Saved Detailed_Occupation_Code exposure vs tasks plot to: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/tasks_vs_exposure_Detailed_Occupation_Code.png
# ✓ Saved Detailed_Occupation_Code exposure vs occupations plot to: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/occupations_vs_exposure_Detailed_Occupation_Code.png

# %%
# Run regressions on industry-group level CSVs: baseline and Major fixed-effects
# For each exposure: regress on num_unique_tasks (one set) and num_unique_occupations (separate set).
# Results saved to: output_data_path/regressions_industryGroup_exposure_byGroupLevel.csv
import statsmodels.api as sm
import statsmodels.formula.api as smf

results = []
print('\nRunning industry-group level regressions for exposure measures...')
for code_col, title_col in group_levels:
    fp = f'{input_dir}/{code_col}_exposure.csv'
    if not os.path.exists(fp):
        print(f'Skipping {code_col} (file not found: {fp})')
        continue
    df = pd.read_csv(fp)
    # Ensure Major_Group_Code exists; if not, construct it from the group code by taking first two chars
    if 'Major_Group_Code' not in df.columns:
        # safe conversion to string then take first two characters (matches ONET Major grouping)
        df['Major_Group_Code'] = df[code_col].astype(str).str[:2]

    for exposure in exposure_cols:
        if exposure not in df.columns:
            print(f'Skipping {exposure} for {code_col}: column not found')
            continue
        # two separate regressions: on num_unique_tasks and on num_unique_occupations
        for num_var in ['num_unique_tasks', 'num_unique_occupations']:
            if num_var not in df.columns:
                print(f'Skipping regressions on {num_var} for {code_col}: column not found')
                continue
            # prepare regression dataframe and drop missing
            df_reg = df[[exposure, num_var, 'Major_Group_Code']].dropna()
            n = len(df_reg)
            if n == 0:
                print(f'No rows for {exposure} ~ {num_var} in {code_col}')
                continue
            # Baseline: intercept + num_var
            try:
                X = sm.add_constant(df_reg[num_var].astype(float))
                y = df_reg[exposure].astype(float)
                model_base = sm.OLS(y, X).fit(cov_type='HC3')
                coef = model_base.params.get(num_var, float('nan'))
                se = model_base.bse.get(num_var, float('nan'))
                pval = model_base.pvalues.get(num_var, float('nan'))
                r2 = model_base.rsquared
            except Exception as e:
                print(f'Baseline regression failed for {exposure} on {num_var} in {code_col}: {e}')
                coef = se = pval = r2 = float('nan')

            results.append({
                'group_level': code_col,
                'group_title_col': title_col,
                'exposure': exposure,
                'regressed_on': num_var,
                'spec': 'baseline',
                'n': n,
                'coef': coef,
                'se': se,
                'pval': pval,
                'r2': r2
            })

            # Fixed effects by Major_Group_Code
            try:
                formula = f"{exposure} ~ {num_var} + C(Major_Group_Code)"
                model_fe = smf.ols(formula, data=df_reg).fit(cov_type='HC3')
                coef = model_fe.params.get(num_var, float('nan'))
                se = model_fe.bse.get(num_var, float('nan'))
                pval = model_fe.pvalues.get(num_var, float('nan'))
                r2 = model_fe.rsquared
            except Exception as e:
                print(f'FE regression failed for {exposure} on {num_var} in {code_col}: {e}')
                coef = se = pval = r2 = float('nan')

            results.append({
                'group_level': code_col,
                'group_title_col': title_col,
                'exposure': exposure,
                'regressed_on': num_var,
                'spec': 'fe_major',
                'n': n,
                'coef': coef,
                'se': se,
                'pval': pval,
                'r2': r2
            })

# Save results summary
res_df = pd.DataFrame(results)
out_fp = f"{output_data_path}/regressions_industryGroup_exposure_byGroupLevel.csv"
res_df.to_csv(out_fp, index=False)
print(f'\n✓ Saved industry-group regression summary to: {out_fp}')
# Out:
# Running industry-group level regressions for exposure measures...
#
# ✓ Saved industry-group regression summary to: ../data/computed_objects/GPT_aiExposure/regressions_industryGroup_exposure_byGroupLevel.csv
#
# ✓ Saved industry-group regression summary to: ../data/computed_objects/GPT_aiExposure/regressions_industryGroup_exposure_byGroupLevel.csv

# %% [markdown]
# ### Plot Previous Graphs but Highlight Industries One by One for Visual Insight

# %%
# Highlight each industry group one-by-one using Major groups as the driver for highlights
# Build a mapping from Major -> { minor: [...], broad: [...], detailed: [...], label: 'Major title' }
# Save plots under: output_plot_path/industryGroup_exposure/industry/<code_col>/
import os
import matplotlib.pyplot as plt
import numpy as np

# Config
group_levels = [
    ('Major_Group_Code', 'Major_Group_Title'),
    ('Minor_Group_Code', 'Minor_Group_Title'),
    ('Broad_Occupation_Code', 'Broad_Occupation_Title'),
    ('Detailed_Occupation_Code', 'Detailed_Occupation_Title')
]
exposure_cols = [
    'gpt4_alpha', 'gpt4_beta', 'gpt4_gamma',
    'human_alpha', 'human_beta', 'human_gamma'
]

# Create mapping for cleaner x-axis labels (keeps consistent style with earlier plots)
exposure_labels = {
    'gpt4_alpha': 'GPT-4 AI Exposure (ALPHA)',
    'gpt4_beta': 'GPT-4 AI Exposure (BETA)',
    'gpt4_gamma': 'GPT-4 AI Exposure (GAMMA)',
    'human_alpha': 'Human AI Exposure (ALPHA)',
    'human_beta': 'Human AI Exposure (BETA)',
    'human_gamma': 'Human AI Exposure (GAMMA)'
}

# Input group-level CSVs (created earlier)
input_dir = f'{output_data_path}/industryGroup_exposure'
# Save into the requested path (with an 'industry' folder)
industry_root = f'{output_plot_path}/industryGroup_exposure/industry'
os.makedirs(industry_root, exist_ok=True)

# Helper to sanitize filenames
def _safe_name(s):
    return str(s).replace('/', '_').replace(' ', '_')

# Highlight color (yellow-ish)
highlight_color = '#FFD966'  # warm yellow

# Build mapping from the detailed occupation-level dataset (exposure_scores_occupation) if present
major_mapping = {}
if 'exposure_scores_occupation' in globals():
    df_occ = exposure_scores_occupation.copy()
    if 'Major_Group_Code' in df_occ.columns:
        for maj, g in df_occ.groupby('Major_Group_Code'):
            # capture an authoritative Major title when available
            maj_titles = g['Major_Group_Title'].dropna().unique().tolist() if 'Major_Group_Title' in g.columns else []
            major_mapping[maj] = {
                'minor': g['Minor_Group_Code'].dropna().unique().tolist() if 'Minor_Group_Code' in g.columns else [],
                'broad': g['Broad_Occupation_Code'].dropna().unique().tolist() if 'Broad_Occupation_Code' in g.columns else [],
                'detailed': g['Detailed_Occupation_Code'].dropna().unique().tolist() if 'Detailed_Occupation_Code' in g.columns else [],
                'label': maj_titles[0] if maj_titles else None,
            }
    else:
        print("Warning: 'Major_Group_Code' not present in exposure_scores_occupation; mapping will be empty")
else:
    print("Warning: exposure_scores_occupation not found in the notebook environment; mapping will be empty")

# If mapping is empty, try to build a fallback by scanning all group-level CSVs (best-effort)
if not major_mapping:
    for code_col, title_col in group_levels:
        fp = f'{input_dir}/{code_col}_exposure.csv'
        if not os.path.exists(fp):
            continue
        df = pd.read_csv(fp)
        if 'Major_Group_Code' in df.columns:
            for maj, g in df.groupby('Major_Group_Code'):
                if maj not in major_mapping:
                    major_mapping[maj] = {'minor': [], 'broad': [], 'detailed': [], 'label': None}
                # collect codes present in this file for safety
                if 'Minor_Group_Code' in df.columns:
                    major_mapping[maj]['minor'].extend(g['Minor_Group_Code'].dropna().unique().tolist())
                if 'Broad_Occupation_Code' in df.columns:
                    major_mapping[maj]['broad'].extend(g['Broad_Occupation_Code'].dropna().unique().tolist())
                if 'Detailed_Occupation_Code' in df.columns:
                    major_mapping[maj]['detailed'].extend(g['Detailed_Occupation_Code'].dropna().unique().tolist())
                # capture Major title when present
                if 'Major_Group_Title' in df.columns:
                    titles = g['Major_Group_Title'].dropna().unique().tolist()
                    if titles:
                        major_mapping[maj]['label'] = titles[0]
    # dedupe lists
    for maj in list(major_mapping.keys()):
        for k in ['minor', 'broad', 'detailed']:
            major_mapping[maj][k] = list(dict.fromkeys(major_mapping[maj][k]))

if not major_mapping:
    print('Warning: major_mapping is empty after attempts; highlighting will fallback to Major codes present in each file')

# Now iterate over each group-level file and, for each Major group, highlight the bins at that level that belong to the Major
for code_col, title_col in group_levels:
    fp = f'{input_dir}/{code_col}_exposure.csv'
    if not os.path.exists(fp):
        print(f'Skipping {code_col} (file not found: {fp})')
        continue
    df = pd.read_csv(fp)

    out_dir = os.path.join(industry_root, _safe_name(code_col))
    os.makedirs(out_dir, exist_ok=True)

    # Determine the set of majors to iterate (prefer Majors present in this df; fall back to mapping keys)
    majors_in_df = df['Major_Group_Code'].dropna().unique() if 'Major_Group_Code' in df.columns else []
    majors_to_iter = majors_in_df if len(majors_in_df) > 0 else list(major_mapping.keys())

    for major in majors_to_iter:
        # Build mask of rows in df that should be highlighted for this major
        # If we're in Major level, highlight where code equals major
        if code_col == 'Major_Group_Code':
            maj_mask = df[code_col] == major
        else:
            # For non-major levels, use the precomputed mapping where possible
            maj_map_entry = major_mapping.get(major, {})
            if code_col == 'Minor_Group_Code':
                candidates = maj_map_entry.get('minor', [])
            elif code_col == 'Broad_Occupation_Code':
                candidates = maj_map_entry.get('broad', [])
            elif code_col == 'Detailed_Occupation_Code':
                candidates = maj_map_entry.get('detailed', [])
            else:
                candidates = []
            # If candidates are empty, fall back to matching Major_Group_Code column if present
            if candidates:
                maj_mask = df[code_col].isin(candidates)
            elif 'Major_Group_Code' in df.columns:
                maj_mask = df['Major_Group_Code'] == major
            else:
                maj_mask = pd.Series([False] * len(df))

        # label for the major group (for filenames / titles)
        maj_label = None
        # Prefer an explicit Major_Group_Title column in the current file
        if 'Major_Group_Title' in df.columns and (df['Major_Group_Code'] == major).any():
            maj_label = df.loc[df['Major_Group_Code'] == major, 'Major_Group_Title'].iloc[0]
        # Otherwise use the mapping label if available
        if maj_label is None:
            maj_label = major_mapping.get(major, {}).get('label')
        # Final fallback to the raw major code
        maj_label = maj_label or str(major)

        # Build display title showing both code and title when available
        if str(major) != str(maj_label):
            display_title = f"{major}: {maj_label}"
        else:
            display_title = str(major)

        safe_maj = _safe_name(major)

        # --- Plot: exposure vs num_unique_tasks (original underlay + highlighted bins belonging to this major) ---
        fig, axes = plt.subplots(2, 3, figsize=(20, 10), sharex=False, sharey=False)
        for i, col in enumerate(exposure_cols):
            ax = axes[i//3, i%3]
            x = df['num_unique_tasks'].astype(float)
            y = df[col].astype(float)

            # Plot all points using the ORIGINAL styling with faint alpha
            ax.scatter(x, y, alpha=0.05, color='steelblue', edgecolors='white', s=35, zorder=1)

            # Add binned overlay
            n_bins = 12
            try:
                bins = pd.cut(x, bins=n_bins)
            except Exception:
                bins = pd.qcut(x, q=min(n_bins, x.nunique()), duplicates='drop')
            bin_stats = (
                df
                .assign(bin=bins)
                .groupby('bin')
                .agg(task_count_mean=('num_unique_tasks', 'mean'),
                     exposure_mean=(col, 'mean'),
                     count=('num_unique_tasks', 'size'))
                .reset_index()
            )
            base_marker_scale = 60
            bin_marker_sizes = np.clip(np.sqrt(bin_stats['count']) * base_marker_scale, 20, 300)
            ax.scatter(bin_stats['task_count_mean'], bin_stats['exposure_mean'], s=bin_marker_sizes, color='steelblue', alpha=0.9, edgecolors='k', label='Binned means')

            # Overlay highlighted group's (major) bins in yellow; this will highlight bins at the current level that belong to the major
            if maj_mask.any():
                # ensure indices align
                ax.scatter(x[maj_mask], y[maj_mask], alpha=0.95, color=highlight_color, edgecolors='black', s=120, zorder=3)

            # Baseline regression (all points)
            valid_mask = (~np.isnan(x)) & (~np.isnan(y))
            if valid_mask.sum() > 1:
                try:
                    coeffs = np.polyfit(x[valid_mask], y[valid_mask], 1)
                    x_fit = np.linspace(x[valid_mask].min(), x[valid_mask].max(), 100)
                    y_fit = coeffs[0] * x_fit + coeffs[1]
                    ax.plot(x_fit, y_fit, color='black', linestyle='--', linewidth=2, label=f'baseline slope={coeffs[0]:.2e}', zorder=2)
                except Exception:
                    pass

                # FE within-Major if df contains Major_Group_Code
                if 'Major_Group_Code' in df.columns:
                    dfv = df.loc[valid_mask, ['num_unique_tasks', col, 'Major_Group_Code']].dropna()
                    if dfv['Major_Group_Code'].nunique() > 1:
                        x_dev = dfv['num_unique_tasks'] - dfv.groupby('Major_Group_Code')['num_unique_tasks'].transform('mean')
                        y_dev = dfv[col] - dfv.groupby('Major_Group_Code')[col].transform('mean')
                        denom = (x_dev ** 2).sum()
                        if denom > 0:
                            slope_within = (x_dev * y_dev).sum() / denom
                            overall_mean_x = dfv['num_unique_tasks'].mean()
                            overall_mean_y = dfv[col].mean()
                            x_fit_fe = np.linspace(dfv['num_unique_tasks'].min(), dfv['num_unique_tasks'].max(), 100)
                            y_fit_fe = overall_mean_y + slope_within * (x_fit_fe - overall_mean_x)
                            ax.plot(x_fit_fe, y_fit_fe, color='#FFD966', linestyle='-', linewidth=2, label=f'FE slope={slope_within:.2e}', zorder=3)

                # regression line for ALL points (already plotted); show legend
                ax.legend()

            ax.set_xlabel('Number of Unique Tasks')
            # Show exposure measure on each subplot's y-axis
            ax.set_ylabel(exposure_labels.get(col, col))
            # Do not show codes in subplot titles; keep subplots titleless (major shown only as figure title)
            ax.set_title('')
            ax.grid(True, alpha=0.3)
            ax.set_ylim(-0.02, 1.02)

        # Show both Major group code and title as the figure title
        plt.suptitle(display_title, fontsize=16)
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plot_file = os.path.join(out_dir, f'tasks_vs_exposure_{safe_maj}_{code_col}.png')
        plt.savefig(plot_file, dpi=300, bbox_inches='tight')
        plt.close(fig)

        # --- Plot: exposure vs num_unique_occupations (original underlay + highlighted bins belonging to this major) ---
        fig, axes = plt.subplots(2, 3, figsize=(20, 10), sharex=False, sharey=False)
        for i, col in enumerate(exposure_cols):
            ax = axes[i//3, i%3]
            x = df['num_unique_occupations'].astype(float)
            y = df[col].astype(float)

            # Original styling for underlay with faint alpha
            ax.scatter(x, y, alpha=0.05, color='indianred', edgecolors='white', s=35, zorder=1)

            # Add binned overlay
            n_bins = 12
            try:
                bins = pd.cut(x, bins=n_bins)
            except Exception:
                bins = pd.qcut(x, q=min(n_bins, x.nunique()), duplicates='drop')
            bin_stats = (
                df
                .assign(bin=bins)
                .groupby('bin')
                .agg(task_count_mean=('num_unique_occupations', 'mean'),
                     exposure_mean=(col, 'mean'),
                     count=('num_unique_occupations', 'size'))
                .reset_index()
            )
            bin_marker_sizes = np.clip(np.sqrt(bin_stats['count']) * base_marker_scale, 20, 300)
            ax.scatter(bin_stats['task_count_mean'], bin_stats['exposure_mean'], s=bin_marker_sizes, color='indianred', alpha=0.9, edgecolors='k', label='Binned means')

            if maj_mask.any():
                ax.scatter(x[maj_mask], y[maj_mask], alpha=0.95, color=highlight_color, edgecolors='black', s=120, zorder=3)

            valid_mask = (~np.isnan(x)) & (~np.isnan(y))
            if valid_mask.sum() > 1:
                try:
                    coeffs = np.polyfit(x[valid_mask], y[valid_mask], 1)
                    x_fit = np.linspace(x[valid_mask].min(), x[valid_mask].max(), 100)
                    y_fit = coeffs[0] * x_fit + coeffs[1]
                    ax.plot(x_fit, y_fit, color='black', linestyle='--', linewidth=2, label=f'baseline slope={coeffs[0]:.2e}', zorder=2)
                except Exception:
                    pass

                if 'Major_Group_Code' in df.columns:
                    dfv = df.loc[valid_mask, ['num_unique_occupations', col, 'Major_Group_Code']].dropna()
                    if dfv['Major_Group_Code'].nunique() > 1:
                        x_dev = dfv['num_unique_occupations'] - dfv.groupby('Major_Group_Code')['num_unique_occupations'].transform('mean')
                        y_dev = dfv[col] - dfv.groupby('Major_Group_Code')[col].transform('mean')
                        denom = (x_dev ** 2).sum()
                        if denom > 0:
                            slope_within = (x_dev * y_dev).sum() / denom
                            overall_mean_x = dfv['num_unique_occupations'].mean()
                            overall_mean_y = dfv[col].mean()
                            x_fit_fe = np.linspace(dfv['num_unique_occupations'].min(), dfv['num_unique_occupations'].max(), 100)
                            y_fit_fe = overall_mean_y + slope_within * (x_fit_fe - overall_mean_x)
                            ax.plot(x_fit_fe, y_fit_fe, color='#FFD966', linestyle='-', linewidth=2, label=f'FE slope={slope_within:.2e}', zorder=3)

                ax.legend()

            # x is number of unique occupations, y is the exposure measure
            ax.set_xlabel('Number of Unique Occupations')
            ax.set_ylabel(exposure_labels.get(col, col))
            # Subplot titles removed  major title shown only as figure suptitle
            ax.set_title('')
            ax.grid(True, alpha=0.3)
            ax.set_ylim(-0.02, 1.02)

        plt.suptitle(display_title, fontsize=16)
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plot_file = os.path.join(out_dir, f'occupations_vs_exposure_{safe_maj}_{code_col}.png')
        plt.savefig(plot_file, dpi=300, bbox_inches='tight')
        plt.close(fig)

        print(f'\u2713 Saved highlight plots for Major={display_title} under: {out_dir}')
# Out:
# ✓ Saved highlight plots for Major=11-0000: Management Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=13-0000: Business and Financial Operations Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=13-0000: Business and Financial Operations Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=15-0000: Computer and Mathematical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=15-0000: Computer and Mathematical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=17-0000: Architecture and Engineering Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=17-0000: Architecture and Engineering Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=19-0000: Life, Physical, and Social Science Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=19-0000: Life, Physical, and Social Science Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=21-0000: Community and Social Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=21-0000: Community and Social Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=23-0000: Legal Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=23-0000: Legal Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=25-0000: Educational Instruction and Library Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=25-0000: Educational Instruction and Library Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=27-0000: Arts, Design, Entertainment, Sports, and Media Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=27-0000: Arts, Design, Entertainment, Sports, and Media Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=29-0000: Healthcare Practitioners and Technical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=29-0000: Healthcare Practitioners and Technical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=31-0000: Healthcare Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=31-0000: Healthcare Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=33-0000: Protective Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=33-0000: Protective Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=35-0000: Food Preparation and Serving Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=35-0000: Food Preparation and Serving Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=37-0000: Building and Grounds Cleaning and Maintenance Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=37-0000: Building and Grounds Cleaning and Maintenance Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=39-0000: Personal Care and Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=39-0000: Personal Care and Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=41-0000: Sales and Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=41-0000: Sales and Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=43-0000: Office and Administrative Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=43-0000: Office and Administrative Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=45-0000: Farming, Fishing, and Forestry Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=45-0000: Farming, Fishing, and Forestry Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=47-0000: Construction and Extraction Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=47-0000: Construction and Extraction Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=49-0000: Installation, Maintenance, and Repair Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=49-0000: Installation, Maintenance, and Repair Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=51-0000: Production Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=51-0000: Production Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=53-0000: Transportation and Material Moving Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=53-0000: Transportation and Material Moving Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Major_Group_Code
# ✓ Saved highlight plots for Major=11-0000: Management Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=11-0000: Management Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=13-0000: Business and Financial Operations Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=13-0000: Business and Financial Operations Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=15-0000: Computer and Mathematical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=15-0000: Computer and Mathematical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=17-0000: Architecture and Engineering Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=17-0000: Architecture and Engineering Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=19-0000: Life, Physical, and Social Science Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=19-0000: Life, Physical, and Social Science Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=21-0000: Community and Social Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=21-0000: Community and Social Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=23-0000: Legal Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=23-0000: Legal Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=25-0000: Educational Instruction and Library Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=25-0000: Educational Instruction and Library Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=27-0000: Arts, Design, Entertainment, Sports, and Media Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=27-0000: Arts, Design, Entertainment, Sports, and Media Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=29-0000: Healthcare Practitioners and Technical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=29-0000: Healthcare Practitioners and Technical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=31-0000: Healthcare Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=31-0000: Healthcare Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=33-0000: Protective Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=33-0000: Protective Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=35-0000: Food Preparation and Serving Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=35-0000: Food Preparation and Serving Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=37-0000: Building and Grounds Cleaning and Maintenance Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=37-0000: Building and Grounds Cleaning and Maintenance Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=39-0000: Personal Care and Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=39-0000: Personal Care and Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=41-0000: Sales and Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=41-0000: Sales and Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=43-0000: Office and Administrative Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=43-0000: Office and Administrative Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=45-0000: Farming, Fishing, and Forestry Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=45-0000: Farming, Fishing, and Forestry Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=47-0000: Construction and Extraction Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=47-0000: Construction and Extraction Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=49-0000: Installation, Maintenance, and Repair Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=49-0000: Installation, Maintenance, and Repair Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=51-0000: Production Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=51-0000: Production Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=53-0000: Transportation and Material Moving Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=53-0000: Transportation and Material Moving Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Minor_Group_Code
# ✓ Saved highlight plots for Major=11-0000: Management Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=11-0000: Management Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=13-0000: Business and Financial Operations Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=13-0000: Business and Financial Operations Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=15-0000: Computer and Mathematical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=15-0000: Computer and Mathematical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=17-0000: Architecture and Engineering Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=17-0000: Architecture and Engineering Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=19-0000: Life, Physical, and Social Science Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=19-0000: Life, Physical, and Social Science Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=21-0000: Community and Social Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=21-0000: Community and Social Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=23-0000: Legal Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=23-0000: Legal Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=25-0000: Educational Instruction and Library Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=25-0000: Educational Instruction and Library Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=27-0000: Arts, Design, Entertainment, Sports, and Media Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=27-0000: Arts, Design, Entertainment, Sports, and Media Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=29-0000: Healthcare Practitioners and Technical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=29-0000: Healthcare Practitioners and Technical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=31-0000: Healthcare Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=31-0000: Healthcare Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=33-0000: Protective Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=33-0000: Protective Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=35-0000: Food Preparation and Serving Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=35-0000: Food Preparation and Serving Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=37-0000: Building and Grounds Cleaning and Maintenance Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=37-0000: Building and Grounds Cleaning and Maintenance Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=39-0000: Personal Care and Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=39-0000: Personal Care and Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=41-0000: Sales and Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=41-0000: Sales and Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=43-0000: Office and Administrative Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=43-0000: Office and Administrative Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=45-0000: Farming, Fishing, and Forestry Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=45-0000: Farming, Fishing, and Forestry Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=47-0000: Construction and Extraction Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=47-0000: Construction and Extraction Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=49-0000: Installation, Maintenance, and Repair Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=49-0000: Installation, Maintenance, and Repair Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=51-0000: Production Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=51-0000: Production Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=53-0000: Transportation and Material Moving Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=53-0000: Transportation and Material Moving Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Broad_Occupation_Code
# ✓ Saved highlight plots for Major=11-0000: Management Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=11-0000: Management Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=13-0000: Business and Financial Operations Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=13-0000: Business and Financial Operations Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=15-0000: Computer and Mathematical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=15-0000: Computer and Mathematical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=17-0000: Architecture and Engineering Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=17-0000: Architecture and Engineering Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=19-0000: Life, Physical, and Social Science Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=19-0000: Life, Physical, and Social Science Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=21-0000: Community and Social Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=21-0000: Community and Social Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=23-0000: Legal Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=23-0000: Legal Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=25-0000: Educational Instruction and Library Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=25-0000: Educational Instruction and Library Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=27-0000: Arts, Design, Entertainment, Sports, and Media Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=27-0000: Arts, Design, Entertainment, Sports, and Media Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=29-0000: Healthcare Practitioners and Technical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=29-0000: Healthcare Practitioners and Technical Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=31-0000: Healthcare Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=31-0000: Healthcare Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=33-0000: Protective Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=33-0000: Protective Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=35-0000: Food Preparation and Serving Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=35-0000: Food Preparation and Serving Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=37-0000: Building and Grounds Cleaning and Maintenance Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=37-0000: Building and Grounds Cleaning and Maintenance Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=39-0000: Personal Care and Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=39-0000: Personal Care and Service Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=41-0000: Sales and Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=41-0000: Sales and Related Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=43-0000: Office and Administrative Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=43-0000: Office and Administrative Support Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=45-0000: Farming, Fishing, and Forestry Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=45-0000: Farming, Fishing, and Forestry Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=47-0000: Construction and Extraction Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=47-0000: Construction and Extraction Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=49-0000: Installation, Maintenance, and Repair Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=49-0000: Installation, Maintenance, and Repair Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=51-0000: Production Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=51-0000: Production Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=53-0000: Transportation and Material Moving Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
# ✓ Saved highlight plots for Major=53-0000: Transportation and Material Moving Occupations under: ../writeup/plots/GPT_aiExposure/industryGroup_exposure/industry/Detailed_Occupation_Code
