# %% [markdown]
# #### By: Peyman Shahidi
# #### Created: Nov 7, 2025
# #### Last Edit: Nov 7, 2025
#
# <br>

# %%
#Python
import getpass
import numpy as np
import pandas as pd
from collections import defaultdict
import itertools
import random 

## formatting number to appear comma separated and with two digits after decimal: e.g, 1000 shown as 1,000.00
pd.set_option('float_format', "{:,.2f}".format)

import matplotlib.pyplot as plt
#%matplotlib inline
#from matplotlib.legend import Legend

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', 200)

# %%
import subprocess
import os


# Install caffeinate package
# %pip install caffeinate

# Use macOS built-in caffeinate command for reliability
# This prevents the system from sleeping while the process is running
try:
    # Start caffeinate in the background
    caff_process = subprocess.Popen(['caffeinate', '-d'], 
                                   stdout=subprocess.DEVNULL, 
                                   stderr=subprocess.DEVNULL)
    print(f"Caffeinate mode ON ☕ – Device will stay awake (PID: {caff_process.pid})")
    print("System sleep is disabled while this process runs.")
    
    # Store the process ID for later cleanup
    caff_pid = caff_process.pid
    
except Exception as e:
    print(f"⚠️ Could not start caffeinate: {e}")
    print("Continuing without caffeinate - system may sleep during long processes.")
    caff_process = None
    caff_pid = None
# Out:
# Requirement already satisfied: caffeinate in /opt/anaconda3/envs/edsl/lib/python3.12/site-packages (0.1.0)
# Requirement already satisfied: pynput>=1.7.2 in /opt/anaconda3/envs/edsl/lib/python3.12/site-packages (from caffeinate) (1.8.1)
# Requirement already satisfied: six in /opt/anaconda3/envs/edsl/lib/python3.12/site-packages (from pynput>=1.7.2->caffeinate) (1.17.0)
# Requirement already satisfied: pyobjc-framework-ApplicationServices>=8.0 in /opt/anaconda3/envs/edsl/lib/python3.12/site-packages (from pynput>=1.7.2->caffeinate) (12.0)
# Requirement already satisfied: pyobjc-framework-Quartz>=8.0 in /opt/anaconda3/envs/edsl/lib/python3.12/site-packages (from pynput>=1.7.2->caffeinate) (12.0)
# Requirement already satisfied: pyobjc-core>=12.0 in /opt/anaconda3/envs/edsl/lib/python3.12/site-packages (from pyobjc-framework-ApplicationServices>=8.0->pynput>=1.7.2->caffeinate) (12.0)
# Requirement already satisfied: pyobjc-framework-Cocoa>=12.0 in /opt/anaconda3/envs/edsl/lib/python3.12/site-packages (from pyobjc-framework-ApplicationServices>=8.0->pynput>=1.7.2->caffeinate) (12.0)
# Requirement already satisfied: pyobjc-framework-CoreText>=12.0 in /opt/anaconda3/envs/edsl/lib/python3.12/site-packages (from pyobjc-framework-ApplicationServices>=8.0->pynput>=1.7.2->caffeinate) (12.0)
# Note: you may need to restart the kernel to use updated packages.
# Caffeinate mode ON ☕ – Device will stay awake (PID: 46314)
# System sleep is disabled while this process runs.

# %%
main_folder_path = ".."
input_data_path = f"{main_folder_path}/data"
output_data_path = f'{input_data_path}/computed_objects'
output_plot_path = f"{main_folder_path}/writeup/plots"

# %%
# Create directories if they don't exist
import os

for path in [output_data_path, output_plot_path]:
    if not os.path.exists(path):
        os.makedirs(path)

# %%
# Load O*NET data and extract unique occupation titles
ONET = pd.read_csv(f'{output_data_path}/ONET_cleaned_tasks.csv')


# Filter out infrequent tasks
# Infrequent tasks are defined as those which are executed daily or more frequently in >70% of the time.

# Define frequency importance threshold (in %):
freq_importance_threshold = 65

# Filter tasks based on frequency importance threshold
ONET['frequent_task'] = ONET['FT_Daily'] + ONET['FT_Several times daily'] + ONET['FT_Hourly or more']
print(f"Total tasks before filtering: {len(ONET)}")

# Length of ONET for different filtering thresholds:
print("Length of ONET for different frequency importance thresholds:")
for threshold in [50, 60, 70, 80, 90]:
    filtered_ONET = ONET[ONET['frequent_task'] >= threshold]
    print(f"  - Threshold {threshold}%: {len(filtered_ONET)} tasks")


ONET = ONET[ONET['frequent_task'] >= freq_importance_threshold].reset_index(drop=True)
print(f"Total tasks after filtering infrequent ones: {len(ONET)}")
# Out:
# Total tasks before filtering: 22310
# Length of ONET for different frequency importance thresholds:
#   - Threshold 50%: 10234 tasks
#   - Threshold 60%: 8265 tasks
#   - Threshold 70%: 6409 tasks
#   - Threshold 80%: 4456 tasks
#   - Threshold 90%: 2267 tasks
# Total tasks after filtering infrequent ones: 7368

# %%
from edsl import QuestionFreeText, Scenario, Model, Survey
from textwrap import dedent
import json
import os
import pandas as pd
import numpy as np

def extract_task_sequence(occupation, tasks_data, output_data_path):
    """
    Extract task sequence for an occupation using EDSL workflow.
    Returns the ordered sequence of tasks.
    """
    # Check if output file already exists
    safe_title = occupation.replace(" ", "_").replace("/", "_")
    output_folder = f'{output_data_path}/tasks_sequences_frequent'
    output_file = os.path.join(output_folder, f"{safe_title}.csv")
    
    if os.path.exists(output_file):
        return output_file, True  # Return file path and flag indicating it already existed
    
    # Check if we have tasks for this occupation
    if tasks_data.empty:
        print(f"⚠️  Warning: No tasks found for occupation '{occupation}' - skipping")
        return None, True  # Treat as already processed to skip
    
    # Create task mappings
    task_id_mapping = dict(zip(tasks_data['Task Title'], tasks_data['Task ID']))
    soc_code_mapping = dict(zip(tasks_data['Task Title'], tasks_data['O*NET-SOC Code']))
    
    # Format tasks as numbered list
    tasks_list = tasks_data['Task Title'].tolist()
    tasks_text = "\n".join([f"{i}. {task}" for i, task in enumerate(tasks_list, 1)])
    num_tasks = len(tasks_list)
    max_tokens = 32000
    
    print(f"   • {num_tasks} tasks, using {max_tokens} max tokens")

    # Create scenario
    scenario = Scenario({
        "occupation": occupation,
        "tasks_list": tasks_text,
        "num_tasks": num_tasks
    })

    # Create question for task sequencing
    q_sequence = QuestionFreeText(
        question_name="task_sequence",
        question_text=dedent("""\
            You are an expert in workflow analysis for the occupation: {{ occupation }}.
            Below is a list of {{ num_tasks }} tasks that are part of this occupation:
            {{ tasks_list }}
            Provide the typical sequential order in which these tasks are performed in a real-world workflow.
            Return your answer as a JSON array where each element has:
            - "Task Position": the sequence number (1, 2, 3, etc.)
            - "Task Title": the exact task text from the list above
            Format: [{"Task Position": 1, "Task Title": "..."}, {"Task Position": 2, "Task Title": "..."}, ...]
            Only return the JSON array, nothing else.
        """)
    )

    try:
        # Create model using openai_v2 for reasoning capabilities
        model = Model("gpt-5-mini", service_name="openai_v2", temperature=0.0, max_tokens=max_tokens)
        
        # Run sequence question
        sequence_results = q_sequence.by(model).by([scenario]).run(progress_bar=False)
        sequence_df = sequence_results.to_pandas()
        sequence_json = sequence_df['answer.task_sequence'][0]
        
        # Debug: Print the raw response before cleaning
        print(f"   • Raw JSON length: {len(str(sequence_json))}")
        print(f"   • Raw JSON preview: {str(sequence_json)[:50]}...")
        
        # Clean the JSON response by removing markdown code blocks if present
        if isinstance(sequence_json, str):
            # Simple string replacement approach
            cleaned_json = sequence_json
            if '```json' in cleaned_json:
                cleaned_json = cleaned_json.replace('```json', '')
            if '```' in cleaned_json:
                cleaned_json = cleaned_json.replace('```', '')
            sequence_json = cleaned_json.strip()
            print(f"   • Cleaned JSON preview: {sequence_json[:50]}...")
        
        # Check if the response is valid
        if pd.isna(sequence_json) or not isinstance(sequence_json, str):
            print(f"❌ Error: Invalid response for '{occupation}' - got {type(sequence_json)} instead of string")
            return None, True  # Treat as already processed to skip
        
        # Try to parse JSON
        try:
            sequence_data = json.loads(sequence_json)
        except json.JSONDecodeError as e:
            print(f"❌ JSON parsing failed, trying to clean response further...")
            print(f"   Original error: {e}")
            print(f"   Response starts with: {sequence_json[:100]}...")
            # Try additional cleanup
            if sequence_json.startswith('```'):
                lines = sequence_json.split('\n')
                if lines[0].strip() in ['```', '```json']:
                    lines = lines[1:]  # Remove first line
                if lines[-1].strip() == '```':
                    lines = lines[:-1]  # Remove last line
                sequence_json = '\n'.join(lines).strip()
                print(f"   Cleaned response starts with: {sequence_json[:100]}...")
                try:
                    sequence_data = json.loads(sequence_json)
                    print(f"   ✅ Successfully parsed after additional cleanup")
                except json.JSONDecodeError as e2:
                    print(f"   ❌ Still failed after cleanup: {e2}")
                    raise e  # Re-raise original error
            else:
                raise e  # Re-raise original error
                
        ordered_sequence_df = pd.DataFrame(sequence_data)
        
        # Add metadata columns
        ordered_sequence_df['Occupation Title'] = occupation
        ordered_sequence_df['Task ID'] = ordered_sequence_df['Task Title'].map(task_id_mapping)
        ordered_sequence_df['O*NET-SOC Code'] = ordered_sequence_df['Task Title'].map(soc_code_mapping)
        
        # Reorder columns
        ordered_sequence_df = ordered_sequence_df[['Task Position', 'Task Title', 'Task ID', 'O*NET-SOC Code', 'Occupation Title']]

        # Save to file
        os.makedirs(output_folder, exist_ok=True)
        ordered_sequence_df.to_csv(output_file, index=False)
        
        print(f"   ✅ Successfully processed and saved task sequence")
        return output_file, False  # Return file path and flag indicating it was newly created
        
    except json.JSONDecodeError as e:
        print(f"❌ JSON Error for '{occupation}': {e}")
        print(f"   Raw response: {sequence_json}")
        return None, True  # Treat as already processed to skip
    except Exception as e:
        print(f"❌ Unexpected error for '{occupation}': {e}")
        return None, True  # Treat as already processed to skip


# NEW: extract sequence of occupations within a minor SOC group
def extract_occupation_sequence(minor_group_title, occupations_df, output_data_path):
    """
    Given a minor SOC group title (e.g., 'Chief Executives') and a DataFrame of occupations within it (with columns
    'Occupation Title' and 'O*NET-SOC Code'), query the model to provide a typical sequence of occupations
    (e.g., which occupations hand off work to which) within that minor group. Saves a CSV per minor group.

    Note: this prompt intentionally does NOT ask for O*NET-SOC Codes to avoid extra token costs; the CSV
    will contain Position and Occupation Title only. If you want to add SOC codes later, you can merge
    them locally from the ONET dataset.
    """
    safe_title = minor_group_title.replace(',', '')
    safe_title = safe_title.replace(' ', '_')
    output_folder = f'{output_data_path}/occupations_sequences_frequent'
    output_file = os.path.join(output_folder, f"{safe_title}.csv")

    if os.path.exists(output_file):
        return output_file, True

    if occupations_df.empty:
        print(f"⚠️  No occupations found for minor group '{minor_group_title}' - skipping")
        return None, True

    # Create task mappings
    minor_group_mapping = dict(zip(occupations_df['Minor_Group_Title'], occupations_df['Minor_Group_Code']))
    occupation_code_mapping = dict(zip(occupations_df['Occupation Title'], occupations_df['O*NET-SOC Code']))
    
    # build occupations list text
    occ_list = occupations_df[['Occupation Title']].drop_duplicates().reset_index(drop=True)
    occ_text = '\n'.join([f"{i}. {row['Occupation Title']}" for i, row in occ_list.iterrows()])
    num_occs = len(occ_list)

    print(f"   • {num_occs} occupations in minor group {minor_group_title}")

    scenario = Scenario({
        'minor_group': minor_group_title,
        'occupations_list': occ_text,
        'num_occs': num_occs
    })

    q_occ_sequence = QuestionFreeText(
        question_name='occupation_sequence',
        question_text=dedent("""\
            You are an expert on occupational workflows. Below is a list of occupations within the same minor SOC group ({{ minor_group }}):
            {{ occupations_list }}
            Provide the typical sequential order in which these occupations interact or hand off work in a multi-step workflow that involves multiple occupations within this group.
            Return your answer as a JSON array where each element has:
            - "Occupation Position": the sequence number (1, 2, 3, ...)
            - "Occupation Title": the exact occupation title from the list above
            Format: [{"Occupation Position": 1, "Occupation Title": "..."}, ...]
            Only return the JSON array, nothing else.
        """)
    )

    try:
        model = Model("gpt-5-mini", service_name="openai_v2", temperature=0.0, max_tokens=16000)
        res = q_occ_sequence.by(model).by([scenario]).run(progress_bar=False)
        res_df = res.to_pandas()
        res_json = res_df['answer.occupation_sequence'][0]

        if isinstance(res_json, str):
            cleaned = res_json
            if '```json' in cleaned:
                cleaned = cleaned.replace('```json', '')
            if '```' in cleaned:
                cleaned = cleaned.replace('```', '')
            res_json = cleaned.strip()

        seq_data = json.loads(res_json)
        seq_df = pd.DataFrame(seq_data)

        # Keep only Occupation Position and Occupation Title to save tokens; user can merge SOC codes locally later
        if 'Occupation Position' not in seq_df.columns or 'Occupation Title' not in seq_df.columns:
            print('⚠️  Unexpected response format; saving raw parsed dataframe for inspection')

        # Add metadata columns
        seq_df['Minor_Group_Title'] = minor_group_title
        seq_df['Minor_Group_Code'] = seq_df['Minor_Group_Title'].map(minor_group_mapping)
        seq_df['O*NET-SOC Code'] = seq_df['Occupation Title'].map(occupation_code_mapping)
        
        # Reorder columns
        seq_df = seq_df[['Occupation Position', 'Occupation Title', 'O*NET-SOC Code', 'Minor_Group_Code', 'Minor_Group_Code']]

        # Save output
        os.makedirs(output_folder, exist_ok=True)
        seq_df.to_csv(output_file, index=False)
        print(f"   ✅ Saved occupation sequence for {minor_group_title} -> {output_file}")
        return output_file, False
    except Exception as e:
        print(f"❌ Failed to extract occupation sequence for {minor_group_title}: {e}")
        return None, True

# %%
# Get all unique occupation titles from the dataset
occupations_list = sorted(ONET['Occupation Title'].unique().tolist())
print(f"Found {len(occupations_list)} unique occupations in the dataset:")

# Set seed for reproducible random sampling
random.seed(42)
np.random.seed(42)

# # Randomly sample 10% of occupations
# sample_size = max(1, int(len(occupations_list) * 0.10))  # Ensure at least 1 occupation
# sampled_occupations = random.sample(occupations_list, sample_size)
# print(f"Randomly selected {len(sampled_occupations)} occupations (5% of total) for processing:")
# print(f"Sample: {sampled_occupations[:5]}..." if len(sampled_occupations) > 5 else f"Sample: {sampled_occupations}")
sampled_occupations = occupations_list

# Process each occupation
processed_count = 0
skipped_count = 0
error_count = 0



for i, occupation in enumerate(sampled_occupations, 1):
    # Filter data for this occupation
    occupation_data = ONET[ONET['Occupation Title'] == occupation].copy()
    
    # Prepare task data
    occupation_task_data = occupation_data[['Task ID', 'Task Title', 'O*NET-SOC Code']].drop_duplicates().reset_index(drop=True)
    
    # Enhanced progress output
    num_tasks = len(occupation_task_data)
    print(f"\n[{i}/{len(sampled_occupations)}] {occupation}")
    
    # Extract task sequence
    output_file, already_existed = extract_task_sequence(occupation, occupation_task_data, output_data_path)
    
    if output_file is None:
        error_count += 1
    elif already_existed:
        print(f"   ⏭️  Already exists - skipping")
        skipped_count += 1
    else:
        processed_count += 1

# Summary
print(f"\n" + "="*50)
print(f"PROCESSING COMPLETE")
print(f"="*50)
print(f"• {processed_count} occupations processed")
print(f"• {skipped_count} occupations skipped (already existed)")
print(f"• {error_count} occupations failed")
print(f"• {len(sampled_occupations)} total occupations in sample")
# Out:
# Found 685 unique occupations in the dataset:
#
# [1/685] Acupuncturists
#    ⏭️  Already exists - skipping
#
# [2/685] Acute Care Nurses
#    ⏭️  Already exists - skipping
#
# [3/685] Adapted Physical Education Specialists
#    ⏭️  Already exists - skipping
#
# [4/685] Adhesive Bonding Machine Operators and Tenders
#    ⏭️  Already exists - skipping
#
# [5/685] Administrative Law Judges, Adjudicators, and Hearing Officers
#    ⏭️  Already exists - skipping
#
# [6/685] Administrative Services Managers
#    ⏭️  Already exists - skipping
#
# [7/685] Adult Basic Education, Adult Secondary Education, and English as a Second Language Instructors
#    ⏭️  Already exists - skipping
#
# [8/685] Advanced Practice Psychiatric Nurses
#    ⏭️  Already exists - skipping
#
# [9/685] Advertising Sales Agents
#    ⏭️  Already exists - skipping
#
# [10/685] Aerospace Engineers
#    ⏭️  Already exists - skipping
#
# [11/685] Agents and Business Managers of Artists, Performers, and Athletes
#    ⏭️  Already exists - skipping
#
# [12/685] Agricultural Equipment Operators
#    ⏭️  Already exists - skipping
#
# [13/685] Agricultural Inspectors
#    ⏭️  Already exists - skipping
#
# [14/685] Air Traffic Controllers
#    ⏭️  Already exists - skipping
#
# [15/685] Aircraft Cargo Handling Supervisors
#    ⏭️  Already exists - skipping
#
# [16/685] Aircraft Mechanics and Service Technicians
#    ⏭️  Already exists - skipping
#
# [17/685] Aircraft Structure, Surfaces, Rigging, and Systems Assemblers
#    ⏭️  Already exists - skipping
#
# [18/685] Airfield Operations Specialists
#    ⏭️  Already exists - skipping
#
# [19/685] Airline Pilots, Copilots, and Flight Engineers
#    ⏭️  Already exists - skipping
#
# [20/685] Allergists and Immunologists
#    ⏭️  Already exists - skipping
#
# [21/685] Amusement and Recreation Attendants
#    ⏭️  Already exists - skipping
#
# [22/685] Anesthesiologist Assistants
#    ⏭️  Already exists - skipping
#
# [23/685] Anesthesiologists
#    ⏭️  Already exists - skipping
#
# [24/685] Animal Breeders
#    ⏭️  Already exists - skipping
#
# [25/685] Animal Caretakers
#    ⏭️  Already exists - skipping
#
# [26/685] Animal Control Workers
#    ⏭️  Already exists - skipping
#
# [27/685] Animal Trainers
#    ⏭️  Already exists - skipping
#
# [28/685] Appraisers and Assessors of Real Estate
#    ⏭️  Already exists - skipping
#
# [29/685] Architects, Except Landscape and Naval
#    ⏭️  Already exists - skipping
#
# [30/685] Architectural and Civil Drafters
#    ⏭️  Already exists - skipping
#
# [31/685] Architectural and Engineering Managers
#    ⏭️  Already exists - skipping
#
# [32/685] Archivists
#    ⏭️  Already exists - skipping
#
# [33/685] Art Directors
#    ⏭️  Already exists - skipping
#
# [34/685] Art Therapists
#    ⏭️  Already exists - skipping
#
# [35/685] Art, Drama, and Music Teachers, Postsecondary
#    ⏭️  Already exists - skipping
#
# [36/685] Athletes and Sports Competitors
#    ⏭️  Already exists - skipping
#
# [37/685] Athletic Trainers
#    ⏭️  Already exists - skipping
#
# [38/685] Atmospheric and Space Scientists
#    ⏭️  Already exists - skipping
#
# [39/685] Audiologists
#    ⏭️  Already exists - skipping
#
# [40/685] Audiovisual Equipment Installers and Repairers
#    ⏭️  Already exists - skipping
#
# [41/685] Automotive Body and Related Repairers
#    ⏭️  Already exists - skipping
#
# [42/685] Automotive Engineering Technicians
#    ⏭️  Already exists - skipping
#
# [43/685] Automotive Engineers
#    ⏭️  Already exists - skipping
#
# [44/685] Automotive Glass Installers and Repairers
#    ⏭️  Already exists - skipping
#
# [45/685] Automotive Service Technicians and Mechanics
#    ⏭️  Already exists - skipping
#
# [46/685] Automotive and Watercraft Service Attendants
#    ⏭️  Already exists - skipping
#
# [47/685] Aviation Inspectors
#    ⏭️  Already exists - skipping
#
# [48/685] Avionics Technicians
#    ⏭️  Already exists - skipping
#
# [49/685] Baggage Porters and Bellhops
#    ⏭️  Already exists - skipping
#
# [50/685] Bailiffs
#    ⏭️  Already exists - skipping
#
# [51/685] Bakers
#    ⏭️  Already exists - skipping
#
# [52/685] Barbers
#    ⏭️  Already exists - skipping
#
# [53/685] Baristas
#    ⏭️  Already exists - skipping
#
# [54/685] Bartenders
#    ⏭️  Already exists - skipping
#
# [55/685] Bicycle Repairers
#    ⏭️  Already exists - skipping
#
# [56/685] Bill and Account Collectors
#    ⏭️  Already exists - skipping
#
# [57/685] Billing and Posting Clerks
#    ⏭️  Already exists - skipping
#
# [58/685] Biochemists and Biophysicists
#    ⏭️  Already exists - skipping
#
# [59/685] Biofuels Processing Technicians
#    ⏭️  Already exists - skipping
#
# [60/685] Biofuels Production Managers
#    ⏭️  Already exists - skipping
#
# [61/685] Biological Technicians
#    ⏭️  Already exists - skipping
#
# [62/685] Biomass Plant Technicians
#    ⏭️  Already exists - skipping
#
# [63/685] Biomass Power Plant Managers
#    ⏭️  Already exists - skipping
#
# [64/685] Bookkeeping, Accounting, and Auditing Clerks
#    ⏭️  Already exists - skipping
#
# [65/685] Brickmasons and Blockmasons
#    ⏭️  Already exists - skipping
#
# [66/685] Bridge and Lock Tenders
#    ⏭️  Already exists - skipping
#
# [67/685] Broadcast Announcers and Radio Disc Jockeys
#    ⏭️  Already exists - skipping
#
# [68/685] Broadcast Technicians
#    ⏭️  Already exists - skipping
#
# [69/685] Brokerage Clerks
#    ⏭️  Already exists - skipping
#
# [70/685] Bus Drivers, Transit and Intercity
#    ⏭️  Already exists - skipping
#
# [71/685] Bus and Truck Mechanics and Diesel Engine Specialists
#    ⏭️  Already exists - skipping
#
# [72/685] Butchers and Meat Cutters
#    ⏭️  Already exists - skipping
#
# [73/685] Buyers and Purchasing Agents, Farm Products
#    ⏭️  Already exists - skipping
#
# [74/685] Cabinetmakers and Bench Carpenters
#    ⏭️  Already exists - skipping
#
# [75/685] Camera Operators, Television, Video, and Film
#    ⏭️  Already exists - skipping
#
# [76/685] Camera and Photographic Equipment Repairers
#    ⏭️  Already exists - skipping
#
# [77/685] Captains, Mates, and Pilots of Water Vessels
#    ⏭️  Already exists - skipping
#
# [78/685] Cardiovascular Technologists and Technicians
#    ⏭️  Already exists - skipping
#
# [79/685] Career/Technical Education Teachers, Middle School
#    ⏭️  Already exists - skipping
#
# [80/685] Career/Technical Education Teachers, Postsecondary
#    ⏭️  Already exists - skipping
#
# [81/685] Career/Technical Education Teachers, Secondary School
#    ⏭️  Already exists - skipping
#
# [82/685] Cargo and Freight Agents
#    ⏭️  Already exists - skipping
#
# [83/685] Carpenters
#    ⏭️  Already exists - skipping
#
# [84/685] Carpet Installers
#    ⏭️  Already exists - skipping
#
# [85/685] Cartographers and Photogrammetrists
#    ⏭️  Already exists - skipping
#
# [86/685] Cashiers
#    ⏭️  Already exists - skipping
#
# [87/685] Cement Masons and Concrete Finishers
#    ⏭️  Already exists - skipping
#
# [88/685] Chefs and Head Cooks
#    ⏭️  Already exists - skipping
#
# [89/685] Chemical Engineers
#    ⏭️  Already exists - skipping
#
# [90/685] Chemical Equipment Operators and Tenders
#    ⏭️  Already exists - skipping
#
# [91/685] Chemical Plant and System Operators
#    ⏭️  Already exists - skipping
#
# [92/685] Chemical Technicians
#    ⏭️  Already exists - skipping
#
# [93/685] Chemists
#    ⏭️  Already exists - skipping
#
# [94/685] Chief Executives
#    ⏭️  Already exists - skipping
#
# [95/685] Chief Sustainability Officers
#    ⏭️  Already exists - skipping
#
# [96/685] Child, Family, and School Social Workers
#    ⏭️  Already exists - skipping
#
# [97/685] Childcare Workers
#    ⏭️  Already exists - skipping
#
# [98/685] Chiropractors
#    ⏭️  Already exists - skipping
#
# [99/685] Choreographers
#    ⏭️  Already exists - skipping
#
# [100/685] Civil Engineers
#    ⏭️  Already exists - skipping
#
# [101/685] Claims Adjusters, Examiners, and Investigators
#    ⏭️  Already exists - skipping
#
# [102/685] Cleaners of Vehicles and Equipment
#    ⏭️  Already exists - skipping
#
# [103/685] Cleaning, Washing, and Metal Pickling Equipment Operators and Tenders
#    ⏭️  Already exists - skipping
#
# [104/685] Clergy
#    ⏭️  Already exists - skipping
#
# [105/685] Clinical Data Managers
#    ⏭️  Already exists - skipping
#
# [106/685] Clinical Nurse Specialists
#    ⏭️  Already exists - skipping
#
# [107/685] Clinical and Counseling Psychologists
#    ⏭️  Already exists - skipping
#
# [108/685] Coaches and Scouts
#    ⏭️  Already exists - skipping
#
# [109/685] Coating, Painting, and Spraying Machine Setters, Operators, and Tenders
#    ⏭️  Already exists - skipping
#
# [110/685] Coil Winders, Tapers, and Finishers
#    ⏭️  Already exists - skipping
#
# [111/685] Coin, Vending, and Amusement Machine Servicers and Repairers
#    ⏭️  Already exists - skipping
#
# [112/685] Commercial Divers
#    ⏭️  Already exists - skipping
#
# [113/685] Commercial Pilots
#    ⏭️  Already exists - skipping
#
# [114/685] Commercial and Industrial Designers
#    ⏭️  Already exists - skipping
#
# [115/685] Community Health Workers
#    ⏭️  Already exists - skipping
#
# [116/685] Compensation and Benefits Managers
#    ⏭️  Already exists - skipping
#
# [117/685] Compliance Officers
#    ⏭️  Already exists - skipping
#
# [118/685] Computer Network Support Specialists
#    ⏭️  Already exists - skipping
#
# [119/685] Computer Numerically Controlled Tool Operators
#    ⏭️  Already exists - skipping
#
# [120/685] Computer Numerically Controlled Tool Programmers
#    ⏭️  Already exists - skipping
#
# [121/685] Computer Programmers
#    ⏭️  Already exists - skipping
#
# [122/685] Computer Systems Analysts
#    ⏭️  Already exists - skipping
#
# [123/685] Computer User Support Specialists
#    ⏭️  Already exists - skipping
#
# [124/685] Computer and Information Research Scientists
#    ⏭️  Already exists - skipping
#
# [125/685] Computer and Information Systems Managers
#    ⏭️  Already exists - skipping
#
# [126/685] Computer, Automated Teller, and Office Machine Repairers
#    ⏭️  Already exists - skipping
#
# [127/685] Concierges
#    ⏭️  Already exists - skipping
#
# [128/685] Conservation Scientists
#    ⏭️  Already exists - skipping
#
# [129/685] Construction Laborers
#    ⏭️  Already exists - skipping
#
# [130/685] Construction Managers
#    ⏭️  Already exists - skipping
#
# [131/685] Construction and Building Inspectors
#    ⏭️  Already exists - skipping
#
# [132/685] Continuous Mining Machine Operators
#    ⏭️  Already exists - skipping
#
# [133/685] Conveyor Operators and Tenders
#    ⏭️  Already exists - skipping
#
# [134/685] Cooks, Fast Food
#    ⏭️  Already exists - skipping
#
# [135/685] Cooks, Institution and Cafeteria
#    ⏭️  Already exists - skipping
#
# [136/685] Cooks, Private Household
#    ⏭️  Already exists - skipping
#
# [137/685] Cooks, Restaurant
#    ⏭️  Already exists - skipping
#
# [138/685] Cooks, Short Order
#    ⏭️  Already exists - skipping
#
# [139/685] Cooling and Freezing Equipment Operators and Tenders
#    ⏭️  Already exists - skipping
#
# [140/685] Coroners
#    ⏭️  Already exists - skipping
#
# [141/685] Correctional Officers and Jailers
#    ⏭️  Already exists - skipping
#
# [142/685] Correspondence Clerks
#    ⏭️  Already exists - skipping
#
# [143/685] Counter and Rental Clerks
#    ⏭️  Already exists - skipping
#
# [144/685] Couriers and Messengers
#    ⏭️  Already exists - skipping
#
# [145/685] Court Reporters and Simultaneous Captioners
#    ⏭️  Already exists - skipping
#
# [146/685] Court, Municipal, and License Clerks
#    ⏭️  Already exists - skipping
#
# [147/685] Craft Artists
#    ⏭️  Already exists - skipping
#
# [148/685] Crane and Tower Operators
#    ⏭️  Already exists - skipping
#
# [149/685] Credit Analysts
#    ⏭️  Already exists - skipping
#
# [150/685] Credit Authorizers, Checkers, and Clerks
#    ⏭️  Already exists - skipping
#
# [151/685] Credit Counselors
#    ⏭️  Already exists - skipping
#
# [152/685] Critical Care Nurses
#    ⏭️  Already exists - skipping
#
# [153/685] Crossing Guards and Flaggers
#    ⏭️  Already exists - skipping
#
# [154/685] Crushing, Grinding, and Polishing Machine Setters, Operators, and Tenders
#    ⏭️  Already exists - skipping
#
# [155/685] Customer Service Representatives
#    ⏭️  Already exists - skipping
#
# [156/685] Customs Brokers
#    ⏭️  Already exists - skipping
#
# [157/685] Customs and Border Protection Officers
#    ⏭️  Already exists - skipping
#
# [158/685] Cutters and Trimmers, Hand
#    ⏭️  Already exists - skipping
#
# [159/685] Cutting and Slicing Machine Setters, Operators, and Tenders
#    ⏭️  Already exists - skipping
#
# [160/685] Cutting, Punching, and Press Machine Setters, Operators, and Tenders, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [161/685] Cytogenetic Technologists
#    ⏭️  Already exists - skipping
#
# [162/685] Cytotechnologists
#    ⏭️  Already exists - skipping
#
# [163/685] Dancers
#    ⏭️  Already exists - skipping
#
# [164/685] Data Entry Keyers
#    ⏭️  Already exists - skipping
#
# [165/685] Demonstrators and Product Promoters
#    ⏭️  Already exists - skipping
#
# [166/685] Dental Assistants
#    ⏭️  Already exists - skipping
#
# [167/685] Dental Hygienists
#    ⏭️  Already exists - skipping
#
# [168/685] Dental Laboratory Technicians
#    ⏭️  Already exists - skipping
#
# [169/685] Dentists, General
#    ⏭️  Already exists - skipping
#
# [170/685] Dermatologists
#    ⏭️  Already exists - skipping
#
# [171/685] Derrick Operators, Oil and Gas
#    ⏭️  Already exists - skipping
#
# [172/685] Desktop Publishers
#    ⏭️  Already exists - skipping
#
# [173/685] Detectives and Criminal Investigators
#    ⏭️  Already exists - skipping
#
# [174/685] Diagnostic Medical Sonographers
#    ⏭️  Already exists - skipping
#
# [175/685] Dietetic Technicians
#    ⏭️  Already exists - skipping
#
# [176/685] Dietitians and Nutritionists
#    ⏭️  Already exists - skipping
#
# [177/685] Dining Room and Cafeteria Attendants and Bartender Helpers
#    ⏭️  Already exists - skipping
#
# [178/685] Dishwashers
#    ⏭️  Already exists - skipping
#
# [179/685] Dispatchers, Except Police, Fire, and Ambulance
#    ⏭️  Already exists - skipping
#
# [180/685] Door-to-Door Sales Workers, News and Street Vendors, and Related Workers
#    ⏭️  Already exists - skipping
#
# [181/685] Dredge Operators
#    ⏭️  Already exists - skipping
#
# [182/685] Drilling and Boring Machine Tool Setters, Operators, and Tenders, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [183/685] Driver/Sales Workers
#    ⏭️  Already exists - skipping
#
# [184/685] Drywall and Ceiling Tile Installers
#    ⏭️  Already exists - skipping
#
# [185/685] Earth Drillers, Except Oil and Gas
#    ⏭️  Already exists - skipping
#
# [186/685] Editors
#    ⏭️  Already exists - skipping
#
# [187/685] Education Administrators, Kindergarten through Secondary
#    ⏭️  Already exists - skipping
#
# [188/685] Education and Childcare Administrators, Preschool and Daycare
#    ⏭️  Already exists - skipping
#
# [189/685] Educational, Guidance, and Career Counselors and Advisors
#    ⏭️  Already exists - skipping
#
# [190/685] Electric Motor, Power Tool, and Related Repairers
#    ⏭️  Already exists - skipping
#
# [191/685] Electrical Power-Line Installers and Repairers
#    ⏭️  Already exists - skipping
#
# [192/685] Electrical and Electronic Equipment Assemblers
#    ⏭️  Already exists - skipping
#
# [193/685] Electrical and Electronics Drafters
#    ⏭️  Already exists - skipping
#
# [194/685] Electrical and Electronics Repairers, Powerhouse, Substation, and Relay
#    ⏭️  Already exists - skipping
#
# [195/685] Electricians
#    ⏭️  Already exists - skipping
#
# [196/685] Electro-Mechanical and Mechatronics Technologists and Technicians
#    ⏭️  Already exists - skipping
#
# [197/685] Electromechanical Equipment Assemblers
#    ⏭️  Already exists - skipping
#
# [198/685] Electronic Equipment Installers and Repairers, Motor Vehicles
#    ⏭️  Already exists - skipping
#
# [199/685] Elementary School Teachers, Except Special Education
#    ⏭️  Already exists - skipping
#
# [200/685] Elevator and Escalator Installers and Repairers
#    ⏭️  Already exists - skipping
#
# [201/685] Eligibility Interviewers, Government Programs
#    ⏭️  Already exists - skipping
#
# [202/685] Embalmers
#    ⏭️  Already exists - skipping
#
# [203/685] Endoscopy Technicians
#    ⏭️  Already exists - skipping
#
# [204/685] Energy Auditors
#    ⏭️  Already exists - skipping
#
# [205/685] Engine and Other Machine Assemblers
#    ⏭️  Already exists - skipping
#
# [206/685] Engineering Teachers, Postsecondary
#    ⏭️  Already exists - skipping
#
# [207/685] English Language and Literature Teachers, Postsecondary
#    ⏭️  Already exists - skipping
#
# [208/685] Epidemiologists
#    ⏭️  Already exists - skipping
#
# [209/685] Equal Opportunity Representatives and Officers
#    ⏭️  Already exists - skipping
#
# [210/685] Etchers and Engravers
#    ⏭️  Already exists - skipping
#
# [211/685] Excavating and Loading Machine and Dragline Operators, Surface Mining
#    ⏭️  Already exists - skipping
#
# [212/685] Executive Secretaries and Executive Administrative Assistants
#    ⏭️  Already exists - skipping
#
# [213/685] Exercise Physiologists
#    ⏭️  Already exists - skipping
#
# [214/685] Exercise Trainers and Group Fitness Instructors
#    ⏭️  Already exists - skipping
#
# [215/685] Explosives Workers, Ordnance Handling Experts, and Blasters
#    ⏭️  Already exists - skipping
#
# [216/685] Extruding and Drawing Machine Setters, Operators, and Tenders, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [217/685] Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers
#    ⏭️  Already exists - skipping
#
# [218/685] Extruding, Forming, Pressing, and Compacting Machine Setters, Operators, and Tenders
#    ⏭️  Already exists - skipping
#
# [219/685] Fabric and Apparel Patternmakers
#    ⏭️  Already exists - skipping
#
# [220/685] Fallers
#    ⏭️  Already exists - skipping
#
# [221/685] Family Medicine Physicians
#    ⏭️  Already exists - skipping
#
# [222/685] Farm Equipment Mechanics and Service Technicians
#    ⏭️  Already exists - skipping
#
# [223/685] Farm Labor Contractors
#    ⏭️  Already exists - skipping
#
# [224/685] Farmers, Ranchers, and Other Agricultural Managers
#    ⏭️  Already exists - skipping
#
# [225/685] Farmworkers and Laborers, Crop, Nursery, and Greenhouse
#    ⏭️  Already exists - skipping
#
# [226/685] Farmworkers, Farm, Ranch, and Aquacultural Animals
#    ⏭️  Already exists - skipping
#
# [227/685] Fashion Designers
#    ⏭️  Already exists - skipping
#
# [228/685] Fast Food and Counter Workers
#    ⏭️  Already exists - skipping
#
# [229/685] Fence Erectors
#    ⏭️  Already exists - skipping
#
# [230/685] Fiberglass Laminators and Fabricators
#    ⏭️  Already exists - skipping
#
# [231/685] File Clerks
#    ⏭️  Already exists - skipping
#
# [232/685] Film and Video Editors
#    ⏭️  Already exists - skipping
#
# [233/685] Financial Managers
#    ⏭️  Already exists - skipping
#
# [234/685] Fire Inspectors and Investigators
#    ⏭️  Already exists - skipping
#
# [235/685] First-Line Supervisors of Construction Trades and Extraction Workers
#    ⏭️  Already exists - skipping
#
# [236/685] First-Line Supervisors of Correctional Officers
#    ⏭️  Already exists - skipping
#
# [237/685] First-Line Supervisors of Farming, Fishing, and Forestry Workers
#    ⏭️  Already exists - skipping
#
# [238/685] First-Line Supervisors of Firefighting and Prevention Workers
#    ⏭️  Already exists - skipping
#
# [239/685] First-Line Supervisors of Food Preparation and Serving Workers
#    ⏭️  Already exists - skipping
#
# [240/685] First-Line Supervisors of Gambling Services Workers
#    ⏭️  Already exists - skipping
#
# [241/685] First-Line Supervisors of Helpers, Laborers, and Material Movers, Hand
#    ⏭️  Already exists - skipping
#
# [242/685] First-Line Supervisors of Housekeeping and Janitorial Workers
#    ⏭️  Already exists - skipping
#
# [243/685] First-Line Supervisors of Landscaping, Lawn Service, and Groundskeeping Workers
#    ⏭️  Already exists - skipping
#
# [244/685] First-Line Supervisors of Material-Moving Machine and Vehicle Operators
#    ⏭️  Already exists - skipping
#
# [245/685] First-Line Supervisors of Mechanics, Installers, and Repairers
#    ⏭️  Already exists - skipping
#
# [246/685] First-Line Supervisors of Non-Retail Sales Workers
#    ⏭️  Already exists - skipping
#
# [247/685] First-Line Supervisors of Office and Administrative Support Workers
#    ⏭️  Already exists - skipping
#
# [248/685] First-Line Supervisors of Personal Service Workers
#    ⏭️  Already exists - skipping
#
# [249/685] First-Line Supervisors of Police and Detectives
#    ⏭️  Already exists - skipping
#
# [250/685] First-Line Supervisors of Production and Operating Workers
#    ⏭️  Already exists - skipping
#
# [251/685] First-Line Supervisors of Retail Sales Workers
#    ⏭️  Already exists - skipping
#
# [252/685] Fish and Game Wardens
#    ⏭️  Already exists - skipping
#
# [253/685] Fishing and Hunting Workers
#    ⏭️  Already exists - skipping
#
# [254/685] Fitness and Wellness Coordinators
#    ⏭️  Already exists - skipping
#
# [255/685] Flight Attendants
#    ⏭️  Already exists - skipping
#
# [256/685] Floor Layers, Except Carpet, Wood, and Hard Tiles
#    ⏭️  Already exists - skipping
#
# [257/685] Floor Sanders and Finishers
#    ⏭️  Already exists - skipping
#
# [258/685] Floral Designers
#    ⏭️  Already exists - skipping
#
# [259/685] Food Batchmakers
#    ⏭️  Already exists - skipping
#
# [260/685] Food Cooking Machine Operators and Tenders
#    ⏭️  Already exists - skipping
#
# [261/685] Food Preparation Workers
#    ⏭️  Already exists - skipping
#
# [262/685] Food Science Technicians
#    ⏭️  Already exists - skipping
#
# [263/685] Food Servers, Nonrestaurant
#    ⏭️  Already exists - skipping
#
# [264/685] Food Service Managers
#    ⏭️  Already exists - skipping
#
# [265/685] Food and Tobacco Roasting, Baking, and Drying Machine Operators and Tenders
#    ⏭️  Already exists - skipping
#
# [266/685] Foreign Language and Literature Teachers, Postsecondary
#    ⏭️  Already exists - skipping
#
# [267/685] Forensic Science Technicians
#    ⏭️  Already exists - skipping
#
# [268/685] Forest Fire Inspectors and Prevention Specialists
#    ⏭️  Already exists - skipping
#
# [269/685] Forest and Conservation Workers
#    ⏭️  Already exists - skipping
#
# [270/685] Forging Machine Setters, Operators, and Tenders, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [271/685] Foundry Mold and Coremakers
#    ⏭️  Already exists - skipping
#
# [272/685] Freight Forwarders
#    ⏭️  Already exists - skipping
#
# [273/685] Fuel Cell Engineers
#    ⏭️  Already exists - skipping
#
# [274/685] Fundraisers
#    ⏭️  Already exists - skipping
#
# [275/685] Funeral Attendants
#    ⏭️  Already exists - skipping
#
# [276/685] Funeral Home Managers
#    ⏭️  Already exists - skipping
#
# [277/685] Furnace, Kiln, Oven, Drier, and Kettle Operators and Tenders
#    ⏭️  Already exists - skipping
#
# [278/685] Furniture Finishers
#    ⏭️  Already exists - skipping
#
# [279/685] Gambling Cage Workers
#    ⏭️  Already exists - skipping
#
# [280/685] Gambling Change Persons and Booth Cashiers
#    ⏭️  Already exists - skipping
#
# [281/685] Gambling Dealers
#    ⏭️  Already exists - skipping
#
# [282/685] Gambling Managers
#    ⏭️  Already exists - skipping
#
# [283/685] Gambling Surveillance Officers and Gambling Investigators
#    ⏭️  Already exists - skipping
#
# [284/685] Gambling and Sports Book Writers and Runners
#    ⏭️  Already exists - skipping
#
# [285/685] Gas Compressor and Gas Pumping Station Operators
#    ⏭️  Already exists - skipping
#
# [286/685] Gas Plant Operators
#    ⏭️  Already exists - skipping
#
# [287/685] Gem and Diamond Workers
#    ⏭️  Already exists - skipping
#
# [288/685] General Internal Medicine Physicians
#    ⏭️  Already exists - skipping
#
# [289/685] General and Operations Managers
#    ⏭️  Already exists - skipping
#
# [290/685] Genetic Counselors
#    ⏭️  Already exists - skipping
#
# [291/685] Geneticists
#    ⏭️  Already exists - skipping
#
# [292/685] Geographic Information Systems Technologists and Technicians
#    ⏭️  Already exists - skipping
#
# [293/685] Geological Technicians, Except Hydrologic Technicians
#    ⏭️  Already exists - skipping
#
# [294/685] Geoscientists, Except Hydrologists and Geographers
#    ⏭️  Already exists - skipping
#
# [295/685] Geothermal Production Managers
#    ⏭️  Already exists - skipping
#
# [296/685] Geothermal Technicians
#    ⏭️  Already exists - skipping
#
# [297/685] Glass Blowers, Molders, Benders, and Finishers
#    ⏭️  Already exists - skipping
#
# [298/685] Glaziers
#    ⏭️  Already exists - skipping
#
# [299/685] Graders and Sorters, Agricultural Products
#    ⏭️  Already exists - skipping
#
# [300/685] Graphic Designers
#    ⏭️  Already exists - skipping
#
# [301/685] Grinding and Polishing Workers, Hand
#    ⏭️  Already exists - skipping
#
# [302/685] Grinding, Lapping, Polishing, and Buffing Machine Tool Setters, Operators, and Tenders, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [303/685] Hairdressers, Hairstylists, and Cosmetologists
#    ⏭️  Already exists - skipping
#
# [304/685] Hazardous Materials Removal Workers
#    ⏭️  Already exists - skipping
#
# [305/685] Healthcare Social Workers
#    ⏭️  Already exists - skipping
#
# [306/685] Hearing Aid Specialists
#    ⏭️  Already exists - skipping
#
# [307/685] Heat Treating Equipment Setters, Operators, and Tenders, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [308/685] Heating, Air Conditioning, and Refrigeration Mechanics and Installers
#    ⏭️  Already exists - skipping
#
# [309/685] Heavy and Tractor-Trailer Truck Drivers
#    ⏭️  Already exists - skipping
#
# [310/685] Helpers--Brickmasons, Blockmasons, Stonemasons, and Tile and Marble Setters
#    ⏭️  Already exists - skipping
#
# [311/685] Helpers--Carpenters
#    ⏭️  Already exists - skipping
#
# [312/685] Helpers--Electricians
#    ⏭️  Already exists - skipping
#
# [313/685] Helpers--Extraction Workers
#    ⏭️  Already exists - skipping
#
# [314/685] Helpers--Installation, Maintenance, and Repair Workers
#    ⏭️  Already exists - skipping
#
# [315/685] Helpers--Painters, Paperhangers, Plasterers, and Stucco Masons
#    ⏭️  Already exists - skipping
#
# [316/685] Helpers--Pipelayers, Plumbers, Pipefitters, and Steamfitters
#    ⏭️  Already exists - skipping
#
# [317/685] Helpers--Production Workers
#    ⏭️  Already exists - skipping
#
# [318/685] Helpers--Roofers
#    ⏭️  Already exists - skipping
#
# [319/685] Highway Maintenance Workers
#    ⏭️  Already exists - skipping
#
# [320/685] Hoist and Winch Operators
#    ⏭️  Already exists - skipping
#
# [321/685] Home Appliance Repairers
#    ⏭️  Already exists - skipping
#
# [322/685] Home Health Aides
#    ⏭️  Already exists - skipping
#
# [323/685] Hospitalists
#    ⏭️  Already exists - skipping
#
# [324/685] Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop
#    ⏭️  Already exists - skipping
#
# [325/685] Hotel, Motel, and Resort Desk Clerks
#    ⏭️  Already exists - skipping
#
# [326/685] Human Resources Assistants, Except Payroll and Timekeeping
#    ⏭️  Already exists - skipping
#
# [327/685] Human Resources Managers
#    ⏭️  Already exists - skipping
#
# [328/685] Hydroelectric Plant Technicians
#    ⏭️  Already exists - skipping
#
# [329/685] Hydroelectric Production Managers
#    ⏭️  Already exists - skipping
#
# [330/685] Industrial Machinery Mechanics
#    ⏭️  Already exists - skipping
#
# [331/685] Industrial Production Managers
#    ⏭️  Already exists - skipping
#
# [332/685] Industrial Truck and Tractor Operators
#    ⏭️  Already exists - skipping
#
# [333/685] Information Technology Project Managers
#    ⏭️  Already exists - skipping
#
# [334/685] Inspectors, Testers, Sorters, Samplers, and Weighers
#    ⏭️  Already exists - skipping
#
# [335/685] Insulation Workers, Floor, Ceiling, and Wall
#    ⏭️  Already exists - skipping
#
# [336/685] Insulation Workers, Mechanical
#    ⏭️  Already exists - skipping
#
# [337/685] Insurance Appraisers, Auto Damage
#    ⏭️  Already exists - skipping
#
# [338/685] Insurance Claims and Policy Processing Clerks
#    ⏭️  Already exists - skipping
#
# [339/685] Insurance Sales Agents
#    ⏭️  Already exists - skipping
#
# [340/685] Insurance Underwriters
#    ⏭️  Already exists - skipping
#
# [341/685] Intelligence Analysts
#    ⏭️  Already exists - skipping
#
# [342/685] Interior Designers
#    ⏭️  Already exists - skipping
#
# [343/685] Interpreters and Translators
#    ⏭️  Already exists - skipping
#
# [344/685] Interviewers, Except Eligibility and Loan
#    ⏭️  Already exists - skipping
#
# [345/685] Investment Fund Managers
#    ⏭️  Already exists - skipping
#
# [346/685] Janitors and Cleaners, Except Maids and Housekeeping Cleaners
#    ⏭️  Already exists - skipping
#
# [347/685] Jewelers and Precious Stone and Metal Workers
#    ⏭️  Already exists - skipping
#
# [348/685] Judges, Magistrate Judges, and Magistrates
#    ⏭️  Already exists - skipping
#
# [349/685] Judicial Law Clerks
#    ⏭️  Already exists - skipping
#
# [350/685] Kindergarten Teachers, Except Special Education
#    ⏭️  Already exists - skipping
#
# [351/685] Laborers and Freight, Stock, and Material Movers, Hand
#    ⏭️  Already exists - skipping
#
# [352/685] Landscape Architects
#    ⏭️  Already exists - skipping
#
# [353/685] Landscaping and Groundskeeping Workers
#    ⏭️  Already exists - skipping
#
# [354/685] Lathe and Turning Machine Tool Setters, Operators, and Tenders, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [355/685] Laundry and Dry-Cleaning Workers
#    ⏭️  Already exists - skipping
#
# [356/685] Lawyers
#    ⏭️  Already exists - skipping
#
# [357/685] Layout Workers, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [358/685] Legal Secretaries and Administrative Assistants
#    ⏭️  Already exists - skipping
#
# [359/685] Librarians and Media Collections Specialists
#    ⏭️  Already exists - skipping
#
# [360/685] Library Assistants, Clerical
#    ⏭️  Already exists - skipping
#
# [361/685] Library Technicians
#    ⏭️  Already exists - skipping
#
# [362/685] Licensed Practical and Licensed Vocational Nurses
#    ⏭️  Already exists - skipping
#
# [363/685] Lifeguards, Ski Patrol, and Other Recreational Protective Service Workers
#    ⏭️  Already exists - skipping
#
# [364/685] Light Truck Drivers
#    ⏭️  Already exists - skipping
#
# [365/685] Loading and Moving Machine Operators, Underground Mining
#    ⏭️  Already exists - skipping
#
# [366/685] Loan Interviewers and Clerks
#    ⏭️  Already exists - skipping
#
# [367/685] Loan Officers
#    ⏭️  Already exists - skipping
#
# [368/685] Locker Room, Coatroom, and Dressing Room Attendants
#    ⏭️  Already exists - skipping
#
# [369/685] Locksmiths and Safe Repairers
#    ⏭️  Already exists - skipping
#
# [370/685] Locomotive Engineers
#    ⏭️  Already exists - skipping
#
# [371/685] Lodging Managers
#    ⏭️  Already exists - skipping
#
# [372/685] Log Graders and Scalers
#    ⏭️  Already exists - skipping
#
# [373/685] Logging Equipment Operators
#    ⏭️  Already exists - skipping
#
# [374/685] Logistics Analysts
#    ⏭️  Already exists - skipping
#
# [375/685] Logistics Engineers
#    ⏭️  Already exists - skipping
#
# [376/685] Loss Prevention Managers
#    ⏭️  Already exists - skipping
#
# [377/685] Low Vision Therapists, Orientation and Mobility Specialists, and Vision Rehabilitation Therapists
#    ⏭️  Already exists - skipping
#
# [378/685] Machine Feeders and Offbearers
#    ⏭️  Already exists - skipping
#
# [379/685] Machinists
#    ⏭️  Already exists - skipping
#
# [380/685] Magnetic Resonance Imaging Technologists
#    ⏭️  Already exists - skipping
#
# [381/685] Maids and Housekeeping Cleaners
#    ⏭️  Already exists - skipping
#
# [382/685] Mail Clerks and Mail Machine Operators, Except Postal Service
#    ⏭️  Already exists - skipping
#
# [383/685] Maintenance Workers, Machinery
#    ⏭️  Already exists - skipping
#
# [384/685] Makeup Artists, Theatrical and Performance
#    ⏭️  Already exists - skipping
#
# [385/685] Manicurists and Pedicurists
#    ⏭️  Already exists - skipping
#
# [386/685] Marriage and Family Therapists
#    ⏭️  Already exists - skipping
#
# [387/685] Massage Therapists
#    ⏭️  Already exists - skipping
#
# [388/685] Materials Engineers
#    ⏭️  Already exists - skipping
#
# [389/685] Mathematicians
#    ⏭️  Already exists - skipping
#
# [390/685] Meat, Poultry, and Fish Cutters and Trimmers
#    ⏭️  Already exists - skipping
#
# [391/685] Mechanical Door Repairers
#    ⏭️  Already exists - skipping
#
# [392/685] Mechanical Drafters
#    ⏭️  Already exists - skipping
#
# [393/685] Mechanical Engineers
#    ⏭️  Already exists - skipping
#
# [394/685] Mechatronics Engineers
#    ⏭️  Already exists - skipping
#
# [395/685] Media Programming Directors
#    ⏭️  Already exists - skipping
#
# [396/685] Media Technical Directors/Managers
#    ⏭️  Already exists - skipping
#
# [397/685] Medical Appliance Technicians
#    ⏭️  Already exists - skipping
#
# [398/685] Medical Assistants
#    ⏭️  Already exists - skipping
#
# [399/685] Medical Equipment Preparers
#    ⏭️  Already exists - skipping
#
# [400/685] Medical Equipment Repairers
#    ⏭️  Already exists - skipping
#
# [401/685] Medical Secretaries and Administrative Assistants
#    ⏭️  Already exists - skipping
#
# [402/685] Medical Transcriptionists
#    ⏭️  Already exists - skipping
#
# [403/685] Medical and Clinical Laboratory Technicians
#    ⏭️  Already exists - skipping
#
# [404/685] Medical and Clinical Laboratory Technologists
#    ⏭️  Already exists - skipping
#
# [405/685] Medical and Health Services Managers
#    ⏭️  Already exists - skipping
#
# [406/685] Meeting, Convention, and Event Planners
#    ⏭️  Already exists - skipping
#
# [407/685] Mental Health Counselors
#    ⏭️  Already exists - skipping
#
# [408/685] Mental Health and Substance Abuse Social Workers
#    ⏭️  Already exists - skipping
#
# [409/685] Merchandise Displayers and Window Trimmers
#    ⏭️  Already exists - skipping
#
# [410/685] Metal-Refining Furnace Operators and Tenders
#    ⏭️  Already exists - skipping
#
# [411/685] Meter Readers, Utilities
#    ⏭️  Already exists - skipping
#
# [412/685] Microbiologists
#    ⏭️  Already exists - skipping
#
# [413/685] Middle School Teachers, Except Special and Career/Technical Education
#    ⏭️  Already exists - skipping
#
# [414/685] Midwives
#    ⏭️  Already exists - skipping
#
# [415/685] Milling and Planing Machine Setters, Operators, and Tenders, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [416/685] Millwrights
#    ⏭️  Already exists - skipping
#
# [417/685] Mixing and Blending Machine Setters, Operators, and Tenders
#    ⏭️  Already exists - skipping
#
# [418/685] Mobile Heavy Equipment Mechanics, Except Engines
#    ⏭️  Already exists - skipping
#
# [419/685] Model Makers, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [420/685] Model Makers, Wood
#    ⏭️  Already exists - skipping
#
# [421/685] Models
#    ⏭️  Already exists - skipping
#
# [422/685] Molders, Shapers, and Casters, Except Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [423/685] Molding, Coremaking, and Casting Machine Setters, Operators, and Tenders, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [424/685] Molecular and Cellular Biologists
#    ⏭️  Already exists - skipping
#
# [425/685] Motion Picture Projectionists
#    ⏭️  Already exists - skipping
#
# [426/685] Motorboat Mechanics and Service Technicians
#    ⏭️  Already exists - skipping
#
# [427/685] Motorboat Operators
#    ⏭️  Already exists - skipping
#
# [428/685] Motorcycle Mechanics
#    ⏭️  Already exists - skipping
#
# [429/685] Multiple Machine Tool Setters, Operators, and Tenders, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [430/685] Music Directors and Composers
#    ⏭️  Already exists - skipping
#
# [431/685] Music Therapists
#    ⏭️  Already exists - skipping
#
# [432/685] Musical Instrument Repairers and Tuners
#    ⏭️  Already exists - skipping
#
# [433/685] Musicians and Singers
#    ⏭️  Already exists - skipping
#
# [434/685] Nannies
#    ⏭️  Already exists - skipping
#
# [435/685] Nanotechnology Engineering Technologists and Technicians
#    ⏭️  Already exists - skipping
#
# [436/685] Naturopathic Physicians
#    ⏭️  Already exists - skipping
#
# [437/685] Network and Computer Systems Administrators
#    ⏭️  Already exists - skipping
#
# [438/685] Neurodiagnostic Technologists
#    ⏭️  Already exists - skipping
#
# [439/685] Neurologists
#    ⏭️  Already exists - skipping
#
# [440/685] New Accounts Clerks
#    ⏭️  Already exists - skipping
#
# [441/685] News Analysts, Reporters, and Journalists
#    ⏭️  Already exists - skipping
#
# [442/685] Non-Destructive Testing Specialists
#    ⏭️  Already exists - skipping
#
# [443/685] Nuclear Medicine Technologists
#    ⏭️  Already exists - skipping
#
# [444/685] Nuclear Monitoring Technicians
#    ⏭️  Already exists - skipping
#
# [445/685] Nuclear Power Reactor Operators
#    ⏭️  Already exists - skipping
#
# [446/685] Nuclear Technicians
#    ⏭️  Already exists - skipping
#
# [447/685] Nurse Anesthetists
#    ⏭️  Already exists - skipping
#
# [448/685] Nurse Midwives
#    ⏭️  Already exists - skipping
#
# [449/685] Nurse Practitioners
#    ⏭️  Already exists - skipping
#
# [450/685] Nursing Assistants
#    ⏭️  Already exists - skipping
#
# [451/685] Obstetricians and Gynecologists
#    ⏭️  Already exists - skipping
#
# [452/685] Occupational Therapists
#    ⏭️  Already exists - skipping
#
# [453/685] Occupational Therapy Aides
#    ⏭️  Already exists - skipping
#
# [454/685] Occupational Therapy Assistants
#    ⏭️  Already exists - skipping
#
# [455/685] Office Clerks, General
#    ⏭️  Already exists - skipping
#
# [456/685] Office Machine Operators, Except Computer
#    ⏭️  Already exists - skipping
#
# [457/685] Online Merchants
#    ⏭️  Already exists - skipping
#
# [458/685] Operating Engineers and Other Construction Equipment Operators
#    ⏭️  Already exists - skipping
#
# [459/685] Ophthalmic Laboratory Technicians
#    ⏭️  Already exists - skipping
#
# [460/685] Ophthalmic Medical Technicians
#    ⏭️  Already exists - skipping
#
# [461/685] Ophthalmic Medical Technologists
#    ⏭️  Already exists - skipping
#
# [462/685] Ophthalmologists, Except Pediatric
#    ⏭️  Already exists - skipping
#
# [463/685] Opticians, Dispensing
#    ⏭️  Already exists - skipping
#
# [464/685] Optometrists
#    ⏭️  Already exists - skipping
#
# [465/685] Oral and Maxillofacial Surgeons
#    ⏭️  Already exists - skipping
#
# [466/685] Order Clerks
#    ⏭️  Already exists - skipping
#
# [467/685] Orderlies
#    ⏭️  Already exists - skipping
#
# [468/685] Orthodontists
#    ⏭️  Already exists - skipping
#
# [469/685] Orthoptists
#    ⏭️  Already exists - skipping
#
# [470/685] Orthotists and Prosthetists
#    ⏭️  Already exists - skipping
#
# [471/685] Outdoor Power Equipment and Other Small Engine Mechanics
#    ⏭️  Already exists - skipping
#
# [472/685] Packaging and Filling Machine Operators and Tenders
#    ⏭️  Already exists - skipping
#
# [473/685] Packers and Packagers, Hand
#    ⏭️  Already exists - skipping
#
# [474/685] Painters, Construction and Maintenance
#    ⏭️  Already exists - skipping
#
# [475/685] Painting, Coating, and Decorating Workers
#    ⏭️  Already exists - skipping
#
# [476/685] Paper Goods Machine Setters, Operators, and Tenders
#    ⏭️  Already exists - skipping
#
# [477/685] Paperhangers
#    ⏭️  Already exists - skipping
#
# [478/685] Paralegals and Legal Assistants
#    ⏭️  Already exists - skipping
#
# [479/685] Park Naturalists
#    ⏭️  Already exists - skipping
#
# [480/685] Parking Attendants
#    ⏭️  Already exists - skipping
#
# [481/685] Parking Enforcement Workers
#    ⏭️  Already exists - skipping
#
# [482/685] Parts Salespersons
#    ⏭️  Already exists - skipping
#
# [483/685] Passenger Attendants
#    ⏭️  Already exists - skipping
#
# [484/685] Patient Representatives
#    ⏭️  Already exists - skipping
#
# [485/685] Patternmakers, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [486/685] Patternmakers, Wood
#    ⏭️  Already exists - skipping
#
# [487/685] Paving, Surfacing, and Tamping Equipment Operators
#    ⏭️  Already exists - skipping
#
# [488/685] Pediatricians, General
#    ⏭️  Already exists - skipping
#
# [489/685] Personal Care Aides
#    ⏭️  Already exists - skipping
#
# [490/685] Personal Financial Advisors
#    ⏭️  Already exists - skipping
#
# [491/685] Pest Control Workers
#    ⏭️  Already exists - skipping
#
# [492/685] Pesticide Handlers, Sprayers, and Applicators, Vegetation
#    ⏭️  Already exists - skipping
#
# [493/685] Petroleum Pump System Operators, Refinery Operators, and Gaugers
#    ⏭️  Already exists - skipping
#
# [494/685] Pharmacists
#    ⏭️  Already exists - skipping
#
# [495/685] Pharmacy Aides
#    ⏭️  Already exists - skipping
#
# [496/685] Pharmacy Technicians
#    ⏭️  Already exists - skipping
#
# [497/685] Phlebotomists
#    ⏭️  Already exists - skipping
#
# [498/685] Photographers
#    ⏭️  Already exists - skipping
#
# [499/685] Photographic Process Workers and Processing Machine Operators
#    ⏭️  Already exists - skipping
#
# [500/685] Photonics Technicians
#    ⏭️  Already exists - skipping
#
# [501/685] Physical Medicine and Rehabilitation Physicians
#    ⏭️  Already exists - skipping
#
# [502/685] Physical Therapist Aides
#    ⏭️  Already exists - skipping
#
# [503/685] Physical Therapist Assistants
#    ⏭️  Already exists - skipping
#
# [504/685] Physical Therapists
#    ⏭️  Already exists - skipping
#
# [505/685] Physician Assistants
#    ⏭️  Already exists - skipping
#
# [506/685] Physicians, Pathologists
#    ⏭️  Already exists - skipping
#
# [507/685] Pile Driver Operators
#    ⏭️  Already exists - skipping
#
# [508/685] Pipelayers
#    ⏭️  Already exists - skipping
#
# [509/685] Plasterers and Stucco Masons
#    ⏭️  Already exists - skipping
#
# [510/685] Plating Machine Setters, Operators, and Tenders, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [511/685] Plumbers, Pipefitters, and Steamfitters
#    ⏭️  Already exists - skipping
#
# [512/685] Podiatrists
#    ⏭️  Already exists - skipping
#
# [513/685] Poets, Lyricists and Creative Writers
#    ⏭️  Already exists - skipping
#
# [514/685] Police and Sheriff's Patrol Officers
#    ⏭️  Already exists - skipping
#
# [515/685] Postal Service Clerks
#    ⏭️  Already exists - skipping
#
# [516/685] Postal Service Mail Carriers
#    ⏭️  Already exists - skipping
#
# [517/685] Postal Service Mail Sorters, Processors, and Processing Machine Operators
#    ⏭️  Already exists - skipping
#
# [518/685] Postmasters and Mail Superintendents
#    ⏭️  Already exists - skipping
#
# [519/685] Potters, Manufacturing
#    ⏭️  Already exists - skipping
#
# [520/685] Pourers and Casters, Metal
#    ⏭️  Already exists - skipping
#
# [521/685] Power Distributors and Dispatchers
#    ⏭️  Already exists - skipping
#
# [522/685] Power Plant Operators
#    ⏭️  Already exists - skipping
#
# [523/685] Prepress Technicians and Workers
#    ⏭️  Already exists - skipping
#
# [524/685] Preschool Teachers, Except Special Education
#    ⏭️  Already exists - skipping
#
# [525/685] Pressers, Textile, Garment, and Related Materials
#    ⏭️  Already exists - skipping
#
# [526/685] Print Binding and Finishing Workers
#    ⏭️  Already exists - skipping
#
# [527/685] Printing Press Operators
#    ⏭️  Already exists - skipping
#
# [528/685] Probation Officers and Correctional Treatment Specialists
#    ⏭️  Already exists - skipping
#
# [529/685] Procurement Clerks
#    ⏭️  Already exists - skipping
#
# [530/685] Producers and Directors
#    ⏭️  Already exists - skipping
#
# [531/685] Production, Planning, and Expediting Clerks
#    ⏭️  Already exists - skipping
#
# [532/685] Proofreaders and Copy Markers
#    ⏭️  Already exists - skipping
#
# [533/685] Property, Real Estate, and Community Association Managers
#    ⏭️  Already exists - skipping
#
# [534/685] Prosthodontists
#    ⏭️  Already exists - skipping
#
# [535/685] Psychiatric Aides
#    ⏭️  Already exists - skipping
#
# [536/685] Psychiatric Technicians
#    ⏭️  Already exists - skipping
#
# [537/685] Psychiatrists
#    ⏭️  Already exists - skipping
#
# [538/685] Public Safety Telecommunicators
#    ⏭️  Already exists - skipping
#
# [539/685] Pump Operators, Except Wellhead Pumpers
#    ⏭️  Already exists - skipping
#
# [540/685] Purchasing Agents, Except Wholesale, Retail, and Farm Products
#    ⏭️  Already exists - skipping
#
# [541/685] Purchasing Managers
#    ⏭️  Already exists - skipping
#
# [542/685] Quality Control Analysts
#    ⏭️  Already exists - skipping
#
# [543/685] Quality Control Systems Managers
#    ⏭️  Already exists - skipping
#
# [544/685] Radiation Therapists
#    ⏭️  Already exists - skipping
#
# [545/685] Radiologic Technologists and Technicians
#    ⏭️  Already exists - skipping
#
# [546/685] Radiologists
#    ⏭️  Already exists - skipping
#
# [547/685] Rail Car Repairers
#    ⏭️  Already exists - skipping
#
# [548/685] Rail Yard Engineers, Dinkey Operators, and Hostlers
#    ⏭️  Already exists - skipping
#
# [549/685] Railroad Brake, Signal, and Switch Operators and Locomotive Firers
#    ⏭️  Already exists - skipping
#
# [550/685] Railroad Conductors and Yardmasters
#    ⏭️  Already exists - skipping
#
# [551/685] Real Estate Brokers
#    ⏭️  Already exists - skipping
#
# [552/685] Real Estate Sales Agents
#    ⏭️  Already exists - skipping
#
# [553/685] Receptionists and Information Clerks
#    ⏭️  Already exists - skipping
#
# [554/685] Recreation Workers
#    ⏭️  Already exists - skipping
#
# [555/685] Recreation and Fitness Studies Teachers, Postsecondary
#    ⏭️  Already exists - skipping
#
# [556/685] Recreational Therapists
#    ⏭️  Already exists - skipping
#
# [557/685] Recreational Vehicle Service Technicians
#    ⏭️  Already exists - skipping
#
# [558/685] Recycling Coordinators
#    ⏭️  Already exists - skipping
#
# [559/685] Recycling and Reclamation Workers
#    ⏭️  Already exists - skipping
#
# [560/685] Refractory Materials Repairers, Except Brickmasons
#    ⏭️  Already exists - skipping
#
# [561/685] Refuse and Recyclable Material Collectors
#    ⏭️  Already exists - skipping
#
# [562/685] Registered Nurses
#    ⏭️  Already exists - skipping
#
# [563/685] Rehabilitation Counselors
#    ⏭️  Already exists - skipping
#
# [564/685] Reinforcing Iron and Rebar Workers
#    ⏭️  Already exists - skipping
#
# [565/685] Reservation and Transportation Ticket Agents and Travel Clerks
#    ⏭️  Already exists - skipping
#
# [566/685] Residential Advisors
#    ⏭️  Already exists - skipping
#
# [567/685] Respiratory Therapists
#    ⏭️  Already exists - skipping
#
# [568/685] Retail Loss Prevention Specialists
#    ⏭️  Already exists - skipping
#
# [569/685] Retail Salespersons
#    ⏭️  Already exists - skipping
#
# [570/685] Riggers
#    ⏭️  Already exists - skipping
#
# [571/685] Rock Splitters, Quarry
#    ⏭️  Already exists - skipping
#
# [572/685] Rolling Machine Setters, Operators, and Tenders, Metal and Plastic
#    ⏭️  Already exists - skipping
#
# [573/685] Roof Bolters, Mining
#    ⏭️  Already exists - skipping
#
# [574/685] Rotary Drill Operators, Oil and Gas
#    ⏭️  Already exists - skipping
#
# [575/685] Roustabouts, Oil and Gas
#    ⏭️  Already exists - skipping
#
# [576/685] Sailors and Marine Oilers
#    ⏭️  Already exists - skipping
#
# [577/685] Sales Managers
#    ⏭️  Already exists - skipping
#
# [578/685] Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products
#    ⏭️  Already exists - skipping
#
# [579/685] Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products
#    ⏭️  Already exists - skipping
#
# [580/685] Sawing Machine Setters, Operators, and Tenders, Wood
#    ⏭️  Already exists - skipping
#
# [581/685] School Psychologists
#    ⏭️  Already exists - skipping
#
# [582/685] Secondary School Teachers, Except Special and Career/Technical Education
#    ⏭️  Already exists - skipping
#
# [583/685] Secretaries and Administrative Assistants, Except Legal, Medical, and Executive
#    ⏭️  Already exists - skipping
#
# [584/685] Securities, Commodities, and Financial Services Sales Agents
#    ⏭️  Already exists - skipping
#
# [585/685] Security Guards
#    ⏭️  Already exists - skipping
#
# [586/685] Security and Fire Alarm Systems Installers
#    ⏭️  Already exists - skipping
#
# [587/685] Self-Enrichment Teachers
#    ⏭️  Already exists - skipping
#
# [588/685] Semiconductor Processing Technicians
#    ⏭️  Already exists - skipping
#
# [589/685] Separating, Filtering, Clarifying, Precipitating, and Still Machine Setters, Operators, and Tenders
#    ⏭️  Already exists - skipping
#
# [590/685] Septic Tank Servicers and Sewer Pipe Cleaners
#    ⏭️  Already exists - skipping
#
# [591/685] Service Unit Operators, Oil and Gas
#    ⏭️  Already exists - skipping
#
# [592/685] Sewers, Hand
#    ⏭️  Already exists - skipping
#
# [593/685] Sewing Machine Operators
#    ⏭️  Already exists - skipping
#
# [594/685] Shampooers
#    ⏭️  Already exists - skipping
#
# [595/685] Sheet Metal Workers
#    ⏭️  Already exists - skipping
#
# [596/685] Ship Engineers
#    ⏭️  Already exists - skipping
#
# [597/685] Shipping, Receiving, and Inventory Clerks
#    ⏭️  Already exists - skipping
#
# [598/685] Shoe Machine Operators and Tenders
#    ⏭️  Already exists - skipping
#
# [599/685] Shoe and Leather Workers and Repairers
#    ⏭️  Already exists - skipping
#
# [600/685] Signal and Track Switch Repairers
#    ⏭️  Already exists - skipping
#
# [601/685] Skincare Specialists
#    ⏭️  Already exists - skipping
#
# [602/685] Slaughterers and Meat Packers
#    ⏭️  Already exists - skipping
#
# [603/685] Social and Community Service Managers
#    ⏭️  Already exists - skipping
#
# [604/685] Software Quality Assurance Analysts and Testers
#    ⏭️  Already exists - skipping
#
# [605/685] Solar Energy Installation Managers
#    ⏭️  Already exists - skipping
#
# [606/685] Solar Sales Representatives and Assessors
#    ⏭️  Already exists - skipping
#
# [607/685] Sound Engineering Technicians
#    ⏭️  Already exists - skipping
#
# [608/685] Spa Managers
#    ⏭️  Already exists - skipping
#
# [609/685] Special Education Teachers, Middle School
#    ⏭️  Already exists - skipping
#
# [610/685] Special Education Teachers, Preschool
#    ⏭️  Already exists - skipping
#
# [611/685] Special Education Teachers, Secondary School
#    ⏭️  Already exists - skipping
#
# [612/685] Special Effects Artists and Animators
#    ⏭️  Already exists - skipping
#
# [613/685] Speech-Language Pathologists
#    ⏭️  Already exists - skipping
#
# [614/685] Speech-Language Pathology Assistants
#    ⏭️  Already exists - skipping
#
# [615/685] Sports Medicine Physicians
#    ⏭️  Already exists - skipping
#
# [616/685] Stationary Engineers and Boiler Operators
#    ⏭️  Already exists - skipping
#
# [617/685] Statistical Assistants
#    ⏭️  Already exists - skipping
#
# [618/685] Stockers and Order Fillers
#    ⏭️  Already exists - skipping
#
# [619/685] Stone Cutters and Carvers, Manufacturing
#    ⏭️  Already exists - skipping
#
# [620/685] Stonemasons
#    ⏭️  Already exists - skipping
#
# [621/685] Structural Iron and Steel Workers
#    ⏭️  Already exists - skipping
#
# [622/685] Structural Metal Fabricators and Fitters
#    ⏭️  Already exists - skipping
#
# [623/685] Substance Abuse and Behavioral Disorder Counselors
#    ⏭️  Already exists - skipping
#
# [624/685] Subway and Streetcar Operators
#    ⏭️  Already exists - skipping
#
# [625/685] Supply Chain Managers
#    ⏭️  Already exists - skipping
#
# [626/685] Surgical Assistants
#    ⏭️  Already exists - skipping
#
# [627/685] Surgical Technologists
#    ⏭️  Already exists - skipping
#
# [628/685] Surveyors
#    ⏭️  Already exists - skipping
#
# [629/685] Switchboard Operators, Including Answering Service
#    ⏭️  Already exists - skipping
#
# [630/685] Tailors, Dressmakers, and Custom Sewers
#    ⏭️  Already exists - skipping
#
# [631/685] Tank Car, Truck, and Ship Loaders
#    ⏭️  Already exists - skipping
#
# [632/685] Tapers
#    ⏭️  Already exists - skipping
#
# [633/685] Tax Examiners and Collectors, and Revenue Agents
#    ⏭️  Already exists - skipping
#
# [634/685] Tax Preparers
#    ⏭️  Already exists - skipping
#
# [635/685] Team Assemblers
#    ⏭️  Already exists - skipping
#
# [636/685] Technical Writers
#    ⏭️  Already exists - skipping
#
# [637/685] Telecommunications Equipment Installers and Repairers, Except Line Installers
#    ⏭️  Already exists - skipping
#
# [638/685] Telecommunications Line Installers and Repairers
#    ⏭️  Already exists - skipping
#
# [639/685] Telemarketers
#    ⏭️  Already exists - skipping
#
# [640/685] Telephone Operators
#    ⏭️  Already exists - skipping
#
# [641/685] Tellers
#    ⏭️  Already exists - skipping
#
# [642/685] Terrazzo Workers and Finishers
#    ⏭️  Already exists - skipping
#
# [643/685] Textile Bleaching and Dyeing Machine Operators and Tenders
#    ⏭️  Already exists - skipping
#
# [644/685] Textile Cutting Machine Setters, Operators, and Tenders
#    ⏭️  Already exists - skipping
#
# [645/685] Textile Knitting and Weaving Machine Setters, Operators, and Tenders
#    ⏭️  Already exists - skipping
#
# [646/685] Textile Winding, Twisting, and Drawing Out Machine Setters, Operators, and Tenders
#    ⏭️  Already exists - skipping
#
# [647/685] Tile and Stone Setters
#    ⏭️  Already exists - skipping
#
# [648/685] Timing Device Assemblers and Adjusters
#    ⏭️  Already exists - skipping
#
# [649/685] Tire Builders
#    ⏭️  Already exists - skipping
#
# [650/685] Tire Repairers and Changers
#    ⏭️  Already exists - skipping
#
# [651/685] Title Examiners, Abstractors, and Searchers
#    ⏭️  Already exists - skipping
#
# [652/685] Tool Grinders, Filers, and Sharpeners
#    ⏭️  Already exists - skipping
#
# [653/685] Tool and Die Makers
#    ⏭️  Already exists - skipping
#
# [654/685] Tour Guides and Escorts
#    ⏭️  Already exists - skipping
#
# [655/685] Transit and Railroad Police
#    ⏭️  Already exists - skipping
#
# [656/685] Transportation Security Screeners
#    ⏭️  Already exists - skipping
#
# [657/685] Transportation Vehicle, Equipment and Systems Inspectors, Except Aviation
#    ⏭️  Already exists - skipping
#
# [658/685] Transportation, Storage, and Distribution Managers
#    ⏭️  Already exists - skipping
#
# [659/685] Travel Agents
#    ⏭️  Already exists - skipping
#
# [660/685] Travel Guides
#    ⏭️  Already exists - skipping
#
# [661/685] Treasurers and Controllers
#    ⏭️  Already exists - skipping
#
# [662/685] Tree Trimmers and Pruners
#    ⏭️  Already exists - skipping
#
# [663/685] Tutors
#    ⏭️  Already exists - skipping
#
# [664/685] Upholsterers
#    ⏭️  Already exists - skipping
#
# [665/685] Urologists
#    ⏭️  Already exists - skipping
#
# [666/685] Ushers, Lobby Attendants, and Ticket Takers
#    ⏭️  Already exists - skipping
#
# [667/685] Veterinarians
#    ⏭️  Already exists - skipping
#
# [668/685] Veterinary Assistants and Laboratory Animal Caretakers
#    ⏭️  Already exists - skipping
#
# [669/685] Veterinary Technologists and Technicians
#    ⏭️  Already exists - skipping
#
# [670/685] Waiters and Waitresses
#    ⏭️  Already exists - skipping
#
# [671/685] Watch and Clock Repairers
#    ⏭️  Already exists - skipping
#
# [672/685] Water and Wastewater Treatment Plant and System Operators
#    ⏭️  Already exists - skipping
#
# [673/685] Water/Wastewater Engineers
#    ⏭️  Already exists - skipping
#
# [674/685] Weatherization Installers and Technicians
#    ⏭️  Already exists - skipping
#
# [675/685] Web Administrators
#    ⏭️  Already exists - skipping
#
# [676/685] Web Developers
#    ⏭️  Already exists - skipping
#
# [677/685] Weighers, Measurers, Checkers, and Samplers, Recordkeeping
#    ⏭️  Already exists - skipping
#
# [678/685] Welders, Cutters, Solderers, and Brazers
#    ⏭️  Already exists - skipping
#
# [679/685] Welding, Soldering, and Brazing Machine Setters, Operators, and Tenders
#    ⏭️  Already exists - skipping
#
# [680/685] Wellhead Pumpers
#    ⏭️  Already exists - skipping
#
# [681/685] Wholesale and Retail Buyers, Except Farm Products
#    ⏭️  Already exists - skipping
#
# [682/685] Wind Energy Operations Managers
#    ⏭️  Already exists - skipping
#
# [683/685] Wind Turbine Service Technicians
#    ⏭️  Already exists - skipping
#
# [684/685] Woodworking Machine Setters, Operators, and Tenders, Except Sawing
#    ⏭️  Already exists - skipping
#
# [685/685] Word Processors and Typists
#    ⏭️  Already exists - skipping
#
# ==================================================
# PROCESSING COMPLETE
# ==================================================
# • 0 occupations processed
# • 685 occupations skipped (already existed)
# • 0 occupations failed
# • 685 total occupations in sample

# %%
# # Get unique minor groups
# minor_groups = ONET['Minor_Group_Title'].unique().tolist()
# minor_groups = [x for x in minor_groups if pd.notna(x)] # Drop "nan" instances
# print(f"Found {len(minor_groups)} minor SOC groups in the dataset:")

# # Process each minor group
# processed = 0
# skipped = 0
# errors = 0

# for i, minor in enumerate(minor_groups, 1):
#     occ_df = ONET[ONET['Minor_Group_Title'] == minor][['Occupation Title','O*NET-SOC Code', 'Minor_Group_Code', 'Minor_Group_Title']].drop_duplicates().reset_index(drop=True)
#     print(f"\n[{i}/{len(minor_groups)}] Minor group: {minor} (occupations: {len(occ_df)})")
#     out_file, existed = extract_occupation_sequence(minor, occ_df, output_data_path)
#     if out_file is None:
#         errors += 1
#     elif existed:
#         print('   ⏭️ Already exists - skipping')
#         skipped += 1
#     else:
#         processed += 1

# # Summary
# print('\n' + '='*50)
# print('PROCESSING COMPLETE')
# print('='*50)
# print(f'• {processed} minor groups processed')
# print(f'• {skipped} minor groups skipped (already existed)')
# print(f'• {errors} minor groups failed')
# print(f'• {len(minor_groups)} total minor groups')

# %%
# Clean up caffeinate process
try:
    if 'caff_process' in globals() and caff_process is not None:
        caff_process.terminate()
        caff_process.wait()  # Wait for process to terminate
        print("Caffeinate mode OFF 💡 - System sleep is now enabled.")
    else:
        print("Caffeinate was not running or already stopped.")
except Exception as e:
    print(f"Note: {e}")
    print("Caffeinate process may have already ended.")
# Out:
# Caffeinate mode OFF 💡 - System sleep is now enabled.
